# %% [markdown]
# ### 0.1 READ THE DATA SOURCE

# %%
import configparser

# Initiate the configparser
config = configparser.ConfigParser()

# Read the config ini file
config.read('config.ini')

# Read the csv file path
csv_file_path = config['path']['house_market']

# %% [markdown]
# ### 0.2 DEFINE THE HTML DISPLAY

# %%
from IPython.display import display, HTML
import pandas as pd

# Define the css that will make the table scrollable
css = """ 
.output {
    max-height: 700px; /* Adjiust as needed*/
    overflow: scroll /* Allows scrolling*/
}
"""

# Apply the css for the scrollable output
display(HTML('<style>{}<style>'.format(css)))

# Configure pandas display options for better visuals
pd.set_option('display.max_rows', None) # Display all rows, adjust as needed
pd.set_option('display.max_columns', None) # Display all columns, adjust as needed
pd.set_option('display.max_colwidth', 90) # Set max column width for long text
pd.options.display.float_format = '{:,.2f}'.format # Format floating-point numbers
# Out:
# <style>
# .output {
#     max-height: 700px; /* Adjiust as needed*/
#     overflow: scroll /* Allows scrolling*/
# }
# <style>

# %% [markdown]
# ____________
# ### 1. DATA EXPOSURE

# %%
# Read the csv file
housing_market = pd.read_csv(csv_file_path, encoding='UTF-8-SIG')

# Function to display the data overview
def display_data (df,title):
    shape_info = f"<div><b>Dataframe Shape:<b>{df.shape}</div>" 
    summary_stats = df.describe().to_html()
    data_types = df.dtypes.to_frame().to_html()

    # Display title, table, data types, summary statistics and complete dataset
    display(HTML(f"<h3>{title}</h3>"))
    display(HTML(shape_info))
    display(HTML(f"<div><b>Data Types:</b></div>"))
    display(HTML(data_types))
    display(HTML(f"<div><b>Summary Statistics:</b></div>"))
    display(HTML(summary_stats))
    display(HTML(f"<div><b>Complete Dataset:</b></div>"))
    display(HTML(df.to_html(index=False)))

# Display the function
display_data(housing_market, "HOUSING MARKET DATA OVERVIEW")
# Out:
# <h3>HOUSING MARKET DATA OVERVIEW</h3>
# <div><b>Dataframe Shape:<b>(200, 11)</div>
# <div><b>Data Types:</b></div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Country</th>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>House Price Index</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>Rent Index</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>Affordability Ratio</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>Mortgage Rate (%)</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>Inflation Rate (%)</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>GDP Growth (%)</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>Population Growth (%)</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>Urbanization Rate (%)</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>Construction Index</th>
#       <td>float64</td>
#     </tr>
#   </tbody>
# </table>
# <div><b>Summary Statistics:</b></div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>House Price Index</th>
#       <th>Rent Index</th>
#       <th>Affordability Ratio</th>
#       <th>Mortgage Rate (%)</th>
#       <th>Inflation Rate (%)</th>
#       <th>GDP Growth (%)</th>
#       <th>Population Growth (%)</th>
#       <th>Urbanization Rate (%)</th>
#       <th>Construction Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>2,019.50</td>
#       <td>130.38</td>
#       <td>83.05</td>
#       <td>7.24</td>
#       <td>4.15</td>
#       <td>3.65</td>
#       <td>2.13</td>
#       <td>0.72</td>
#       <td>74.77</td>
#       <td>111.20</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>2.88</td>
#       <td>28.75</td>
#       <td>21.44</td>
#       <td>2.58</td>
#       <td>1.38</td>
#       <td>1.88</td>
#       <td>2.41</td>
#       <td>1.04</td>
#       <td>8.73</td>
#       <td>24.31</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>2,015.00</td>
#       <td>80.55</td>
#       <td>50.35</td>
#       <td>3.04</td>
#       <td>1.54</td>
#       <td>0.53</td>
#       <td>-1.92</td>
#       <td>-0.96</td>
#       <td>60.17</td>
#       <td>70.97</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>2,017.00</td>
#       <td>104.14</td>
#       <td>60.47</td>
#       <td>5.03</td>
#       <td>3.05</td>
#       <td>1.94</td>
#       <td>-0.10</td>
#       <td>-0.18</td>
#       <td>66.92</td>
#       <td>90.18</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>2,019.50</td>
#       <td>129.19</td>
#       <td>83.72</td>
#       <td>7.38</td>
#       <td>4.33</td>
#       <td>3.66</td>
#       <td>2.31</td>
#       <td>0.72</td>
#       <td>75.10</td>
#       <td>110.59</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>2,022.00</td>
#       <td>157.13</td>
#       <td>100.60</td>
#       <td>9.28</td>
#       <td>5.22</td>
#       <td>5.26</td>
#       <td>4.27</td>
#       <td>1.62</td>
#       <td>82.68</td>
#       <td>133.78</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>2,024.00</td>
#       <td>179.97</td>
#       <td>119.86</td>
#       <td>11.88</td>
#       <td>6.49</td>
#       <td>6.91</td>
#       <td>5.96</td>
#       <td>2.50</td>
#       <td>89.79</td>
#       <td>149.74</td>
#     </tr>
#   </tbody>
# </table>
# <div><b>Complete Dataset:</b></div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Country</th>
#       <th>Year</th>
#       <th>House Price Index</th>
#       <th>Rent Index</th>
#       <th>Affordability Ratio</th>
#       <th>Mortgage Rate (%)</th>
#       <th>Inflation Rate (%)</th>
#       <th>GDP Growth (%)</th>
#       <th>Population Growth (%)</th>
#       <th>Urbanization Rate (%)</th>
#       <th>Construction Index</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>USA</td>
#       <td>2015</td>
#       <td>117.45</td>
#       <td>116.55</td>
#       <td>9.59</td>
#       <td>4.49</td>
#       <td>1.51</td>
#       <td>-0.75</td>
#       <td>-0.80</td>
#       <td>85.99</td>
#       <td>118.09</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2016</td>
#       <td>150.81</td>
#       <td>51.44</td>
#       <td>11.73</td>
#       <td>5.66</td>
#       <td>1.88</td>
#       <td>-0.55</td>
#       <td>-0.36</td>
#       <td>69.13</td>
#       <td>111.98</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2017</td>
#       <td>123.19</td>
#       <td>70.39</td>
#       <td>8.51</td>
#       <td>2.20</td>
#       <td>2.40</td>
#       <td>0.93</td>
#       <td>0.60</td>
#       <td>83.56</td>
#       <td>85.97</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2018</td>
#       <td>131.42</td>
#       <td>91.47</td>
#       <td>3.42</td>
#       <td>4.54</td>
#       <td>1.61</td>
#       <td>-1.48</td>
#       <td>2.32</td>
#       <td>88.97</td>
#       <td>134.67</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2019</td>
#       <td>110.46</td>
#       <td>56.84</td>
#       <td>9.16</td>
#       <td>3.70</td>
#       <td>1.29</td>
#       <td>1.96</td>
#       <td>-0.88</td>
#       <td>87.28</td>
#       <td>90.70</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2020</td>
#       <td>146.25</td>
#       <td>71.82</td>
#       <td>7.68</td>
#       <td>4.23</td>
#       <td>1.70</td>
#       <td>5.76</td>
#       <td>1.71</td>
#       <td>88.18</td>
#       <td>141.59</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2021</td>
#       <td>139.79</td>
#       <td>114.53</td>
#       <td>3.80</td>
#       <td>2.48</td>
#       <td>0.79</td>
#       <td>0.60</td>
#       <td>0.36</td>
#       <td>68.14</td>
#       <td>136.30</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2022</td>
#       <td>115.68</td>
#       <td>69.67</td>
#       <td>7.88</td>
#       <td>2.20</td>
#       <td>5.71</td>
#       <td>-1.40</td>
#       <td>2.45</td>
#       <td>83.17</td>
#       <td>85.90</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2023</td>
#       <td>80.55</td>
#       <td>107.08</td>
#       <td>9.36</td>
#       <td>5.15</td>
#       <td>5.51</td>
#       <td>-1.41</td>
#       <td>0.25</td>
#       <td>63.48</td>
#       <td>139.05</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>2024</td>
#       <td>142.33</td>
#       <td>73.16</td>
#       <td>3.57</td>
#       <td>3.05</td>
#       <td>2.61</td>
#       <td>3.84</td>
#       <td>1.23</td>
#       <td>86.62</td>
#       <td>107.78</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2015</td>
#       <td>91.96</td>
#       <td>99.93</td>
#       <td>9.85</td>
#       <td>4.31</td>
#       <td>5.51</td>
#       <td>1.95</td>
#       <td>0.83</td>
#       <td>72.83</td>
#       <td>72.03</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2016</td>
#       <td>90.79</td>
#       <td>52.20</td>
#       <td>8.73</td>
#       <td>3.07</td>
#       <td>3.81</td>
#       <td>5.26</td>
#       <td>-0.13</td>
#       <td>72.31</td>
#       <td>130.44</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2017</td>
#       <td>102.88</td>
#       <td>55.39</td>
#       <td>5.61</td>
#       <td>2.31</td>
#       <td>6.54</td>
#       <td>4.46</td>
#       <td>1.22</td>
#       <td>86.14</td>
#       <td>134.29</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2018</td>
#       <td>98.66</td>
#       <td>112.48</td>
#       <td>7.85</td>
#       <td>5.54</td>
#       <td>6.32</td>
#       <td>0.54</td>
#       <td>-0.61</td>
#       <td>66.84</td>
#       <td>104.17</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2019</td>
#       <td>161.80</td>
#       <td>110.25</td>
#       <td>3.06</td>
#       <td>4.05</td>
#       <td>3.21</td>
#       <td>-0.22</td>
#       <td>-0.58</td>
#       <td>70.13</td>
#       <td>145.43</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2020</td>
#       <td>112.32</td>
#       <td>86.32</td>
#       <td>9.33</td>
#       <td>3.32</td>
#       <td>6.82</td>
#       <td>5.70</td>
#       <td>-0.12</td>
#       <td>74.92</td>
#       <td>94.07</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2021</td>
#       <td>108.48</td>
#       <td>52.58</td>
#       <td>8.49</td>
#       <td>4.01</td>
#       <td>0.83</td>
#       <td>0.23</td>
#       <td>2.18</td>
#       <td>67.19</td>
#       <td>81.59</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2022</td>
#       <td>128.95</td>
#       <td>119.00</td>
#       <td>5.18</td>
#       <td>4.86</td>
#       <td>5.45</td>
#       <td>-0.10</td>
#       <td>1.55</td>
#       <td>71.03</td>
#       <td>120.58</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2023</td>
#       <td>143.35</td>
#       <td>87.50</td>
#       <td>3.81</td>
#       <td>5.68</td>
#       <td>2.59</td>
#       <td>-0.51</td>
#       <td>-0.86</td>
#       <td>77.73</td>
#       <td>124.21</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>2024</td>
#       <td>81.66</td>
#       <td>85.85</td>
#       <td>5.04</td>
#       <td>4.73</td>
#       <td>1.63</td>
#       <td>3.53</td>
#       <td>0.35</td>
#       <td>88.10</td>
#       <td>81.00</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2015</td>
#       <td>114.11</td>
#       <td>57.94</td>
#       <td>11.32</td>
#       <td>5.89</td>
#       <td>2.18</td>
#       <td>3.28</td>
#       <td>1.86</td>
#       <td>76.66</td>
#       <td>112.37</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2016</td>
#       <td>104.19</td>
#       <td>56.52</td>
#       <td>11.07</td>
#       <td>6.00</td>
#       <td>4.62</td>
#       <td>0.71</td>
#       <td>0.22</td>
#       <td>81.78</td>
#       <td>141.77</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2017</td>
#       <td>168.71</td>
#       <td>104.59</td>
#       <td>8.78</td>
#       <td>1.92</td>
#       <td>1.55</td>
#       <td>5.19</td>
#       <td>1.12</td>
#       <td>60.28</td>
#       <td>78.12</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2018</td>
#       <td>146.35</td>
#       <td>50.35</td>
#       <td>4.45</td>
#       <td>4.24</td>
#       <td>5.00</td>
#       <td>3.22</td>
#       <td>-0.22</td>
#       <td>81.37</td>
#       <td>88.98</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2019</td>
#       <td>112.54</td>
#       <td>102.25</td>
#       <td>8.85</td>
#       <td>5.75</td>
#       <td>4.77</td>
#       <td>2.55</td>
#       <td>-0.67</td>
#       <td>71.03</td>
#       <td>91.22</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2020</td>
#       <td>104.40</td>
#       <td>118.11</td>
#       <td>6.54</td>
#       <td>5.96</td>
#       <td>4.60</td>
#       <td>4.36</td>
#       <td>0.76</td>
#       <td>77.31</td>
#       <td>109.40</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2021</td>
#       <td>99.52</td>
#       <td>100.57</td>
#       <td>5.53</td>
#       <td>1.62</td>
#       <td>4.70</td>
#       <td>-0.58</td>
#       <td>2.29</td>
#       <td>88.62</td>
#       <td>143.19</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2022</td>
#       <td>117.02</td>
#       <td>51.08</td>
#       <td>11.35</td>
#       <td>3.64</td>
#       <td>6.78</td>
#       <td>5.71</td>
#       <td>1.99</td>
#       <td>68.83</td>
#       <td>100.81</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2023</td>
#       <td>165.11</td>
#       <td>72.18</td>
#       <td>4.53</td>
#       <td>4.28</td>
#       <td>6.59</td>
#       <td>3.57</td>
#       <td>1.00</td>
#       <td>62.92</td>
#       <td>119.20</td>
#     </tr>
#     <tr>
#       <td>UK</td>
#       <td>2024</td>
#       <td>179.01</td>
#       <td>59.81</td>
#       <td>7.66</td>
#       <td>5.89</td>
#       <td>5.31</td>
#       <td>3.58</td>
#       <td>1.46</td>
#       <td>70.78</td>
#       <td>93.49</td>
#     </tr>
#     <tr>
#       <td>Germany</td>
#       <td>2015</td>
#       <td>160.94</td>
#       <td>106.71</td>
#       <td>10.80</td>
#       <td>6.07</td>
#       <td>3.82</td>
#       <td>2.01</td>
#       <td>1

# %% [markdown]
# #### MARKET INDICATORS OVERVIEW
#
# - **House Price Index:** The average price changes in repeat sales or refinancings on the same properties [Investopedia](https://www.investopedia.com/terms/h/house-price-index-hpi.asp).
# - **Rent Index:** The change in rental prices over time, considering geography and property type.
# - **Affordability Ratio:** The general cost of living in the region, and the capability of affording basic living goods. [Investopedia](https://www.investopedia.com/terms/a/affordability-index.asp).
# - **Mortgage Rate(%):** The interest charged for a home loan, highly sensitive to economic conditions [Investopedia](https://www.investopedia.com/terms/m/mortgage-rate.asp).
# - **Population Growth(%):** Population size changes overtime [WorldBank](https://data.worldbank.org/indicator/SP.POP.GROW?end=2023&start=1961&view=chart).
# - **Urbanization Rate (%):** The numbers of persons residing in an area defined as ''urban'' per 100 total population. [WorldBank](https://databank.worldbank.org/metadataglossary/world-development-indicators/series/SP.URB.TOTL.IN.ZS)
# - **Construction Index:** Changes in the cost of construction, or price fluctuation of required resources.

# %% [markdown]
# ____________
# ### 2. DATA PREPARE

# %% [markdown]
# ##### A. DEFINE AND APPLY A STANDARD CLEANING FUNCTION

# %%
# Define a standard cleaning function
def clean_dataset (df,dtype_mapping=None, index_col=None):
    """ 
    data cleaning function

    Parameters
    1. df: Input DataFrame
    2. dtype_mapping: Dictionary of column: dtype for conversion
    3. index_col: Column to set as index

    Returns
    - cleaned display
    - Display cleaning report
    """
    # Initiate the cleaning report
    report ={
        'original_shape': df.shape,
        'duplicates_removed': 0,
        'missing_values': {},
        'type_changes': {},
        'index_set': None,
        'final_shape': None
    }

    # Create working copy
    df_clean = df.copy()

    # 1. Handle data type conversions
    if dtype_mapping:
        for col, dtype in dtype_mapping.items():
            if col not in df_clean.columns:
                raise ValueError(f"Column '{col}' not found in DataFrame")
            try:
                old_type = str(df_clean[col].dtype)
                df_clean[col] = df_clean[col].astype(dtype)
                new_type = str(df_clean[col].dtype)
                if old_type != new_type:
                    report['type_changes'][col] = f"{old_type} → {new_type}"
            except (ValueError, TypeError) as e:
                raise ValueError(f"Failed to convert column '{col}' to {dtype}: {str(e)}")

    # 2. Identify missing values and report only
    for col in df_clean.columns:
        missing = df_clean[col].isna().sum()
        if missing > 0:
            report['missing_values'][col] = missing
    
   # 3. Remove duplicates
    duplicates = df_clean.duplicated().sum()
    df_clean.drop_duplicates(inplace=True)
    report['duplicates_removed'] = duplicates

    # 4. Set index if specified
    if index_col and index_col in df_clean.columns:
        df_clean.set_index(index_col, inplace=True)
        report['index_set'] = index_col

    # 5. Final metadata
    report['final_shape'] = df_clean.shape

    # Display report
    display_cleaning_report(report)

    return df_clean

def display_cleaning_report(report):
    """Display compact cleaning report"""
    html = """
    <style>
        .cleaning-report {
            font-family: Arial, sans-serif;
            border-collapse: collapse;
            width: 100%;
            margin-bottom: 20px;
        }
        .cleaning-report th {
            background-color: #f2f2f2;
            text-align: left;
            padding: 8px;
            border: 1px solid #ddd;
        }
        .cleaning-report td {
            padding: 8px;
            border: 1px solid #ddd;
        }
        .cleaning-report tr:nth-child(even) {
            background-color: #f9f9f9;
        }
    </style>
    <h3>Data Cleaning Report</h3>
    <table class="cleaning-report">
        <tr>
            <th>Operation</th>
            <th>Details</th>
        </tr>
    """
    
    # Basic stats
    html += f"""
        <tr>
            <td>Original Shape</td>
            <td>{report['original_shape']}</td>
        </tr>
        <tr>
            <td>Final Shape</td>
            <td>{report['final_shape']}</td>
        </tr>
        <tr>
            <td>Duplicates Removed</td>
            <td>{report['duplicates_removed']}</td>
        </tr>
    """
    
    # Missing values
    if report['missing_values']:
        html += """
        <tr>
            <td>Missing Values Found</td>
            <td>
        """
        for col, count in report['missing_values'].items():
            html += f"{col}: {count}<br>"
        html += "</td></tr>"
    
    # Type changes
    html += """
        <tr>
            <td>Data Type Changes</td>
            <td>
    """
    if report['type_changes']:
        for col, change in report['type_changes'].items():
            html += f"{col}: {change}<br>"
    else:
        html += "None"
    html += "</td></tr>"

    
    # Index setting
    if report['index_set']:
        html += f"""
        <tr>
            <td>Index Set</td>
            <td>{report['index_set']}</td>
        </tr>
        """
    
    html += "</table>"
    display(HTML(html))

# %%
# Define the new dtype mapping
dtype_spec = {
    'Country': 'object',
    'Year':'int64',
    'House Price Index':'float64',
    'Rent Index':'float64',
    'Affordability Ratio':'float64',
    'Mortgage Rate (%)':'float64',
    'Inflation Rate (%)':'float64',
    'GDP Growth (%)':'float64',
    'Population Growth (%)':'float64',
    'Urbanization Rate (%)':'float64',
    'Construction Index':'float64',
}

# Clean the data
cleaned_df = clean_dataset(
    housing_market,
    dtype_mapping=dtype_spec,
    index_col=None
)
# Out:
#     <style>
#         .cleaning-report {
#             font-family: Arial, sans-serif;
#             border-collapse: collapse;
#             width: 100%;
#             margin-bottom: 20px;
#         }
#         .cleaning-report th {
#             background-color: #f2f2f2;
#             text-align: left;
#             padding: 8px;
#             border: 1px solid #ddd;
#         }
#         .cleaning-report td {
#             padding: 8px;
#             border: 1px solid #ddd;
#         }
#         .cleaning-report tr:nth-child(even) {
#             background-color: #f9f9f9;
#         }
#     </style>
#     <h3>Data Cleaning Report</h3>
#     <table class="cleaning-report">
#         <tr>
#             <th>Operation</th>
#             <th>Details</th>
#         </tr>
#
#         <tr>
#             <td>Original Shape</td>
#             <td>(200, 11)</td>
#         </tr>
#         <tr>
#             <td>Final Shape</td>
#             <td>(200, 11)</td>
#         </tr>
#         <tr>
#             <td>Duplicates Removed</td>
#             <td>0</td>
#         </tr>
#
#         <tr>
#             <td>Data Type Changes</td>
#             <td>
#     None</td></tr></table>

# %% [markdown]
# ##### B. CREATE DERIVE FIELDS TO OPTIMIZE ANALYSIS
#
# ##### Step 1: Add a regional group field for simplied analysis
#
# IMPORTANT: This dataset includes twenty one countries!
# - NA (2)
# - LATAM(2)
# - EMEA (11)
# - APAC (5)

# %%
# Define the mapping logic for regional grouping
regional_grouping = {
    # North America
    'USA': 'NA', 
    'Canada': 'NA',
    # Latin America
    'Brazil': 'LATAM', 
    'Mexico': 'LATAM',
    'Argentina': 'LATAM',
    # Europe, Middle East, Africa
    'UK': 'EMEA', 
    'Germany': 'EMEA',
    'France': 'EMEA', 
    'Italy': 'EMEA', 
    'Spain': 'EMEA',
    'South Africa': 'EMEA', 
    'Russia': 'EMEA', 
    'Netherlands': 'EMEA',
    'Sweden': 'EMEA', 
    'Switzerland': 'EMEA', 
    'UAE': 'EMEA',
    # Asia Pacific
    'Australia': 'APAC', 
    'India': 'APAC', 
    'China': 'APAC', 
    'Japan': 'APAC',
    'South Korea': 'APAC',
    'Singapore': 'APAC' 
}

# Simple mapping for regional group addition
cleaned_df['derived_regional_group'] = cleaned_df['Country'].map(regional_grouping)

# Create country-region summary table
regional_validation_table = (
    cleaned_df
    .groupby([ 'derived_regional_group', 'Country'])
    .size()  # Count rows per group
    .reset_index(name='Row Count')
    .sort_values('derived_regional_group') 
    # Format for clean display
    .style
    .hide(axis='index')
)

display(HTML(regional_validation_table.to_html()))
# Out:
# <style type="text/css">
# </style>
# <table id="T_eb37d">
#   <thead>
#     <tr>
#       <th id="T_eb37d_level0_col0" class="col_heading level0 col0" >derived_regional_group</th>
#       <th id="T_eb37d_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_eb37d_level0_col2" class="col_heading level0 col2" >Row Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eb37d_row0_col0" class="data row0 col0" >APAC</td>
#       <td id="T_eb37d_row0_col1" class="data row0 col1" >Australia</td>
#       <td id="T_eb37d_row0_col2" class="data row0 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row1_col0" class="data row1 col0" >APAC</td>
#       <td id="T_eb37d_row1_col1" class="data row1 col1" >China</td>
#       <td id="T_eb37d_row1_col2" class="data row1 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row2_col0" class="data row2 col0" >APAC</td>
#       <td id="T_eb37d_row2_col1" class="data row2 col1" >India</td>
#       <td id="T_eb37d_row2_col2" class="data row2 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row3_col0" class="data row3 col0" >APAC</td>
#       <td id="T_eb37d_row3_col1" class="data row3 col1" >Japan</td>
#       <td id="T_eb37d_row3_col2" class="data row3 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row4_col0" class="data row4 col0" >APAC</td>
#       <td id="T_eb37d_row4_col1" class="data row4 col1" >South Korea</td>
#       <td id="T_eb37d_row4_col2" class="data row4 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row5_col0" class="data row5 col0" >EMEA</td>
#       <td id="T_eb37d_row5_col1" class="data row5 col1" >UK</td>
#       <td id="T_eb37d_row5_col2" class="data row5 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row6_col0" class="data row6 col0" >EMEA</td>
#       <td id="T_eb37d_row6_col1" class="data row6 col1" >UAE</td>
#       <td id="T_eb37d_row6_col2" class="data row6 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row7_col0" class="data row7 col0" >EMEA</td>
#       <td id="T_eb37d_row7_col1" class="data row7 col1" >Switzerland</td>
#       <td id="T_eb37d_row7_col2" class="data row7 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row8_col0" class="data row8 col0" >EMEA</td>
#       <td id="T_eb37d_row8_col1" class="data row8 col1" >Sweden</td>
#       <td id="T_eb37d_row8_col2" class="data row8 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row9_col0" class="data row9 col0" >EMEA</td>
#       <td id="T_eb37d_row9_col1" class="data row9 col1" >Spain</td>
#       <td id="T_eb37d_row9_col2" class="data row9 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row10_col0" class="data row10 col0" >EMEA</td>
#       <td id="T_eb37d_row10_col1" class="data row10 col1" >Russia</td>
#       <td id="T_eb37d_row10_col2" class="data row10 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row11_col0" class="data row11 col0" >EMEA</td>
#       <td id="T_eb37d_row11_col1" class="data row11 col1" >Netherlands</td>
#       <td id="T_eb37d_row11_col2" class="data row11 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row12_col0" class="data row12 col0" >EMEA</td>
#       <td id="T_eb37d_row12_col1" class="data row12 col1" >Italy</td>
#       <td id="T_eb37d_row12_col2" class="data row12 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row13_col0" class="data row13 col0" >EMEA</td>
#       <td id="T_eb37d_row13_col1" class="data row13 col1" >Germany</td>
#       <td id="T_eb37d_row13_col2" class="data row13 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row14_col0" class="data row14 col0" >EMEA</td>
#       <td id="T_eb37d_row14_col1" class="data row14 col1" >France</td>
#       <td id="T_eb37d_row14_col2" class="data row14 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row15_col0" class="data row15 col0" >EMEA</td>
#       <td id="T_eb37d_row15_col1" class="data row15 col1" >South Africa</td>
#       <td id="T_eb37d_row15_col2" class="data row15 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row16_col0" class="data row16 col0" >LATAM</td>
#       <td id="T_eb37d_row16_col1" class="data row16 col1" >Brazil</td>
#       <td id="T_eb37d_row16_col2" class="data row16 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row17_col0" class="data row17 col0" >LATAM</td>
#       <td id="T_eb37d_row17_col1" class="data row17 col1" >Mexico</td>
#       <td id="T_eb37d_row17_col2" class="data row17 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row18_col0" class="data row18 col0" >NA</td>
#       <td id="T_eb37d_row18_col1" class="data row18 col1" >Canada</td>
#       <td id="T_eb37d_row18_col2" class="data row18 col2" >10</td>
#     </tr>
#     <tr>
#       <td id="T_eb37d_row19_col0" class="data row19 col0" >NA</td>
#       <td id="T_eb37d_row19_col1" class="data row19 col1" >USA</td>
#       <td id="T_eb37d_row19_col2" class="data row19 col2" >10</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Step 2: Add a calcualted derived fields for financial analysis.

# %% [markdown]
# - **Real house price index:** Dividing the House Price by one plus Inflation for the **real purchasing power**.
# - **Real mortgage cost:** Subtraction of rates Mortgage minus Inflation for the **net borrowing cost**.
# - **Ownnership rent spread:** Multiplication of house price/rent index by mortgage to see **how many years of rent equal the house price**.
# - **Affordibility gdp population score:** Multiply Affordability by GDP and divide by population growth **adjusted Affordability**
# - **Construction urbanizatio ratio:** Divide construction costs by urbanization rate to measure **cost per unit of urbanization** or urbanization cost-efficiency.

# %%
# Create derived fields using the chaining method
cleaned_df = (
    cleaned_df.assign(
        # Real house price index adjusted for inflation
        derived_real_house_price_index = lambda df:df['House Price Index']/ (1 + df['Inflation Rate (%)']/100),
        # Mortgage cost net of inflation
        derived_real_mortgage_cost = lambda df:df['Mortgage Rate (%)'] -  df['Inflation Rate (%)'],
        # Ownership vs rent spread
        derived_ownership_rent_spread = lambda df: (df['House Price Index']/df['Rent Index']) * df['Mortgage Rate (%)'],
        # Affordability ratio adjusted to economic/demographic factors
        derived_affordability_gdp_population_score = lambda df:df['Affordability Ratio']*(1 + df['GDP Growth (%)']/100)/ (1 + df['Population Growth (%)']/100),
        # Construction vs urbanization ratio
        derived_construction_urbanization_ratio = lambda df:df['Construction Index']/ (df['Urbanization Rate (%)']/100)
    )
)

# Display the top 5 rows of the table and the included derived fields
#display(HTML(cleaned_df.head(2000).to_html()))

# %%
# calculate summary statistics of the new fields
new_stats = cleaned_df[['derived_real_house_price_index', 
                        'derived_real_mortgage_cost', 
                        'derived_ownership_rent_spread',
                        'derived_affordability_gdp_population_score',
                         'derived_construction_urbanization_ratio' ]].describe()

display(HTML(new_stats.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>derived_real_house_price_index</th>
#       <th>derived_real_mortgage_cost</th>
#       <th>derived_ownership_rent_spread</th>
#       <th>derived_affordability_gdp_population_score</th>
#       <th>derived_construction_urbanization_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#       <td>200.00</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>125.81</td>
#       <td>0.50</td>
#       <td>6.99</td>
#       <td>7.34</td>
#       <td>150.84</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>27.71</td>
#       <td>2.36</td>
#       <td>3.50</td>
#       <td>2.62</td>
#       <td>37.72</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>76.34</td>
#       <td>-4.53</td>
#       <td>1.60</td>
#       <td>3.04</td>
#       <td>81.68</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>101.43</td>
#       <td>-0.99</td>
#       <td>4.28</td>
#       <td>5.07</td>
#       <td>122.58</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>124.01</td>
#       <td>0.63</td>
#       <td>6.04</td>
#       <td>7.44</td>
#       <td>149.69</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>152.00</td>
#       <td>2.23</td>
#       <td>8.86</td>
#       <td>9.39</td>
#       <td>176.49</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>175.73</td>
#       <td>5.79</td>
#       <td>19.56</td>
#       <td>12.39</td>
#       <td>241.14</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ______________
# ### 3. DISCOVERY QUESTIONS

# %% [markdown]
# ##### ***HOW HAS THE REAL HOUSE PRICE GROWTH CHANGED PER REGIONAL GROUP OVERTIME?***

# %% [markdown]
# **Key Trend**: APAC showed the most volatility (-33% to +32%), while EMEA demonstrated relative stability until 2022's downturn.
# **Notable Shifts**:
# - **LATAM**: Extreme swings (2023: +46% → 2024: -27%) reflect emerging market sensitivity.
# - **NA**: Sustained growth (2016-2019) followed by post-pandemic correction.
# - **APAC**: 2016 contraction (-33%) reversed by 2017 infrastructure-led recovery (+32%).

# %%
# Calculate YoY changes grouped by region and country
real_house_analysis_df = (
    cleaned_df[['Country', 'Year', 'House Price Index', 'Inflation Rate (%)', 'derived_regional_group', 'derived_real_house_price_index']]
    .sort_values(['Country', 'Year'])
    .assign(
        real_house_yoy_pct=lambda df: df.groupby('Country')['derived_real_house_price_index']
        .pct_change(1).mul(100).round(2)
    )
    .round(2)
)

# Aggregate regionally (e.g., mean of YoY changes per region/year)
regional_yoy_table = (
    real_house_analysis_df
    .groupby(['Year', 'derived_regional_group'])
    ['real_house_yoy_pct'].median()
    .unstack(level=0)  
    .fillna('N/A')
    
)

# Display yoy changes table
display(HTML(regional_yoy_table.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Year</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#       <th>2021</th>
#       <th>2022</th>
#       <th>2023</th>
#       <th>2024</th>
#     </tr>
#     <tr>
#       <th>derived_regional_group</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>APAC</th>
#       <td>N/A</td>
#       <td>-33.21</td>
#       <td>32.80</td>
#       <td>-13.88</td>
#       <td>-20.91</td>
#       <td>11.91</td>
#       <td>15.29</td>
#       <td>-8.94</td>
#       <td>10.82</td>
#       <td>3.14</td>
#     </tr>
#     <tr>
#       <th>EMEA</th>
#       <td>N/A</td>
#       <td>-10.04</td>
#       <td>1.60</td>
#       <td>-4.81</td>
#       <td>-15.37</td>
#       <td>11.99</td>
#       <td>0.25</td>
#       <td>-19.46</td>
#       <td>8.88</td>
#       <td>19.26</td>
#     </tr>
#     <tr>
#       <th>LATAM</th>
#       <td>N/A</td>
#       <td>-15.47</td>
#       <td>-15.86</td>
#       <td>49.84</td>
#       <td>2.64</td>
#       <td>-21.04</td>
#       <td>11.59</td>
#       <td>-16.02</td>
#       <td>46.13</td>
#       <td>-27.42</td>
#     </tr>
#     <tr>
#       <th>NA</th>
#       <td>N/A</td>
#       <td>14.15</td>
#       <td>-4.15</td>
#       <td>1.80</td>
#       <td>26.63</td>
#       <td>-0.53</td>
#       <td>-0.62</td>
#       <td>-3.72</td>
#       <td>-7.98</td>
#       <td>19.59</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### ***WHICH COUNTRIES HAVE THE MOST VOLATILE  HOUSE PRICES?***

# %% [markdown]
# **Top 3 Volatile Markets**:
# 1. **UAE** (43.4%) - The Impact of Foreign Investment in the Dubai Residential Properties. [EUTAX](https://www.taxobservatory.eu/publication/foreign-investment-in-the-dubai-housing-market-2020-2024/)
# 2. **Sweden** (40.5%) - Post-COVID Record High Demand for Residential Housing. [Sweden RE Market Outlook](https://content.cbre.se/hubfs/content%20offers/2022%20Sweden%20Real%20Estate%20Market%20Outlook.pdf)
# 3. **Mexico** (32.4%) - Price Upward Trend for More Than a Decade, Having Mexico City As The Most Expensive Location. [Statista](https://www.statista.com/statistics/613690/house-price-changes-in-mexico-by-quarter/)
#
# **Stability Leaders**:
# - Switzerland (13.8%)
# - Brazil (17.6%)
# - India (19.7%)
#
# **Insight**:
# > Markets with >30% average volatility experienced at least one crisis event between 2020-2024.

# %%
# Calculate YoY CHANGES on real house price index
price_shift_table = (
    cleaned_df
    .groupby(['Year', 'Country'])
    ['derived_real_house_price_index']
    .median()
    .groupby(level=1)
    .pct_change()
    .mul(100)
    .abs()
    .unstack(level=0)  # Transpose to get Countries as rows, Years as columns
    # Add 'Average' column and sort
    .assign(Average=lambda df: df.mean(axis=1, skipna=True))
    .sort_values('Average', ascending=False)
    .style
    .format("{:.1f}%")
    .map(
        lambda x: 'background-color: #FFA07A' if x > 60
        else ('background-color : #FFD700' if x > 20
        else 'background-color : #98FB98')
    )
)

display(HTML(price_shift_table.to_html()))
# Out:
# <style type="text/css">
# #T_d92a3_row0_col0, #T_d92a3_row0_col1, #T_d92a3_row0_col4, #T_d92a3_row1_col0, #T_d92a3_row1_col4, #T_d92a3_row1_col8, #T_d92a3_row2_col0, #T_d92a3_row2_col1, #T_d92a3_row2_col2, #T_d92a3_row2_col4, #T_d92a3_row2_col6, #T_d92a3_row2_col9, #T_d92a3_row3_col0, #T_d92a3_row3_col5, #T_d92a3_row3_col6, #T_d92a3_row3_col7, #T_d92a3_row3_col8, #T_d92a3_row3_col9, #T_d92a3_row4_col0, #T_d92a3_row4_col5, #T_d92a3_row4_col6, #T_d92a3_row4_col7, #T_d92a3_row5_col0, #T_d92a3_row5_col1, #T_d92a3_row5_col2, #T_d92a3_row5_col5, #T_d92a3_row6_col0, #T_d92a3_row6_col3, #T_d92a3_row6_col6, #T_d92a3_row6_col7, #T_d92a3_row6_col8, #T_d92a3_row7_col0, #T_d92a3_row7_col2, #T_d92a3_row7_col3, #T_d92a3_row7_col4, #T_d92a3_row7_col6, #T_d92a3_row8_col0, #T_d92a3_row8_col1, #T_d92a3_row8_col3, #T_d92a3_row8_col5, #T_d92a3_row8_col6, #T_d92a3_row8_col8, #T_d92a3_row9_col0, #T_d92a3_row9_col4, #T_d92a3_row9_col6, #T_d92a3_row9_col8, #T_d92a3_row9_col9, #T_d92a3_row10_col0, #T_d92a3_row10_col1, #T_d92a3_row10_col5, #T_d92a3_row10_col6, #T_d92a3_row10_col8, #T_d92a3_row11_col0, #T_d92a3_row11_col1, #T_d92a3_row11_col3, #T_d92a3_row11_col7, #T_d92a3_row11_col9, #T_d92a3_row12_col0, #T_d92a3_row12_col2, #T_d92a3_row12_col7, #T_d92a3_row12_col8, #T_d92a3_row12_col9, #T_d92a3_row13_col0, #T_d92a3_row13_col1, #T_d92a3_row13_col3, #T_d92a3_row13_col5, #T_d92a3_row13_col6, #T_d92a3_row13_col7, #T_d92a3_row13_col9, #T_d92a3_row14_col0, #T_d92a3_row14_col1, #T_d92a3_row14_col2, #T_d92a3_row14_col4, #T_d92a3_row14_col8, #T_d92a3_row15_col0, #T_d92a3_row15_col1, #T_d92a3_row15_col2, #T_d92a3_row15_col3, #T_d92a3_row15_col6, #T_d92a3_row15_col7, #T_d92a3_row15_col8, #T_d92a3_row16_col0, #T_d92a3_row16_col1, #T_d92a3_row16_col3, #T_d92a3_row16_col5, #T_d92a3_row16_col7, #T_d92a3_row16_col9, #T_d92a3_row17_col0, #T_d92a3_row17_col3, #T_d92a3_row17_col4, #T_d92a3_row17_col5, #T_d92a3_row17_col6, #T_d92a3_row17_col8, #T_d92a3_row17_col10, #T_d92a3_row18_col0, #T_d92a3_row18_col2, #T_d92a3_row18_col5, #T_d92a3_row18_col6, #T_d92a3_row18_col7, #T_d92a3_row18_col8, #T_d92a3_row18_col10, #T_d92a3_row19_col0, #T_d92a3_row19_col1, #T_d92a3_row19_col3, #T_d92a3_row19_col4, #T_d92a3_row19_col6, #T_d92a3_row19_col7, #T_d92a3_row19_col9, #T_d92a3_row19_col10 {
#   background-color: #98FB98;
# }
# #T_d92a3_row0_col2, #T_d92a3_row0_col3, #T_d92a3_row0_col6, #T_d92a3_row0_col8, #T_d92a3_row0_col9, #T_d92a3_row0_col10, #T_d92a3_row1_col1, #T_d92a3_row1_col2, #T_d92a3_row1_col3, #T_d92a3_row1_col5, #T_d92a3_row1_col7, #T_d92a3_row1_col9, #T_d92a3_row1_col10, #T_d92a3_row2_col5, #T_d92a3_row2_col7, #T_d92a3_row2_col10, #T_d92a3_row3_col1, #T_d92a3_row3_col3, #T_d92a3_row3_col10, #T_d92a3_row4_col1, #T_d92a3_row4_col2, #T_d92a3_row4_col3, #T_d92a3_row4_col4, #T_d92a3_row4_col8, #T_d92a3_row4_col10, #T_d92a3_row5_col3, #T_d92a3_row5_col4, #T_d92a3_row5_col7, #T_d92a3_row5_col9, #T_d92a3_row5_col10, #T_d92a3_row6_col1, #T_d92a3_row6_col2, #T_d92a3_row6_col4, #T_d92a3_row6_col5, #T_d92a3_row6_col9, #T_d92a3_row6_col10, #T_d92a3_row7_col1, #T_d92a3_row7_col5, #T_d92a3_row7_col7, #T_d92a3_row7_col8, #T_d92a3_row7_col10, #T_d92a3_row8_col2, #T_d92a3_row8_col4, #T_d92a3_row8_col7, #T_d92a3_row8_col10, #T_d92a3_row9_col1, #T_d92a3_row9_col2, #T_d92a3_row9_col3, #T_d92a3_row9_col7, #T_d92a3_row9_col10, #T_d92a3_row10_col2, #T_d92a3_row10_col3, #T_d92a3_row10_col4, #T_d92a3_row10_col7, #T_d92a3_row10_col9, #T_d92a3_row10_col10, #T_d92a3_row11_col2, #T_d92a3_row11_col4, #T_d92a3_row11_col5, #T_d92a3_row11_col6, #T_d92a3_row11_col8, #T_d92a3_row11_col10, #T_d92a3_row12_col1, #T_d92a3_row12_col3, #T_d92a3_row12_col4, #T_d92a3_row12_col5, #T_d92a3_row12_col6, #T_d92a3_row12_col10, #T_d92a3_row13_col4, #T_d92a3_row13_col8, #T_d92a3_row13_col10, #T_d92a3_row14_col3, #T_d92a3_row14_col6, #T_d92a3_row14_col7, #T_d92a3_row14_col9, #T_d92a3_row14_col10, #T_d92a3_row15_col5, #T_d92a3_row15_col9, #T_d92a3_row15_col10, #T_d92a3_row16_col2, #T_d92a3_row16_col4, #T_d92a3_row16_col6, #T_d92a3_row16_col8, #T_d92a3_row16_col10, #T_d92a3_row17_col1, #T_d92a3_row17_col2, #T_d92a3_row17_col7, #T_d92a3_row17_col9, #T_d92a3_row18_col1, #T_d92a3_row18_col3, #T_d92a3_row18_col4, #T_d92a3_row18_col9, #T_d92a3_row19_col2, #T_d92a3_row19_col5, #T_d92a3_row19_col8 {
#   background-color: #FFD700;
# }
# #T_d92a3_row0_col5, #T_d92a3_row0_col7, #T_d92a3_row1_col6, #T_d92a3_row2_col3, #T_d92a3_row2_col8, #T_d92a3_row3_col2, #T_d92a3_row3_col4, #T_d92a3_row4_col9, #T_d92a3_row5_col6, #T_d92a3_row5_col8, #T_d92a3_row7_col9, #T_d92a3_row8_col9, #T_d92a3_row9_col5, #T_d92a3_row13_col2, #T_d92a3_row14_col5, #T_d92a3_row15_col4 {
#   background-color: #FFA07A;
# }
# </style>
# <table id="T_d92a3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th id="T_d92a3_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_d92a3_level0_col1" class="col_heading level0 col1" >2016</th>
#       <th id="T_d92a3_level0_col2" class="col_heading level0 col2" >2017</th>
#       <th id="T_d92a3_level0_col3" class="col_heading level0 col3" >2018</th>
#       <th id="T_d92a3_level0_col4" class="col_heading level0 col4" >2019</th>
#       <th id="T_d92a3_level0_col5" class="col_heading level0 col5" >2020</th>
#       <th id="T_d92a3_level0_col6" class="col_heading level0 col6" >2021</th>
#       <th id="T_d92a3_level0_col7" class="col_heading level0 col7" >2022</th>
#       <th id="T_d92a3_level0_col8" class="col_heading level0 col8" >2023</th>
#       <th id="T_d92a3_level0_col9" class="col_heading level0 col9" >2024</th>
#       <th id="T_d92a3_level0_col10" class="col_heading level0 col10" >Average</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d92a3_level0_row0" class="row_heading level0 row0" >UAE</th>
#       <td id="T_d92a3_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_d92a3_row0_col1" class="data row0 col1" >8.9%</td>
#       <td id="T_d92a3_row0_col2" class="data row0 col2" >51.2%</td>
#       <td id="T_d92a3_row0_col3" class="data row0 col3" >39.2%</td>
#       <td id="T_d92a3_row0_col4" class="data row0 col4" >16.6%</td>
#       <td id="T_d92a3_row0_col5" class="data row0 col5" >95.3%</td>
#       <td id="T_d92a3_row0_col6" class="data row0 col6" >40.0%</td>
#       <td id="T_d92a3_row0_col7" class="data row0 col7" >84.0%</td>
#       <td id="T_d92a3_row0_col8" class="data row0 col8" >29.0%</td>
#       <td id="T_d92a3_row0_col9" class="data row0 col9" >26.2%</td>
#       <td id="T_d92a3_row0_col10" class="data row0 col10" >43.4%</td>
#     </tr>
#     <tr>
#       <th id="T_d92a3_level0_row1" class="row_heading level0 row1" >Sweden</th>
#       <td id="T_d92a3_row1_col0" class="data row1 col0" >nan%</td>
#       <td id="T_d92a3_row1_col1" class="data row1 col1" >20.4%</td>
#       <td id="T_d92a3_row1_col2" class="data row1 col2" >38.6%</td>
#       <td id="T_d92a3_row1_col3" class="data row1 col3" >48.9%</td>
#       <td id="T_d92a3_row1_col4" class="data row1 col4" >18.5%</td>
#       <td id="T_d92a3_row1_col5" class="data row1 col5" >38.8%</td>
#       <td id="T_d92a3_row1_col6" class="data row1 col6" >101.1%</td>
#       <td id="T_d92a3_row1_col7" class="data row1 col7" >48.3%</td>
#       <td id="T_d92a3_row1_col8" class="data row1 col8" >13.6%</td>
#       <td id="T_d92a3_row1_col9" class="data row1 col9" >36.0%</td>
#       <td id="T_d92a3_row1_col10" class="data row1 col10" >40.5%</td>
#     </tr>
#     <tr>
#       <th id="T_d92a3_level0_row2" class="row_heading level0 row2" >Mexico</th>
#       <td id="T_d92a3_row2_col0" class="data r

# %% [markdown]
# ##### ***WHAT IS THE REAL MORTGAGE COST CHANGE PER REGIONAL GROUP OVERTIME?***

# %% [markdown]
# **Key Insights**:
# - **LATAM experienced extreme volatility**, with  swings from -5.17 (2021) to +6.51 (2022) in one year.

# %%
# Create a stored df with year-over-year calculations
owning_renting_analysis = (
    cleaned_df[['Country', 'Year', 'derived_regional_group', 'derived_real_mortgage_cost']]
    .sort_values(['Country', 'Year'])
    .assign(
        real_mortgage_abs_yoy=lambda df: df.groupby('Country')['derived_real_mortgage_cost'].diff(1).round(2)
    )
)

# Create a separated table for tabular display
yoy_table_mortgage = (
    owning_renting_analysis.groupby(['Year','derived_regional_group'])
    ['real_mortgage_abs_yoy']
    .median()
    .unstack()
    .fillna('N/A')
)

# Diaplay yoy changes table
display(HTML(yoy_table_mortgage.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>derived_regional_group</th>
#       <th>APAC</th>
#       <th>EMEA</th>
#       <th>LATAM</th>
#       <th>NA</th>
#     </tr>
#     <tr>
#       <th>Year</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2015</th>
#       <td>N/A</td>
#       <td>N/A</td>
#       <td>N/A</td>
#       <td>N/A</td>
#     </tr>
#     <tr>
#       <th>2016</th>
#       <td>0.13</td>
#       <td>-0.58</td>
#       <td>-0.54</td>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>2017</th>
#       <td>-0.61</td>
#       <td>-1.02</td>
#       <td>1.38</td>
#       <td>-3.74</td>
#     </tr>
#     <tr>
#       <th>2018</th>
#       <td>-2.17</td>
#       <td>-0.32</td>
#       <td>2.86</td>
#       <td>3.29</td>
#     </tr>
#     <tr>
#       <th>2019</th>
#       <td>5.83</td>
#       <td>0.83</td>
#       <td>0.47</td>
#       <td>0.55</td>
#     </tr>
#     <tr>
#       <th>2020</th>
#       <td>-0.61</td>
#       <td>0.39</td>
#       <td>-3.17</td>
#       <td>-2.11</td>
#     </tr>
#     <tr>
#       <th>2021</th>
#       <td>-1.33</td>
#       <td>0.82</td>
#       <td>-5.17</td>
#       <td>2.92</td>
#     </tr>
#     <tr>
#       <th>2022</th>
#       <td>1.38</td>
#       <td>-0.63</td>
#       <td>6.51</td>
#       <td>-4.49</td>
#     </tr>
#     <tr>
#       <th>2023</th>
#       <td>-2.01</td>
#       <td>1.30</td>
#       <td>0.97</td>
#       <td>3.41</td>
#     </tr>
#     <tr>
#       <th>2024</th>
#       <td>-0.97</td>
#       <td>-1.94</td>
#       <td>-0.81</td>
#       <td>0.41</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### ***WHICH YEARS SAW THE LARGEST AFFORDABILITY SHIFTS PER REGIONAL GROUP?***

# %% [markdown]
# **Phase 1: Pre-Pandemic (2015-2019)**
# - **APAC**: Steady erosion (4.78 → 6.86) despite 2017's 69% YoY spike
# - **NA**: Sharp 2020 surge (8.93) erased earlier gains from 2016's peak (10.45)
#
# **Phase 2: Pandemic & Recovery (2020-2024)**
# - **LATAM**: Catastrophic 2024 collapse (3.62) after brief 2020 recovery (9.63)
# - **EMEA**: Remarkable stability (6.47-7.81) despite 2020's 31.7% YoY swing
#
# **Insight**:
# > Clear worldwide Affordability Impact During the pre- and initial stages of COVID-19.

# %%
# Create a table with conditional formatting
afford_table = (
    cleaned_df.groupby((['Year', 'derived_regional_group']))
    ['derived_affordability_gdp_population_score']
    .median()
    .unstack()
    .style
    .format("{:.2f}")
    .map(
        lambda x: 'background-color: #98FB98' if x > 8
        else ('background-color: #FFD700' if x > 5
        else 'background-color: #FFA07A')
    )
    
)

display(HTML(afford_table.to_html()))
# Out:
# <style type="text/css">
# #T_09d6d_row0_col0, #T_09d6d_row2_col0, #T_09d6d_row2_col2, #T_09d6d_row3_col2, #T_09d6d_row8_col0, #T_09d6d_row9_col2, #T_09d6d_row9_col3 {
#   background-color: #FFA07A;
# }
# #T_09d6d_row0_col1, #T_09d6d_row0_col3, #T_09d6d_row1_col3, #T_09d6d_row2_col1, #T_09d6d_row3_col0, #T_09d6d_row4_col1, #T_09d6d_row5_col2, #T_09d6d_row5_col3, #T_09d6d_row6_col0, #T_09d6d_row6_col1, #T_09d6d_row7_col0, #T_09d6d_row8_col2 {
#   background-color: #98FB98;
# }
# #T_09d6d_row0_col2, #T_09d6d_row1_col0, #T_09d6d_row1_col1, #T_09d6d_row1_col2, #T_09d6d_row2_col3, #T_09d6d_row3_col1, #T_09d6d_row3_col3, #T_09d6d_row4_col0, #T_09d6d_row4_col2, #T_09d6d_row4_col3, #T_09d6d_row5_col0, #T_09d6d_row5_col1, #T_09d6d_row6_col2, #T_09d6d_row6_col3, #T_09d6d_row7_col1, #T_09d6d_row7_col2, #T_09d6d_row7_col3, #T_09d6d_row8_col1, #T_09d6d_row8_col3, #T_09d6d_row9_col0, #T_09d6d_row9_col1 {
#   background-color: #FFD700;
# }
# </style>
# <table id="T_09d6d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >derived_regional_group</th>
#       <th id="T_09d6d_level0_col0" class="col_heading level0 col0" >APAC</th>
#       <th id="T_09d6d_level0_col1" class="col_heading level0 col1" >EMEA</th>
#       <th id="T_09d6d_level0_col2" class="col_heading level0 col2" >LATAM</th>
#       <th id="T_09d6d_level0_col3" class="col_heading level0 col3" >NA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09d6d_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_09d6d_row0_col0" class="data row0 col0" >4.78</td>
#       <td id="T_09d6d_row0_col1" class="data row0 col1" >8.37</td>
#       <td id="T_09d6d_row0_col2" class="data row0 col2" >7.00</td>
#       <td id="T_09d6d_row0_col3" class="data row0 col3" >9.77</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_09d6d_row1_col0" class="data row1 col0" >5.72</td>
#       <td id="T_09d6d_row1_col1" class="data row1 col1" >6.47</td>
#       <td id="T_09d6d_row1_col2" class="data row1 col2" >7.00</td>
#       <td id="T_09d6d_row1_col3" class="data row1 col3" >10.45</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_09d6d_row2_col0" class="data row2 col0" >4.95</td>
#       <td id="T_09d6d_row2_col1" class="data row2 col1" >8.15</td>
#       <td id="T_09d6d_row2_col2" class="data row2 col2" >4.29</td>
#       <td id="T_09d6d_row2_col3" class="data row2 col3" >7.16</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_09d6d_row3_col0" class="data row3 col0" >8.38</td>
#       <td id="T_09d6d_row3_col1" class="data row3 col1" >7.74</td>
#       <td id="T_09d6d_row3_col2" class="data row3 col2" >3.75</td>
#       <td id="T_09d6d_row3_col3" class="data row3 col3" >5.62</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row4" class="row_heading level0 row4" >2019</th>
#       <td id="T_09d6d_row4_col0" class="data row4 col0" >5.58</td>
#       <td id="T_09d6d_row4_col1" class="data row4 col1" >9.91</td>
#       <td id="T_09d6d_row4_col2" class="data row4 col2" >5.81</td>
#       <td id="T_09d6d_row4_col3" class="data row4 col3" >6.25</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_09d6d_row5_col0" class="data row5 col0" >7.51</td>
#       <td id="T_09d6d_row5_col1" class="data row5 col1" >6.77</td>
#       <td id="T_09d6d_row5_col2" class="data row5 col2" >9.63</td>
#       <td id="T_09d6d_row5_col3" class="data row5 col3" >8.93</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row6" class="row_heading level0 row6" >2021</th>
#       <td id="T_09d6d_row6_col0" class="data row6 col0" >8.03</td>
#       <td id="T_09d6d_row6_col1" class="data row6 col1" >8.89</td>
#       <td id="T_09d6d_row6_col2" class="data row6 col2" >5.71</td>
#       <td id="T_09d6d_row6_col3" class="data row6 col3" >6.06</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row7" class="row_heading level0 row7" >2022</th>
#       <td id="T_09d6d_row7_col0" class="data row7 col0" >8.37</td>
#       <td id="T_09d6d_row7_col1" class="data row7 col1" >7.19</td>
#       <td id="T_09d6d_row7_col2" class="data row7 col2" >6.45</td>
#       <td id="T_09d6d_row7_col3" class="data row7 col3" >6.34</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row8" class="row_heading level0 row8" >2023</th>
#       <td id="T_09d6d_row8_col0" class="data row8 col0" >3.73</td>
#       <td id="T_09d6d_row8_col1" class="data row8 col1" >6.46</td>
#       <td id="T_09d6d_row8_col2" class="data row8 col2" >8.08</td>
#       <td id="T_09d6d_row8_col3" class="data row8 col3" >6.52</td>
#     </tr>
#     <tr>
#       <th id="T_09d6d_level0_row9" class="row_heading level0 row9" >2024</th>
#       <td id="T_09d6d_row9_col0" class="data row9 col0" >6.86</td>
#       <td id="T_09d6d_row9_col1" class="data row9 col1" >7.81</td>
#       <td id="T_09d6d_row9_col2" class="data row9 col2" >3.62</td>
#       <td id="T_09d6d_row9_col3" class="data row9 col3" >4.43</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Median affordability level per region/year

# %%
# Calculate YoY CHANGES in regional affordability
afford_shift_table = (
    cleaned_df
    .groupby(['Year', 'derived_regional_group'])
    ['derived_affordability_gdp_population_score'].median()
    .groupby(level=1)  # Group by region
    .pct_change()      # YoY % change
    .mul(100)
    .abs()             # Focus on magnitude of change
    .unstack()
    .style
    .format("{:.1f}%")  # Format as percentages
    .map(
        lambda x: 'background-color: #FFA07A' if x > 50
        else ('background-color: #FFD700' if x > 30
        else 'background-color: #98FB98')
    )
)

display(HTML(afford_shift_table.to_html()))
# Out:
# <style type="text/css">
# #T_e807b_row0_col0, #T_e807b_row0_col1, #T_e807b_row0_col2, #T_e807b_row0_col3, #T_e807b_row1_col0, #T_e807b_row1_col1, #T_e807b_row1_col2, #T_e807b_row1_col3, #T_e807b_row2_col0, #T_e807b_row2_col1, #T_e807b_row3_col1, #T_e807b_row3_col2, #T_e807b_row3_col3, #T_e807b_row4_col1, #T_e807b_row4_col3, #T_e807b_row6_col0, #T_e807b_row7_col0, #T_e807b_row7_col1, #T_e807b_row7_col2, #T_e807b_row7_col3, #T_e807b_row8_col1, #T_e807b_row8_col2, #T_e807b_row8_col3, #T_e807b_row9_col1 {
#   background-color: #98FB98;
# }
# #T_e807b_row2_col2, #T_e807b_row2_col3, #T_e807b_row4_col0, #T_e807b_row5_col0, #T_e807b_row5_col1, #T_e807b_row5_col3, #T_e807b_row6_col1, #T_e807b_row6_col2, #T_e807b_row6_col3, #T_e807b_row9_col3 {
#   background-color: #FFD700;
# }
# #T_e807b_row3_col0, #T_e807b_row4_col2, #T_e807b_row5_col2, #T_e807b_row8_col0, #T_e807b_row9_col0, #T_e807b_row9_col2 {
#   background-color: #FFA07A;
# }
# </style>
# <table id="T_e807b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >derived_regional_group</th>
#       <th id="T_e807b_level0_col0" class="col_heading level0 col0" >APAC</th>
#       <th id="T_e807b_level0_col1" class="col_heading level0 col1" >EMEA</th>
#       <th id="T_e807b_level0_col2" class="col_heading level0 col2" >LATAM</th>
#       <th id="T_e807b_level0_col3" class="col_heading level0 col3" >NA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e807b_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_e807b_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_e807b_row0_col1" class="data row0 col1" >nan%</td>
#       <td id="T_e807b_row0_col2" class="data row0 col2" >nan%</td>
#       <td id="T_e807b_row0_col3" class="data row0 col3" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_e807b_row1_col0" class="data row1 col0" >19.5%</td>
#       <td id="T_e807b_row1_col1" class="data row1 col1" >22.7%</td>
#       <td id="T_e807b_row1_col2" class="data row1 col2" >0.1%</td>
#       <td id="T_e807b_row1_col3" class="data row1 col3" >6.9%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_e807b_row2_col0" class="data row2 col0" >13.3%</td>
#       <td id="T_e807b_row2_col1" class="data row2 col1" >25.9%</td>
#       <td id="T_e807b_row2_col2" class="data row2 col2" >38.7%</td>
#       <td id="T_e807b_row2_col3" class="data row2 col3" >31.5%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_e807b_row3_col0" class="data row3 col0" >69.2%</td>
#       <td id="T_e807b_row3_col1" class="data row3 col1" >5.0%</td>
#       <td id="T_e807b_row3_col2" class="data row3 col2" >12.7%</td>
#       <td id="T_e807b_row3_col3" class="data row3 col3" >21.5%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row4" class="row_heading level0 row4" >2019</th>
#       <td id="T_e807b_row4_col0" class="data row4 col0" >33.4%</td>
#       <td id="T_e807b_row4_col1" class="data row4 col1" >28.0%</td>
#       <td id="T_e807b_row4_col2" class="data row4 col2" >55.1%</td>
#       <td id="T_e807b_row4_col3" class="data row4 col3" >11.2%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_e807b_row5_col0" class="data row5 col0" >34.5%</td>
#       <td id="T_e807b_row5_col1" class="data row5 col1" >31.7%</td>
#       <td id="T_e807b_row5_col2" class="data row5 col2" >65.7%</td>
#       <td id="T_e807b_row5_col3" class="data row5 col3" >42.9%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row6" class="row_heading level0 row6" >2021</th>
#       <td id="T_e807b_row6_col0" class="data row6 col0" >6.9%</td>
#       <td id="T_e807b_row6_col1" class="data row6 col1" >31.3%</td>
#       <td id="T_e807b_row6_col2" class="data row6 col2" >40.7%</td>
#       <td id="T_e807b_row6_col3" class="data row6 col3" >32.1%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row7" class="row_heading level0 row7" >2022</th>
#       <td id="T_e807b_row7_col0" class="data row7 col0" >4.3%</td>
#       <td id="T_e807b_row7_col1" class="data row7 col1" >19.2%</td>
#       <td id="T_e807b_row7_col2" class="data row7 col2" >12.9%</td>
#       <td id="T_e807b_row7_col3" class="data row7 col3" >4.6%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row8" class="row_heading level0 row8" >2023</th>
#       <td id="T_e807b_row8_col0" class="data row8 col0" >55.4%</td>
#       <td id="T_e807b_row8_col1" class="data row8 col1" >10.2%</td>
#       <td id="T_e807b_row8_col2" class="data row8 col2" >25.3%</td>
#       <td id="T_e807b_row8_col3" class="data row8 col3" >2.8%</td>
#     </tr>
#     <tr>
#       <th id="T_e807b_level0_row9" class="row_heading level0 row9" >2024</th>
#       <td id="T_e807b_row9_col0" class="data row9 col0" >83.6%</td>
#       <td id="T_e807b_row9_col1" class="data row9 col1" >20.9%</td>
#       <td id="T_e807b_row9_col2" class="data row9 col2" >55.3%</td>
#       <td id="T_e807b_row9_col3" class="data row9 col3" >32.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Largest Affordability Shifts (Absolute YoY % Change)

# %% [markdown]
# ##### ***HOW DOES THE COST OF OWNING VS RENTING EVOLVE ACROSS REGIONAL GROUPS:***
# ##### How Many Years of Rent Equal the House Price?

# %% [markdown]
# **Key Regional Patterns**:
# - **LATAM's Affordability Collapse**: Buying a home went from 5.3 years of rent (2015) to 11.7 years (2024)—a **122% deterioration**. This signals severe ownership accessibility issues.
# - **APAC's Swings**: Extreme volatility (3.31 years in 2019 → 10.0 years in 2015) reflects policy experimentation and speculative bubbles.
# - **NA's Stability Advantage**: Maintained the healthiest balance (4.5-6.7 years), though 2016's spike (11.0 years) revealed mortgage-rate sensitivity.
#
# **Critical Threshold Breaches**:
# > "When ownership costs exceed 8 years of rent (red), renting becomes economically rational. LATAM breached this in 2019/2024, APAC in 2015/2020/2022, and EMEA in 2022."

# %%
# Create a pivot table with conditional formatting
spread_table = (
    cleaned_df.groupby(['Year', 'derived_regional_group'])
    ['derived_ownership_rent_spread']
    .median()
    .unstack()
    .style
    .format("{:.2f}")
    .map(
        lambda x: 'background-color: #FFA07A' if x > 8
        else ('background-color: #FFD700' if x > 5 
        else 'background-color: #98FB98')
    )
)

display(HTML(spread_table.to_html()))
# Out:
# <style type="text/css">
# #T_b7313_row0_col0, #T_b7313_row0_col1, #T_b7313_row1_col2, #T_b7313_row1_col3, #T_b7313_row4_col2, #T_b7313_row5_col0, #T_b7313_row7_col0, #T_b7313_row7_col1, #T_b7313_row8_col0, #T_b7313_row8_col2, #T_b7313_row9_col2 {
#   background-color: #FFA07A;
# }
# #T_b7313_row0_col2, #T_b7313_row1_col0, #T_b7313_row1_col1, #T_b7313_row2_col0, #T_b7313_row2_col1, #T_b7313_row2_col2, #T_b7313_row3_col2, #T_b7313_row3_col3, #T_b7313_row4_col1, #T_b7313_row4_col3, #T_b7313_row5_col1, #T_b7313_row5_col2, #T_b7313_row5_col3, #T_b7313_row6_col0, #T_b7313_row6_col1, #T_b7313_row6_col3, #T_b7313_row7_col2, #T_b7313_row8_col1, #T_b7313_row8_col3, #T_b7313_row9_col0, #T_b7313_row9_col1, #T_b7313_row9_col3 {
#   background-color: #FFD700;
# }
# #T_b7313_row0_col3, #T_b7313_row2_col3, #T_b7313_row3_col0, #T_b7313_row3_col1, #T_b7313_row4_col0, #T_b7313_row6_col2, #T_b7313_row7_col3 {
#   background-color: #98FB98;
# }
# </style>
# <table id="T_b7313">
#   <thead>
#     <tr>
#       <th class="index_name level0" >derived_regional_group</th>
#       <th id="T_b7313_level0_col0" class="col_heading level0 col0" >APAC</th>
#       <th id="T_b7313_level0_col1" class="col_heading level0 col1" >EMEA</th>
#       <th id="T_b7313_level0_col2" class="col_heading level0 col2" >LATAM</th>
#       <th id="T_b7313_level0_col3" class="col_heading level0 col3" >NA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7313_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_b7313_row0_col0" class="data row0 col0" >10.02</td>
#       <td id="T_b7313_row0_col1" class="data row0 col1" >9.22</td>
#       <td id="T_b7313_row0_col2" class="data row0 col2" >5.28</td>
#       <td id="T_b7313_row0_col3" class="data row0 col3" >4.25</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_b7313_row1_col0" class="data row1 col0" >5.86</td>
#       <td id="T_b7313_row1_col1" class="data row1 col1" >5.86</td>
#       <td id="T_b7313_row1_col2" class="data row1 col2" >8.47</td>
#       <td id="T_b7313_row1_col3" class="data row1 col3" >10.97</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_b7313_row2_col0" class="data row2 col0" >7.84</td>
#       <td id="T_b7313_row2_col1" class="data row2 col1" >5.03</td>
#       <td id="T_b7313_row2_col2" class="data row2 col2" >6.45</td>
#       <td id="T_b7313_row2_col3" class="data row2 col3" >4.06</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_b7313_row3_col0" class="data row3 col0" >3.12</td>
#       <td id="T_b7313_row3_col1" class="data row3 col1" >4.72</td>
#       <td id="T_b7313_row3_col2" class="data row3 col2" >7.56</td>
#       <td id="T_b7313_row3_col3" class="data row3 col3" >5.69</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row4" class="row_heading level0 row4" >2019</th>
#       <td id="T_b7313_row4_col0" class="data row4 col0" >3.31</td>
#       <td id="T_b7313_row4_col1" class="data row4 col1" >7.09</td>
#       <td id="T_b7313_row4_col2" class="data row4 col2" >10.22</td>
#       <td id="T_b7313_row4_col3" class="data row4 col3" >6.57</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_b7313_row5_col0" class="data row5 col0" >8.10</td>
#       <td id="T_b7313_row5_col1" class="data row5 col1" >5.32</td>
#       <td id="T_b7313_row5_col2" class="data row5 col2" >6.22</td>
#       <td id="T_b7313_row5_col3" class="data row5 col3" >6.47</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row6" class="row_heading level0 row6" >2021</th>
#       <td id="T_b7313_row6_col0" class="data row6 col0" >5.64</td>
#       <td id="T_b7313_row6_col1" class="data row6 col1" >6.80</td>
#       <td id="T_b7313_row6_col2" class="data row6 col2" >3.32</td>
#       <td id="T_b7313_row6_col3" class="data row6 col3" >5.65</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row7" class="row_heading level0 row7" >2022</th>
#       <td id="T_b7313_row7_col0" class="data row7 col0" >8.63</td>
#       <td id="T_b7313_row7_col1" class="data row7 col1" >8.25</td>
#       <td id="T_b7313_row7_col2" class="data row7 col2" >6.09</td>
#       <td id="T_b7313_row7_col3" class="data row7 col3" >4.46</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row8" class="row_heading level0 row8" >2023</th>
#       <td id="T_b7313_row8_col0" class="data row8 col0" >8.08</td>
#       <td id="T_b7313_row8_col1" class="data row8 col1" >6.24</td>
#       <td id="T_b7313_row8_col2" class="data row8 col2" >8.47</td>
#       <td id="T_b7313_row8_col3" class="data row8 col3" >6.58</td>
#     </tr>
#     <tr>
#       <th id="T_b7313_level0_row9" class="row_heading level0 row9" >2024</th>
#       <td id="T_b7313_row9_col0" class="data row9 col0" >5.45</td>
#       <td id="T_b7313_row9_col1" class="data row9 col1" >6.10</td>
#       <td id="T_b7313_row9_col2" class="data row9 col2" >11.71</td>
#       <td id="T_b7313_row9_col3" class="data row9 col3" >5.22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### ***WHAT IS THE COST PER UNIT OF URBANIZATION PER REGION? AND HOW DOES IT CHANGE OVER TIME?***
#
# Unit: USD per 1% of urbanization

# %% [markdown]
# **Decade-Long Trends**:
# - **APAC**: Maintained lowest costs (avg 150 USD/%) but paid stability premium—2020's 57% YoY spike reflected supply chain disruptions.
# - **LATAM's Lost Opportunity**: Despite 2017-2019 improvements, 2024's 203 USD/% represents **failed urbanization value capture**.

# %%
# Create a table with conditional formatting
urban_efficiency = (
    cleaned_df.groupby((['Year','derived_regional_group']))
    ['derived_construction_urbanization_ratio']
    .median()
    .unstack()
    .style
    .format("{:.2f}")
    .map (
        lambda x: 'background-color: #FFA07A' if x > 150
        else ('background-color: #FFD700' if x > 120
        else 'background-color: #98FB98')
    )
)

display(HTML(urban_efficiency.to_html()))
# Out:
# <style type="text/css">
# #T_62c9e_row0_col0, #T_62c9e_row0_col1, #T_62c9e_row1_col2, #T_62c9e_row2_col1, #T_62c9e_row2_col2, #T_62c9e_row2_col3, #T_62c9e_row3_col0, #T_62c9e_row3_col2, #T_62c9e_row4_col2, #T_62c9e_row5_col1, #T_62c9e_row5_col3, #T_62c9e_row6_col1, #T_62c9e_row7_col3, #T_62c9e_row8_col1, #T_62c9e_row9_col1 {
#   background-color: #FFD700;
# }
# #T_62c9e_row0_col2, #T_62c9e_row1_col0, #T_62c9e_row1_col1, #T_62c9e_row1_col3, #T_62c9e_row2_col0, #T_62c9e_row3_col1, #T_62c9e_row3_col3, #T_62c9e_row4_col1, #T_62c9e_row4_col3, #T_62c9e_row5_col0, #T_62c9e_row5_col2, #T_62c9e_row6_col0, #T_62c9e_row6_col2, #T_62c9e_row6_col3, #T_62c9e_row7_col0, #T_62c9e_row7_col1, #T_62c9e_row7_col2, #T_62c9e_row8_col0, #T_62c9e_row8_col2, #T_62c9e_row8_col3, #T_62c9e_row9_col0, #T_62c9e_row9_col2 {
#   background-color: #FFA07A;
# }
# #T_62c9e_row0_col3, #T_62c9e_row4_col0, #T_62c9e_row9_col3 {
#   background-color: #98FB98;
# }
# </style>
# <table id="T_62c9e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >derived_regional_group</th>
#       <th id="T_62c9e_level0_col0" class="col_heading level0 col0" >APAC</th>
#       <th id="T_62c9e_level0_col1" class="col_heading level0 col1" >EMEA</th>
#       <th id="T_62c9e_level0_col2" class="col_heading level0 col2" >LATAM</th>
#       <th id="T_62c9e_level0_col3" class="col_heading level0 col3" >NA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62c9e_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_62c9e_row0_col0" class="data row0 col0" >129.18</td>
#       <td id="T_62c9e_row0_col1" class="data row0 col1" >139.27</td>
#       <td id="T_62c9e_row0_col2" class="data row0 col2" >217.42</td>
#       <td id="T_62c9e_row0_col3" class="data row0 col3" >118.12</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_62c9e_row1_col0" class="data row1 col0" >159.79</td>
#       <td id="T_62c9e_row1_col1" class="data row1 col1" >153.83</td>
#       <td id="T_62c9e_row1_col2" class="data row1 col2" >132.16</td>
#       <td id="T_62c9e_row1_col3" class="data row1 col3" >171.19</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_62c9e_row2_col0" class="data row2 col0" >150.80</td>
#       <td id="T_62c9e_row2_col1" class="data row2 col1" >122.64</td>
#       <td id="T_62c9e_row2_col2" class="data row2 col2" >133.94</td>
#       <td id="T_62c9e_row2_col3" class="data row2 col3" >129.39</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_62c9e_row3_col0" class="data row3 col0" >149.65</td>
#       <td id="T_62c9e_row3_col1" class="data row3 col1" >169.98</td>
#       <td id="T_62c9e_row3_col2" class="data row3 col2" >149.26</td>
#       <td id="T_62c9e_row3_col3" class="data row3 col3" >153.61</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row4" class="row_heading level0 row4" >2019</th>
#       <td id="T_62c9e_row4_col0" class="data row4 col0" >101.91</td>
#       <td id="T_62c9e_row4_col1" class="data row4 col1" >159.49</td>
#       <td id="T_62c9e_row4_col2" class="data row4 col2" >134.69</td>
#       <td id="T_62c9e_row4_col3" class="data row4 col3" >155.65</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_62c9e_row5_col0" class="data row5 col0" >159.47</td>
#       <td id="T_62c9e_row5_col1" class="data row5 col1" >149.19</td>
#       <td id="T_62c9e_row5_col2" class="data row5 col2" >186.00</td>
#       <td id="T_62c9e_row5_col3" class="data row5 col3" >143.06</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row6" class="row_heading level0 row6" >2021</th>
#       <td id="T_62c9e_row6_col0" class="data row6 col0" >152.01</td>
#       <td id="T_62c9e_row6_col1" class="data row6 col1" >135.86</td>
#       <td id="T_62c9e_row6_col2" class="data row6 col2" >160.70</td>
#       <td id="T_62c9e_row6_col3" class="data row6 col3" >160.73</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row7" class="row_heading level0 row7" >2022</th>
#       <td id="T_62c9e_row7_col0" class="data row7 col0" >180.96</td>
#       <td id="T_62c9e_row7_col1" class="data row7 col1" >159.14</td>
#       <td id="T_62c9e_row7_col2" class="data row7 col2" >163.02</td>
#       <td id="T_62c9e_row7_col3" class="data row7 col3" >136.52</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row8" class="row_heading level0 row8" >2023</th>
#       <td id="T_62c9e_row8_col0" class="data row8 col0" >162.62</td>
#       <td id="T_62c9e_row8_col1" class="data row8 col1" >139.96</td>
#       <td id="T_62c9e_row8_col2" class="data row8 col2" >153.46</td>
#       <td id="T_62c9e_row8_col3" class="data row8 col3" >189.43</td>
#     </tr>
#     <tr>
#       <th id="T_62c9e_level0_row9" class="row_heading level0 row9" >2024</th>
#       <td id="T_62c9e_row9_col0" class="data row9 col0" >154.45</td>
#       <td id="T_62c9e_row9_col1" class="data row9 col1" >132.07</td>
#       <td id="T_62c9e_row9_col2" class="data row9 col2" >203.80</td>
#       <td id="T_62c9e_row9_col3" class="data row9 col3" >108.19</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Largest cost changes (Absolute YoY % Change)

# %%
# Calculate YoY CHANGES in regional urbanization cost
urban_shift_table = (
    cleaned_df
    .groupby(['Year', 'derived_regional_group'])
    ['derived_construction_urbanization_ratio']
    .median()
    .groupby(level=1)
    .pct_change()
    .mul(100)
    .abs()
    .unstack()
    .style
    .format("{:.1f}%")
    .map(
        lambda x: 'background-color: #FFA07A' if x > 30
        else ( 'background-color: #FFD700' if x > 15 
        else 'background-color: #98FB98')
    )
)

display(HTML(urban_shift_table.to_html()))
# Out:
# <style type="text/css">
# #T_a3628_row0_col0, #T_a3628_row0_col1, #T_a3628_row0_col2, #T_a3628_row0_col3, #T_a3628_row1_col1, #T_a3628_row2_col0, #T_a3628_row2_col2, #T_a3628_row3_col0, #T_a3628_row3_col2, #T_a3628_row4_col1, #T_a3628_row4_col2, #T_a3628_row4_col3, #T_a3628_row5_col1, #T_a3628_row5_col3, #T_a3628_row6_col0, #T_a3628_row6_col1, #T_a3628_row6_col2, #T_a3628_row6_col3, #T_a3628_row7_col2, #T_a3628_row8_col0, #T_a3628_row8_col1, #T_a3628_row8_col2, #T_a3628_row9_col0, #T_a3628_row9_col1 {
#   background-color: #98FB98;
# }
# #T_a3628_row1_col0, #T_a3628_row2_col1, #T_a3628_row2_col3, #T_a3628_row3_col3, #T_a3628_row7_col0, #T_a3628_row7_col1, #T_a3628_row7_col3 {
#   background-color: #FFD700;
# }
# #T_a3628_row1_col2, #T_a3628_row1_col3, #T_a3628_row3_col1, #T_a3628_row4_col0, #T_a3628_row5_col0, #T_a3628_row5_col2, #T_a3628_row8_col3, #T_a3628_row9_col2, #T_a3628_row9_col3 {
#   background-color: #FFA07A;
# }
# </style>
# <table id="T_a3628">
#   <thead>
#     <tr>
#       <th class="index_name level0" >derived_regional_group</th>
#       <th id="T_a3628_level0_col0" class="col_heading level0 col0" >APAC</th>
#       <th id="T_a3628_level0_col1" class="col_heading level0 col1" >EMEA</th>
#       <th id="T_a3628_level0_col2" class="col_heading level0 col2" >LATAM</th>
#       <th id="T_a3628_level0_col3" class="col_heading level0 col3" >NA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3628_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_a3628_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_a3628_row0_col1" class="data row0 col1" >nan%</td>
#       <td id="T_a3628_row0_col2" class="data row0 col2" >nan%</td>
#       <td id="T_a3628_row0_col3" class="data row0 col3" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_a3628_row1_col0" class="data row1 col0" >23.7%</td>
#       <td id="T_a3628_row1_col1" class="data row1 col1" >10.5%</td>
#       <td id="T_a3628_row1_col2" class="data row1 col2" >39.2%</td>
#       <td id="T_a3628_row1_col3" class="data row1 col3" >44.9%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_a3628_row2_col0" class="data row2 col0" >5.6%</td>
#       <td id="T_a3628_row2_col1" class="data row2 col1" >20.3%</td>
#       <td id="T_a3628_row2_col2" class="data row2 col2" >1.4%</td>
#       <td id="T_a3628_row2_col3" class="data row2 col3" >24.4%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_a3628_row3_col0" class="data row3 col0" >0.8%</td>
#       <td id="T_a3628_row3_col1" class="data row3 col1" >38.6%</td>
#       <td id="T_a3628_row3_col2" class="data row3 col2" >11.4%</td>
#       <td id="T_a3628_row3_col3" class="data row3 col3" >18.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row4" class="row_heading level0 row4" >2019</th>
#       <td id="T_a3628_row4_col0" class="data row4 col0" >31.9%</td>
#       <td id="T_a3628_row4_col1" class="data row4 col1" >6.2%</td>
#       <td id="T_a3628_row4_col2" class="data row4 col2" >9.8%</td>
#       <td id="T_a3628_row4_col3" class="data row4 col3" >1.3%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_a3628_row5_col0" class="data row5 col0" >56.5%</td>
#       <td id="T_a3628_row5_col1" class="data row5 col1" >6.5%</td>
#       <td id="T_a3628_row5_col2" class="data row5 col2" >38.1%</td>
#       <td id="T_a3628_row5_col3" class="data row5 col3" >8.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row6" class="row_heading level0 row6" >2021</th>
#       <td id="T_a3628_row6_col0" class="data row6 col0" >4.7%</td>
#       <td id="T_a3628_row6_col1" class="data row6 col1" >8.9%</td>
#       <td id="T_a3628_row6_col2" class="data row6 col2" >13.6%</td>
#       <td id="T_a3628_row6_col3" class="data row6 col3" >12.4%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row7" class="row_heading level0 row7" >2022</th>
#       <td id="T_a3628_row7_col0" class="data row7 col0" >19.0%</td>
#       <td id="T_a3628_row7_col1" class="data row7 col1" >17.1%</td>
#       <td id="T_a3628_row7_col2" class="data row7 col2" >1.4%</td>
#       <td id="T_a3628_row7_col3" class="data row7 col3" >15.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row8" class="row_heading level0 row8" >2023</th>
#       <td id="T_a3628_row8_col0" class="data row8 col0" >10.1%</td>
#       <td id="T_a3628_row8_col1" class="data row8 col1" >12.1%</td>
#       <td id="T_a3628_row8_col2" class="data row8 col2" >5.9%</td>
#       <td id="T_a3628_row8_col3" class="data row8 col3" >38.8%</td>
#     </tr>
#     <tr>
#       <th id="T_a3628_level0_row9" class="row_heading level0 row9" >2024</th>
#       <td id="T_a3628_row9_col0" class="data row9 col0" >5.0%</td>
#       <td id="T_a3628_row9_col1" class="data row9 col1" >5.6%</td>
#       <td id="T_a3628_row9_col2" class="data row9 col2" >32.8%</td>
#       <td id="T_a3628_row9_col3" class="data row9 col3" >42.9%</td>
#     </tr>
#   </tbody>
# </table>
