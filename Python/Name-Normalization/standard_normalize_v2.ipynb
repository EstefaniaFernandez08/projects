# %%
import pandas as pd
from IPython.display import display, HTML

# We define the CSS that will make the table scrollable
# Definimos el CSS que hará que la tabla sea desplazable
css = """
.output {
    max-height: 500px; /* Adjust this to your needs / Ajusta esto a tus necesidades */
    overflow: scroll;  /* Allows scrolling / Permite desplazamiento */
}
"""
# We apply the CSS
# Aplicamos el CSS
HTML('<style>{}</style>'.format(css))
# Out:
# <style>
# .output {
#     max-height: 500px; /* Adjust this to your needs / Ajusta esto a tus necesidades */
#     overflow: scroll;  /* Allows scrolling / Permite desplazamiento */
# }
# </style>

# %%
# Set the maximum number of rows to display
# Configuramos el máximo número de filas para mostrar
pd.set_option('display.max_rows', None)  # or a specific number of rows / o un número específico de filas

# Set the maximum number of columns to display
# Configuramos el máximo número de columnas para mostrar
pd.set_option('display.max_columns', None)  # or a specific number of columns / o un número específico de columnas

# Configure to wrap text for very long values
# Configuramos para que ajuste el texto a los valores muy largos
pd.set_option('display.max_colwidth', 90)

# Configurar pandas para mejorar la visualización de números: separador de miles
pd.options.display.float_format = '{:,.2f}'.format

# %%
import pandas as pd

dtype = {
    'ACCOUNT_CDE': 'str',  
    'ASSETID':'str',
    'BUSINESS_UNIT':'str',
    'BUSINESS_UNIT_CDE': 'str', 
    'BUYER_ID': 'str', 
    'COMPANY_CDE': 'str',
    'COST_CENTER': 'str', 
    'COST_CENTER_DESC': 'str',
    'EXPENSE_REPORT_NAME': 'str',
    'FILE_NAME': 'str',
    'FISCAL_MONTH': 'str',
    'FISCAL_QUARTER': 'str',
    'FISCAL_YEAR': 'str',
    'INVOICE_COMMENT': 'str',
    'INVOICE_PMT_TERMS': 'str',
    'INVOICE_LINE_DESC': 'str',
    'INVOICE_LINE_NBR': 'str', 
    'INVOICE_LINE_QTY': 'str', 
    'INVOICE_LINE_UNIT_PRICE': 'str', 
    'INVOICE_NBR': 'str', 
    'INVOICE_PMT_TERMS_CDE': 'str', 
    'LEGAL_ENTITY_CDE': 'str',
    'LOCATION': 'str', 
    'LOCATION_ID': 'str',
    'PAYMENT_TYPE': 'str',
    'PO_LINE_DESC': 'str',
    'PO_LINE_ITEM_ID': 'str', 
    'PO_LINE_NBR': 'str', 
    'PO_LINE_QTY': 'str', 
    'PO_NBR': 'str', 
    'PROJECT_NAME':'str',
    'PROJECT_DESCRIPTION': 'str',
    'SUPPLIER_ADDRESS_1': 'str',
    'SUPPLIER_GRP': 'str',
    'SUPPLIER_ERP': 'str',
    'SUPPLIER_NBR': 'str',
    'SUPPLIER_NORMALIZED': 'str',
    'SUPPLIER_PMT_TERM_CDE': 'str',
    'SUPPLIER_STATE': 'str',
    'SUPPLIER_TAXID': 'str',
    'SUPPLIER_ZIP_POSTAL_CDE':'str',
    'DAYS_ATF_PO': 'str', 
    'INVOICE_LINE_AMOUNT': 'float',
    'EXCHANGE_RATE': 'float',
    'TOTAL_SPEND_USD': 'float',
    'TOTAL_SPEND':'float',
}

df = pd.read_csv('TBC_OUTPUT_CONCUR_FY23_MAR v.2.csv', encoding='UTF-8-SIG', encoding_errors='ignore', dtype=dtype)

df_shape = df.shape
print("DataFrame shape:", df_shape)

# Count of non-null values in 'SUPPLIER_NORMALIZED'
nonnull_count = df['SUPPLIER_NORMALIZED'].notna().sum()

print(f"Non-null values supplier normalized: {nonnull_count}")
# Out:
# DataFrame shape: (4002, 90)
# Non-null values supplier normalized: 0

# %%
df = pd.read_csv('TBC_OUTPUT_CONCUR_FY23_MAR v.2.csv',
                 encoding='UTF-8-SIG',
                 encoding_errors='ignore',
                 usecols=['ASSETID', 'SUPPLIER_ERP', 'TOTAL_SPEND_USD']
                 )

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4002 entries, 0 to 4001
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ASSETID          4002 non-null   object
#  1   SUPPLIER_ERP     3875 non-null   object
#  2   TOTAL_SPEND_USD  4002 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 93.9+ KB

# %%
#df.rename(columns={'Supplier - Normalized': 'SUPPLIER_NORMALIZED'}, inplace=True)
df.rename(columns={'TOTAL_SPEND_USD': 'TOTAL_SPEND'}, inplace=True)

# %%
# Suponiendo que TOTAL_SPEND podría tener espacios o caracteres no numéricos por error
# df['TOTAL_SPEND'] = df['TOTAL_SPEND'].replace(r'[^\d.]', '', regex=True).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4002 entries, 0 to 4001
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ASSETID       4002 non-null   object
#  1   SUPPLIER_ERP  3875 non-null   object
#  2   TOTAL_SPEND   4002 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 93.9+ KB

# %% [markdown]
# # Exploration

# %%
# Crearemos un diccionario para almacenar los conteos de valores únicos de cada columna
conteos_unicos = {}

# Iteramos sobre cada columna en el DataFrame
for columna in df.columns:
    # Contamos los valores únicos en cada columna y los almacenamos en el diccionario
    conteos_unicos[columna] = df[columna].nunique()

# Mostramos el resultado
print(conteos_unicos)
# Out:
# {'ASSETID': 4002, 'SUPPLIER_ERP': 2168, 'TOTAL_SPEND': 2910}

# %%
import plotly.graph_objects as go
import plotly.express as px

# Reemplazar valores nulos en 'SUPPLIER_ERP' por 'Unknown' directamente en el DataFrame
df['SUPPLIER_ERP'] = df['SUPPLIER_ERP'].fillna('UNKNOWN')

# Agrupar el dataframe por 'SUPPLIER_ERP' y sumar 'TOTAL_SPEND'
df_grouped = df.groupby('SUPPLIER_ERP', as_index=False)['TOTAL_SPEND'].sum()

# Ordenar los valores sumados en orden descendente para obtener los proveedores con mayores gastos
df_grouped_sorted = df_grouped.sort_values(by='TOTAL_SPEND', ascending=False).head(40)

# Crear una escala de colores basada en los valores de 'TOTAL_SPEND'
color_scale = px.colors.sequential.Viridis

# Mapear el valor de 'TOTAL_SPEND' a la escala de colores
df_grouped_sorted['color'] = df_grouped_sorted['TOTAL_SPEND'].apply(lambda x: color_scale[int(((x - df_grouped_sorted['TOTAL_SPEND'].min()) / (df_grouped_sorted['TOTAL_SPEND'].max() - df_grouped_sorted['TOTAL_SPEND'].min())) * (len(color_scale) - 1))])

# Crear el gráfico de barras
fig = go.Figure(data=[go.Bar(
    x=df_grouped_sorted['SUPPLIER_ERP'],  # Nombres de los proveedores
    y=df_grouped_sorted['TOTAL_SPEND'],  # Gasto total sumado
    marker=dict(color=df_grouped_sorted['color']),  # Usar la escala de colores mapeada
    textposition='outside'
)])

# Actualizar el layout para añadir título y ajustar el eje Y
fig.update_layout(
    title_text='Top 40 Suppliers by Total Spend Aggregated',  # Título del gráfico
    xaxis_tickangle=-45,
    xaxis_title='Supplier',
    yaxis=dict(
        title='Total Spend ($)',
        tickprefix="$",
        tickformat=',.2f',
    ),
    template='plotly_white',
    autosize=True
)

# Ajustar el formato del texto para mostrar valores monetarios correctamente
fig.update_traces(texttemplate='%{text:$,.2f}')

# Mostrar el gráfico
fig.show()

# %%
import plotly.express as px

df['SUPPLIER_ERP_WONULL'] = df['SUPPLIER_ERP'].fillna('UNKNOWN')

# Contar las ocurrencias de cada valor en 'SUPPLIER_NORMALIZED'
value_counts = df['SUPPLIER_ERP_WONULL'].value_counts()

# Convertir el conteo en un DataFrame para visualización
counts_df = pd.DataFrame(value_counts).reset_index()
counts_df.columns = ['Supplier', 'Frequency']

# Crear un gráfico de barras con Plotly Express
fig = px.bar(counts_df.head(40), x='Supplier', y='Frequency',
             title="Top 40 Suppliers by Ocurrency",
             labels={'Supplier': 'Supplier Name', 'Frequency': 'Ocurrency'},
             color='Frequency',  # Color por frecuencia para una visualización más rica
             height=400)  # Ajustar la altura según necesidades

# Mostrar el gráfico
fig.show()

# %%
import plotly.graph_objects as go
from collections import Counter

# Asumiendo que 'df' es tu DataFrame y ya está cargado
# Contar las ocurrencias de cada palabra en la columna 'SUPPLIER_NORMALIZED'
word_counts = Counter(" ".join(df['SUPPLIER_ERP_WONULL']).split())

# Convertir el contador en un DataFrame
words_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Frequency'])
words_df = words_df.sort_values(by='Frequency', ascending=False).head(200)

# Crear una tabla interactiva con Plotly Graph Objects
fig = go.Figure(data=[go.Table(
    header=dict(values=['Word', 'Frequency'],
                fill_color='paleturquoise',
                align='left',
                font=dict(size=14)),
    cells=dict(values=[words_df['Word'], words_df['Frequency']],
               fill_color='lavender',
               align='left'))
])

# Ajustar los márgenes de la figura y añadir un título
fig.update_layout(
    title_text="Most Frequent Words in Supplier Normalized",  # Título de la tabla
    title_x=0.5,  # Centrar el título
    title_font=dict(size=20),
    margin=dict(l=0, r=0, t=50, b=0),  # Ajustar márgenes para acomodar el título
    autosize=True
)

# Mostrar la figura
fig.show()

# %% [markdown]
# ### Diccionario

# %%
# Agrupar el dataframe por 'SUPPLIER_NORMALIZED' y sumar 'TOTAL_SPEND'
df_grouped = df.groupby('SUPPLIER_ERP', as_index=False)['TOTAL_SPEND'].sum()

# Calcular el gasto total en todo el dataset
total_spend_all = df_grouped['TOTAL_SPEND'].sum()

# Lista de números de proveedores top para los cuales calcular el porcentaje
top_counts = [25, 50, 100, 200, 300, 500]

# Imprimir el porcentaje del total spend que cada grupo de proveedores top abarca
for count in top_counts:
    # Ordenar los valores sumados en orden descendente para obtener los proveedores con mayores gastos
    df_top = df_grouped.sort_values(by='TOTAL_SPEND', ascending=False).head(count)
    # Calcular el gasto total de los proveedores top seleccionados
    total_spend_top = df_top['TOTAL_SPEND'].sum()
    # Calcular el porcentaje del total que representa
    percentage_top = (total_spend_top / total_spend_all) * 100
    # Imprimir la información
    print(f"Seleccionando los {count} primeros proveedores, estos incluyen el {percentage_top:.2f}% del total spend en el dataset.")
# Out:
# Seleccionando los 25 primeros proveedores, estos incluyen el 47.99% del total spend en el dataset.
# Seleccionando los 50 primeros proveedores, estos incluyen el 58.19% del total spend en el dataset.
# Seleccionando los 100 primeros proveedores, estos incluyen el 67.88% del total spend en el dataset.
# Seleccionando los 200 primeros proveedores, estos incluyen el 77.63% del total spend en el dataset.
# Seleccionando los 300 primeros proveedores, estos incluyen el 82.63% del total spend en el dataset.
# Seleccionando los 500 primeros proveedores, estos incluyen el 88.69% del total spend en el dataset.

# %%
# Extraemos el top whatever u want to provedores en terminos de total_spend para convertirlos en un diccionario OJO, REVISE QUE NO CAUSE ERRORES UN NOMBRE MUY CORTO, EJ: UBER, DELTA

# Reemplazar valores nulos en 'SUPPLIER_NORMALIZED' por 'Unknown'
# df['SUPPLIER_NORMALIZED'] = df['SUPPLIER_NORMALIZED'].fillna('Unknown') # no es necesario porque ya se corrio generando el grafico de total_spend por supplier

# Agrupar el dataframe por 'SUPPLIER_NORMALIZED' y sumar 'TOTAL_SPEND'
df_grouped = df.groupby('SUPPLIER_NORMALIZED', as_index=False)['TOTAL_SPEND'].sum()

# Ordenar los valores sumados en orden descendente para obtener los proveedores con mayores gastos
df_top = df_grouped.sort_values(by='TOTAL_SPEND', ascending=False).head(25) # AQUI selecciona el numero de proveedores que quieras usar para crear el diccionario

# Hacer una copia de la columna 'SUPPLIER_NORMALIZED'
df_top['if'] = df_top['SUPPLIER_NORMALIZED']

# Renombrar la columna original 'SUPPLIER_NORMALIZED' a 'then'
df_top.rename(columns={'SUPPLIER_NORMALIZED': 'then'}, inplace=True)

# Seleccionar solo las columnas renombradas para simplificar el DataFrame
df_dict = df_top[['if', 'then']]

df_dict
# Out:
#                        if                then
# 4804        HILTON HOTELS       HILTON HOTELS
# 3009       DELTA AIRLINES      DELTA AIRLINES
# 583     AMERICAN AIRLINES   AMERICAN AIRLINES
# 4637         HAMPTON INNS        HAMPTON INNS
# 9295   SOUTHWEST AIRLINES  SOUTHWEST AIRLINES
# 4757                HERTZ               HERTZ
# 3233    DOUBLETREE HOTELS   DOUBLETREE HOTELS
# 8321       RESIDENCE INNS      RESIDENCE INNS
# 7109                 NULL                NULL
# 6391      MARRIOTT HOTELS     MARRIOTT HOTELS
# 10580     UNITED AIRLINES     UNITED AIRLINES
# 4868      HOMES TO SUITES     HOMES TO SUITES
# 3514       EMBASSY SUITES      EMBASSY SUITES
# 2573           COURTYARDS          COURTYARDS
# 4845          HOLIDAY INN         HOLIDAY INN
# 10552                UBER                UBER
# 5065         HYATT HOTELS        HYATT HOTELS
# 10359             TOOJAYS             TOOJAYS
# 2060          CHICK FIL A         CHICK FIL A
# 5155                 IMDA                IMDA
# 4873      HOMEWOOD SUITES     HOMEWOOD SUITES
# 444            AIR CANADA          AIR CANADA
# 7161     OFFICE DEPOT INC    OFFICE DEPOT INC
# 3714       FAIRFIELD INNS      FAIRFIELD INNS
# 10778             WALMART             WALMART

# %%
df_dict.to_excel(r'tbc_suppliers_dictionary_vv1_050624.xlsx', index=False)

# %%
# Carga el archivo Excel en un DataFrame
df_patterns = pd.read_excel(r'tbc_suppliers_dictionary_vv1_050624.xlsx')
df_patterns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   if contains  48 non-null     object
#  1   then         48 non-null     object
# dtypes: object(2)
# memory usage: 900.0+ bytes

# %%
# Crearemos un diccionario para almacenar los conteos de valores únicos de cada columna
conteos_unicos = {}

# Iteramos sobre cada columna en el DataFrame
for columna in df_patterns.columns:
    # Contamos los valores únicos en cada columna y los almacenamos en el diccionario
    conteos_unicos[columna] = df_patterns[columna].nunique()

# Mostramos el resultado
print(conteos_unicos)
# Out:
# {'if contains': 48, 'then': 44}

# %%
# Convierte el DataFrame en un diccionario
patterns = pd.Series(df_patterns['then'].values, index=df_patterns['if contains']).to_dict()

# Imprimir la cantidad de elementos en el diccionario
print(f'El diccionario tiene {len(patterns)} elementos.')
# Out:
# El diccionario tiene 48 elementos.

# %%
# Imprimir los primeros 5 elementos del diccionario para verificar
for pattern, normalized_name in list(patterns.items())[:10]:
    print(f'Pattern: {pattern}, Normalized Name: {normalized_name}')
# Out:
# Pattern: HILTON, Normalized Name: HILTON HOTELS
# Pattern: DELTA, Normalized Name: DELTA AIRLINES
# Pattern: AMERICAN AIRLINES, Normalized Name: AMERICAN AIRLINES
# Pattern: HAMPTON INN, Normalized Name: HAMPTON INNS
# Pattern: SOUTHWES, Normalized Name: SOUTHWEST AIRLINES
# Pattern: HERTZ, Normalized Name: HERTZ
# Pattern: DOUBLETREE, Normalized Name: DOUBLETREE HOTELS
# Pattern: RESIDENCE INNS, Normalized Name: RESIDENCE INNS
# Pattern: MARRIOTT, Normalized Name: MARRIOTT HOTELS
# Pattern: UNITED AIRLINES, Normalized Name: UNITED AIRLINES

# %%
patterns
# Out:
# {'HILTON': 'HILTON HOTELS',
#  'DELTA': 'DELTA AIRLINES',
#  'AMERICAN AIRLINES': 'AMERICAN AIRLINES',
#  'HAMPTON INN': 'HAMPTON INNS',
#  'SOUTHWES': 'SOUTHWEST AIRLINES',
#  'HERTZ': 'HERTZ',
#  'DOUBLETREE': 'DOUBLETREE HOTELS',
#  'RESIDENCE INNS': 'RESIDENCE INNS',
#  'MARRIOTT': 'MARRIOTT HOTELS',
#  'UNITED AIRLINES': 'UNITED AIRLINES',
#  'HOMES TO SUITES': 'HOMES TO SUITES',
#  'EMBASSY SUITES': 'EMBASSY SUITES',
#  'COURTYARD': 'COURTYARDS',
#  'HOLIDAY INN': 'HOLIDAY INN',
#  'HYATT': 'HYATT HOTELS',
#  'TOOJAYS': 'TOOJAYS',
#  'CHICK FIL A': 'CHICK FIL A',
#  'IMDA': 'IMDA',
#  'HOMEWOOD SUITES': 'HOMEWOOD SUITES',
#  'AIR CAN': 'AIR CANADA',
#  'OFFICE DEPOT': 'OFFICE DEPOT INC',
#  'OFFICEMAX': 'OFFICE DEPOT INC',
#  'FAIRFIELD INNS': 'FAIRFIELD INNS',
#  'WALMART': 'WALMART',
#  'WAL MART': 'WALMART',
#  'STARBUCKS': 'STARBUCKS',
#  'BUFFALO WILD': 'BUFFALO WILD WINGS',
#  'DUNKIN': 'DUNKIN DONUTS',
#  'FAIRFIELD INN': 'FAIRFIELD INNS',
#  'FEDEX': 'FEDEX',
#  'FED EX': 'FEDEX',
#  'FIREHOUSE': 'FIREHOUSE SUBS',
#  'JERSEY MIKES': 'JERSEY MIKES',
#  'BURGER KING': 'BURGER KING',
#  'KFC': 'KFC',
#  'KRISPY KREME': 'KRISPY KREME',
#  'LOVES': 'LOVES',
#  'LYFT': 'LYFT',
#  'MCDONALD': 'MCDONALDS',
#  'ALE HOUSE': 'ALE HOUSE',
#  'OLIVE GARDEN': 'OLIVE GARDEN',
#  'RACETRAC': 'RACETRAC',
#  'SAMS': 'SAMS CLUB',
#  'SHEETZ': 'SHEETZ',
#  'SHELL': 'SHELL OIL',
#  'SPEEDWAY': 'SPEEDWAY',
#  'SUNOCO': 'SUNOCO',
#  'UBER': 'UBER'}

# %% [markdown]
# # Cleaning

# %% [markdown]
# ### Funcion y aplicacion de la funcion de Diana:

# %%
import re

def normalize_supplier_name(row):
    word = row['SUPPLIER_ERP']
    
    # If SUPPLIER_NORMALIZED is not blank, return its value without changes
    if not pd.isna(row['SUPPLIER_NORMALIZED']) and row['SUPPLIER_NORMALIZED']:
        return row['SUPPLIER_NORMALIZED']

    if pd.isna(word):
        return ''
    

    # Strip '#' and anything following it from right to left
    word =re.sub(r'#.*$', '', word)
    
    # Remove trailing whitespaces
    word = word.rstrip()

    # For concur (credit card) data only`
    payment_methods = ['TCB*','NIC*  ','CF* ','IN *','GLF*','WPY*','ZSK*','TLF*','TN*','PY *','PLACPAY*','L2G*','IC* ', 'B2P*', 'CCI*', 
                       'CEP*', 'CKE*', 'EIG*', 'FSP*', 'HAD*', 'PAR*', 'PAYPAL *', 'PMT*', 'PP*', 'SLICE*', 'SQ *', 'TST*',
                       '4TE*', 'UEP*', 'ORACL*']
    
    # Remove listed payment methods from supplier name
    for method in payment_methods:
        if word.startswith(method):
            word = word[len(method):].strip('*').strip()
    
    word = word.replace('$', '').replace('%', '').replace('^', '').replace('#', '').replace('(', '').replace(')', '')
    word = word.replace('[', '').replace(']', '').replace(';', '').replace(':', '').replace('"', '').replace("'", "")
    word = word.replace('"', '').replace(',', '').replace('’', '').replace('-', ' ').replace('/', ' ').replace('°', '')

    to_keep = ['.COM', '.com', '.ORG', '.org', '.NET', '.net', 'WWW.', 'www.']
    if any([keep in word for keep in to_keep]):
        return word
    else:
        word = word.replace('.', '')
        return word.upper()

# %%
# Apply the normalization function to create the SUPPLIER_NORMALIZED column
df['SUPPLIER_NORMALIZED'] = df.apply(normalize_supplier_name, axis=1)

# Print the distinct count of supplier erp and normalized to test re results of the normalization function
print(f"Distinct values before normalization: {df['SUPPLIER_ERP'].nunique()}")
print(f"Distinct values after normalization: {df['SUPPLIER_NORMALIZED'].nunique()}")
# Out:
# Distinct values before normalization: 2168
# Distinct values after normalization: 1891

# %%
#Final export for Insigths
df.to_csv('TBC_OUTPUT_SAP_FY23_MAR v.2.csv', encoding='UTF-8-SIG', index=False)

# %%
# Clustering operation Concur data input

selected_columns =['FILE_NAME','ASSETID','SUPPLIER_ERP', 'SUPPLIER_NORMALIZED', 'TOTAL_SPEND_USD']
df_selected =df[selected_columns]

shape_before = df_selected.shape
print("Row count before grouping and with blanks:", shape_before)

df_summarized = df_selected.groupby(['FILE_NAME','ASSETID','SUPPLIER_ERP', 'SUPPLIER_NORMALIZED'])['TOTAL_SPEND_USD'].sum().reset_index()

#Use .loc to strip whitespaces in 'SUPPLIER_ERP' and 'SUPPLIER_NORMALIZED'
df_summarized.loc[:, 'SUPPLIER_ERP'] = df_summarized['SUPPLIER_ERP'].str.strip()
df_summarized.loc[:, 'SUPPLIER_NORMALIZED'] = df_summarized['SUPPLIER_NORMALIZED'].str.strip()

concur_data = df_summarized.dropna(subset=['SUPPLIER_ERP', 'SUPPLIER_NORMALIZED'], how='any', inplace=False)


shape_after= concur_data.shape
print("Row count after grouping and without blanks:", shape_after)

concur_data.to_csv('concur supplier list mar v.1.csv', encoding='UTF-8-SIG', index=False)
# Out:
# Row count before grouping and with blanks: (4002, 5)
# Row count after grouping and without blanks: (3875, 5)

# %% [markdown]
# ### Our code

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4002 entries, 0 to 4001
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ASSETID              4002 non-null   object
#  1   SUPPLIER_ERP         4002 non-null   object
#  2   TOTAL_SPEND          4002 non-null   float64
#  3   SUPPLIER_ERP_WONULL  4002 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 125.2+ KB

# %%
# Crearemos un diccionario para almacenar los conteos de valores únicos de cada columna
conteos_unicos = {}

# Iteramos sobre cada columna en el DataFrame
for columna in df.columns:
    # Contamos los valores únicos en cada columna y los almacenamos en el diccionario
    conteos_unicos[columna] = df[columna].nunique()

# Mostramos el resultado
print(conteos_unicos)
# Out:
# {'ASSETID': 4002, 'SUPPLIER_ERP': 2169, 'TOTAL_SPEND': 2910, 'SUPPLIER_ERP_WONULL': 2169}

# %%
import re

def normalize_supplier_name(name, patterns):
    """
    Normalize supplier names based on given patterns.

    Args:
    name (str): The name of the supplier to normalize.
    patterns (dict): A dictionary of patterns where key is the part of the name to match and
                     the value is the normalized name.

    Returns:
    str: The normalized name if a pattern is matched, otherwise the original name.
    """
    
    # Comprobar si el nombre es una cadena
    if isinstance(name, str):
        # Convert the name to uppercase for case-insensitive comparison
        name_upper = name.upper()
        
        # Check each pattern in the dictionary
        for pattern, normalized_name in patterns.items():
            # If the pattern is found in the name, return the normalized name
            if re.search(pattern, name_upper):
                return normalized_name
    
    # If no pattern matches or if name is not a string, return the original name
    return name

# Example usage
example_names = [
    'SALTGRASS ARKANSAS INC',
    'WAL-MART SUPERCENTER 878',
    'CHICK-FIL-A 01393',
    'WHATABURGER346',
    'WHATABURGER RESTAURANTS LLC',
    'WHATABURGER INC 708',
    'CHICK FIL A 02045',
    'CHICK FIL A 01393',
    'WAL MART', 
    'WALMART21012',
    None,  # Agregar un ejemplo no string para probar
    12345  # Otro ejemplo no string
]

# Normalize the example names
normalized_names = [normalize_supplier_name(name, patterns) for name in example_names]
normalized_names
# Out:
# ['SALTGRASS ARKANSAS INC',
#  'WAL-MART SUPERCENTER 878',
#  'CHICK-FIL-A 01393',
#  'WHATABURGER346',
#  'WHATABURGER RESTAURANTS LLC',
#  'WHATABURGER INC 708',
#  'CHICK FIL A',
#  'CHICK FIL A',
#  'WALMART',
#  'WALMART',
#  None,
#  12345]

# %%
# Aplicar la función de normalización a la columna 'supplier_name'
df['SUPPLIER_CLEAN'] = df['SUPPLIER_ERP'].apply(lambda x: normalize_supplier_name(x, patterns))

unique_before = df['SUPPLIER_ERP'].nunique()
unique_after = df['SUPPLIER_CLEAN'].nunique()

# Imprimir el conteo distinto de valores antes y despues de la operacionn
print(f"Distinct values before operation: {unique_before}")
print(f"Distinct values after operation: {unique_after}")

# Calcular el numero de filas afectadas por la operacion 
values_normalized = unique_before - unique_after
print(f"Number of values normalized through the function: {values_normalized}")

# Crear un DataFrame con solo los registros afectados para comparar el antes y el después
affected_df = df[df['SUPPLIER_ERP'] != df['SUPPLIER_CLEAN']]

# Contar el numero de filas afectadas por la operacion
rows_affected = affected_df.shape[0]
print(f"Number of rows affected by the dictionary function: {rows_affected}")

# Mostrar el número de registros afectados y los detalles de los registros afectados
affected_df[['SUPPLIER_ERP', 'SUPPLIER_CLEAN']].sort_values(by='SUPPLIER_ERP', ascending=True)
# Out:
# Distinct values before operation: 2169
# Distinct values after operation: 1710
# Number of values normalized through the function: 459
# Number of rows affected by the dictionary function: 1671
#                    SUPPLIER_ERP      SUPPLIER_CLEAN
# 3277     64199 - HILTON DOWNTOW       HILTON HOTELS
# 3631               A DUNKIN LAS       DUNKIN DONUTS
# 2933      AIR CAN 0144263076334          AIR CANADA
# 3132     AIR CAN 01480922553040          AIR CANADA
# 1501    AIR CAN* 00142191709599          AIR CANADA
# 2929    AIR CAN* 00144263551182          AIR CANADA
# 671     AIR CAN* 00144263591233          AIR CANADA
# 1596          American Airlines   AMERICAN AIRLINES
# 3438          American Airlines   AMERICAN AIRLINES
# 3425          American Airlines   AMERICAN AIRLINES
# 3974          American Airlines   AMERICAN AIRLINES
# 3424          American Airlines   AMERICAN AIRLINES
# 3423          American Airlines   AMERICAN AIRLINES
# 3421          American Airlines   AMERICAN AIRLINES
# 3244          American Airlines   AMERICAN AIRLINES
# 2598          American Airlines   AMERICAN AIRLINES
# 265           American Airlines   AMERICAN AIRLINES
# 181           American Airlines   AMERICAN AIRLINES
# 2870          American Airlines   AMERICAN AIRLINES
# 168           American Airlines   AMERICAN AIRLINES
# 152           American Airlines   AMERICAN AIRLINES
# 149           American Airlines   AMERICAN AIRLINES
# 2942          American Airlines   AMERICAN AIRLINES
# 60         Bridgewater Marriott     MARRIOTT HOTELS
# 58         Bridgewater Marriott     MARRIOTT HOTELS
# 59         Bridgewater Marriott     MARRIOTT HOTELS
# 2889         Buffalo Wild Wings  BUFFALO WILD WINGS
# 1145                Burger King         BURGER KING
# 2948            CHICK FIL A CHS         CHICK FIL A
# 3470       CHICK FIL A MAIN CLT         CHICK FIL A
# 1874         COURTYARD MANASSAS          COURTYARDS
# 2457         COURTYARD SYRACUSE          COURTYARDS
# 874                 Chick Fil A         CHICK FIL A
# 3363                 Courtyards          COURTYARDS
# 3366                 Courtyards          COURTYARDS
# 3368                 Courtyards          COURTYARDS
# 1862                 Courtyards          COURTYARDS
# 1863                 Courtyards          COURTYARDS
# 1864                 Courtyards          COURTYARDS
# 1865                 Courtyards          COURTYARDS
# 3365                 Courtyards          COURTYARDS
# 1867                 Courtyards          COURTYARDS
# 3362                 Courtyards          COURTYARDS
# 3364                 Courtyards          COURTYARDS
# 1873                 Courtyards          COURTYARDS
# 3359                 Courtyards          COURTYARDS
# 3360                 Courtyards          COURTYARDS
# 3361                 Courtyards          COURTYARDS
# 1866                 Courtyards          COURTYARDS
# 167                  Courtyards          COURTYARDS
# 3367                 Courtyards          COURTYARDS
# 2906                 Courtyards          COURTYARDS
# 3369                 Courtyards          COURTYARDS
# 166                  Courtyards          COURTYARDS
# 165                  Courtyards          COURTYARDS
# 164                  Courtyards          COURTYARDS
# 163                  Courtyards          COURTYARDS
# 162                  Courtyards          COURTYARDS
# 158                  Courtyards          COURTYARDS
# 2926                 Courtyards          COURTYARDS
# 2632      DD DOORDASH FIREHOUSE      FIREHOUSE SUBS
# 2631      DD DOORDASH FIREHOUSE      FIREHOUSE SUBS
# 2745       DELTA 00641116616641      DELTA AIRLINES
# 784        DELTA 00642109955141      DELTA AIRLINES
# 269        DELTA 00642112173091      DELTA AIRLINES
# 1753       DELTA 00642113433802      DELTA AIRLINES
# 1291       DELTA 00642114405004      DELTA AIRLINES
# 1302       DELTA 00642114692741      DELTA AIRLINES
# 1759       DELTA 00642115280660      DELTA AIRLINES
# 2650       DELTA 00642115334700      DELTA AIRLINES
# 1607       DELTA 00642116469750      DELTA AIRLINES
# 1095       DELTA 00642116826584      DELTA AIRLINES
# 2158       DELTA 00642117234371      DELTA AIRLINES
# 2204       DELTA 00642117531834      DELTA AIRLINES
# 796        DELTA 00642118978760      DELTA AIRLINES
# 2646       DELTA 00642119154434      DELTA AIRLINES
# 281        DELTA 00642119644132      DELTA AIRLINES
# 1611       DELTA 00642119733485      DELTA AIRLINES
# 2119       DELTA 00680913463241      DELTA AIRLINES
# 3528       DELTA 00680926810141      DELTA AIRLINES
# 2700       DELTA 00680938145926      DELTA AIRLINES
# 3951       DELTA 00680949507836      DELTA AIRLINES
# 2640       DELTA 00680949508956      DELTA AIRLINES
# 3107       DELTA 00680949509063      DELTA AIRLINES
# 80        DOUBLE TREE BY HILTON       HILTON HOTELS
# 1239     DOUBLETREE CHARLOTTE A   DOUBLETREE HOTELS
# 1262     DOUBLETREE CHARLOTTE A   DOUBLETREE HOTELS
# 1252          DoubleTree Hotels   DOUBLETREE HOTELS
# 1254          DoubleTree Hotels   DOUBLETREE HOTELS
# 1255          DoubleTree Hotels   DOUBLETREE HOTELS
# 1256          DoubleTree Hotels   DOUBLETREE HOTELS
# 91            DoubleTree Hotels   DOUBLETREE HOTELS
# 1257          DoubleTree Hotels   DOUBLETREE HOTELS
# 1258          DoubleTree Hotels   DOUBLETREE HOTELS
# 1260          DoubleTree Hotels   DOUBLETREE HOTELS
# 94            DoubleTree Hotels   DOUBLETREE HOTELS
# 96            DoubleTree Hotels   DOUBLETREE HOTELS
# 1899          DoubleTree Hotels   DOUBLETREE HOTELS
# 87            DoubleTree Hotels   DOUBLETREE HOTELS
# 1900          DoubleTree Hotels   DOUBLETREE HOTELS
# 1901          DoubleTree Hotels   DOUBLETREE HOTELS
# 86            DoubleTree Hotels   DOUBLETREE HOTELS
# 2861          DoubleTree Hotels   DOUBLETREE HOTELS
# 1817          DoubleTree Hotels   DOUBLETREE HOTELS
# 2858          DoubleTree Hotels   DOUBLETREE HOTELS
# 1898          DoubleTree Hotels   DOUBLETREE HOTELS
# 84            DoubleTree Hotels   DOUBLETREE HOTELS
# 89            DoubleTree Hotels   DOUBLETREE HOTELS
# 85            DoubleTree Hotels   DOUBLETREE HOTELS
# 88            DoubleTree Hotels   DOUBLETREE HOTELS
# 95            DoubleTree Hotels   DOUBLETREE HOTELS
# 1896          DoubleTree Hotels   DOUBLETREE HOTELS
# 248           DoubleTree Hotels   DOUBLETREE HOTELS
# 83            DoubleTree Hotels   DOUBLETREE HOTELS
# 82            DoubleTree Hotels   DOUBLETREE HOTELS
# 1897          DoubleTree Hotels   DOUBLETREE HOTELS
# 2871              Dunkin Donuts       DUNKIN DONUTS
# 1530     EMBASSY SUITES JACKSON      EMBASSY SUITES
# 1048      EMBASSY SUITES MYRTLE      EMBASSY SUITES
# 2801             Embassy Suites      EMBASSY SUITES
# 2789             Embassy Suites      EMBASSY SUITES
# 2800             Embassy Suites      EMBASSY SUITES
# 414              Embassy Suites      EMBASSY SUITES
# 2799             Embassy Suites      EMBASSY SUITES
# 1655             Embassy Suites      EMBASSY SUITES
# 1028             Embassy Suites      EMBASSY SUITES
# 3196             Embassy Suites      EMBASSY SUITES
# 3197             Embassy Suites      EMBASSY SUITES
# 1654             Embassy Suites      EMBASSY SUITES
# 1656             Embassy Suites      EMBASSY SUITES
# 1657             Embassy Suites      EMBASSY SUITES
# 1658             Embassy Suites      EMBASSY SUITES
# 425              Embassy Suites      EMBASSY SUITES
# 1659             Embassy Suites      EMBASSY SUITES
# 1677             Embassy Suites      EMBASSY SUITES
# 1678             Embassy Suites      EMBASSY SUITES
# 1679             Embassy Suites      EMBASSY SUITES
# 1680             Embassy Suites      EMBASSY SUITES
# 1681             Embassy Suites      EMBASSY SUITES
# 1682             Embassy Suites      EMBASSY SUITES
# 1676             Embassy Suites      EMBASSY SUITES
# 2790             Embassy Suites      EMBASSY SUITES
# 209      FAIRFIELD INN & SUITES      FAIRFIELD INNS
# 3867             HERTZ #0130606               HERTZ
# 105              HERTZ #0130606               HERTZ
# 1263             HERTZ #0188012               HERTZ
# 252         HERTZ TOLL 10123653               HERTZ
# 2802        HERTZ TOLL 10341429               HERTZ
# 449         HERTZ TOLL 91854057               HERTZ
# 3003        HERTZ TOLL 91888087               HERTZ
# 3790        HERTZ TOLL 91910295               HERTZ
# 2760        HERTZ TOLL 96858995               HERTZ
# 774         HERTZ TOLL 96859480               HERTZ
# 3103        HERTZ TOLL 96966304               HERTZ
# 3106        HERTZ TOLL 96966304               HERTZ
# 234         HERTZ TOLL 98309902               HERTZ
# 2974        HERTZ TOLL 98572320               HERTZ
# 3606              HILTON DRAGOS       HILTON HOTELS
# 2708              HILTON DRAGOS       HILTON HOTELS
# 2445          HILTON GARDEN INN       HILTON HOTELS
# 1481          HILTON GARDEN INN       HILTON HOTELS
# 2851          HILTON GARDEN INN       HILTON HOTELS
# 3977          HILTON GARDEN INN       HILTON HOTELS
# 2764          HILTON GARDEN INN       HILTON HOTELS
# 2763          HILTON GARDEN INN       HILTON HOTELS
# 3913          HILTON GARDEN INN       HILTON HOTELS
# 3321          HILTON GARDEN INN       HILTON HOTELS
# 460           HILTON GARDEN INN       HILTON HOTELS
# 471           HILTON GARDEN INN       HILTON HOTELS
# 2491          HILTON GARDEN INN       HILTON HOTELS
# 2451          HILTON GARDEN INN       HILTON HOTELS
# 1136          HILTON GARDEN INN       HILTON HOTELS
# 424           HILTON GARDEN INN       HILTON HOTELS
# 452           HILTON GARDEN INN       HILTON HOTELS
# 1794          HILTON GARDEN INN       HILTON HOTELS
# 1085      HILTON GARDEN INN ATL       HILTON HOTELS
# 1087     HILTON GARDEN INN ATLA       HILTON HOTELS
# 464       HILTON GARDEN INN DFW       HILTON HOTELS
# 987      HILTON GARDEN INN DOWN       HILTON HOTELS
# 1512     HILTON GARDEN INN FRED       HILTON HOTELS
# 1474     HILTON GARDEN INN HALI       HILTON HOTELS
# 1514     HILTON GARDEN INN HALI       HILTON HOTELS
# 2360     HILTON GARDEN INN HUNT       HILTON HOTELS
# 964      HILTON GARDEN INN MT L       HILTON HOTELS
# 2956     HILTON GARDEN INN MT L       HILTON HOTELS
# 3863      HILTON GARDEN INN PBG       HILTON HOTELS
# 3868      HILTON GARDEN INN PBG       HILTON HOTELS
# 3999     HILTON GARDEN INN SPEC       HILTON HOTELS
# 1535     HILTON MYRTLE BEACH RE       HILTON HOTELS
# 3139     HILTON SUITES WINNIPEG       HILTON HOTELS
# 473                 HILTON WACO       HILTON HOTELS
# 2058     HOLIDAY INN EXP & SUIT         HOLIDAY INN
# 24       HOLIDAY INN EXPRESS NA         HOLIDAY INN
# 23       HOLIDAY INN EXPRESS NA         HOLIDAY INN
# 13       HOLIDAY INN EXPRESS NA         HOLIDAY INN
# 232      HOMES TO SUITES BY HIL     HOMES TO SUITES
# 326      HOMES TO SUITES BY HIL     HOMES TO SUITES
# 1971     HOMES TO SUITES BY HIL     HOMES TO SUITES
# 619      HOMES TO SUITES BY HIL     HOMES TO SUITES
# 990               Hilton Hotels       HILTON HOTELS
# 1172              Hilton Hotels       HILTON HOTELS
# 2615                Holiday Inn         HOLIDAY INN
# 763                 Holiday Inn         HOLIDAY INN
# 143                 Holiday Inn         HOLIDAY INN
# 141                 Holiday Inn         HOLIDAY INN
# 762                 Holiday Inn         HOLIDAY INN
# 2616                Holiday Inn         HOLIDAY INN
# 321                 Holiday Inn         HOLIDAY INN
# 113                 Holiday Inn         HOLIDAY INN
# 139                 Holiday Inn         HOLIDAY INN
# 125                 Holiday Inn         HOLIDAY INN
# 135                 Holiday Inn         HOLIDAY INN
# 112                 Holiday Inn         HOLIDAY INN
# 114                 Holiday Inn         HOLIDAY INN
# 121                 Holiday Inn         HOLIDAY INN
# 115                 Holiday Inn         HOLIDAY INN
# 120                 Holiday Inn         HOLIDAY INN
# 123                 Holiday Inn         HOLIDAY INN
# 683                 Holiday Inn         HOLIDAY INN
# 116                 Holiday Inn         HOLIDAY INN
# 117                 Holiday Inn         HOLIDAY INN
# 122                 Holiday Inn         HOLIDAY INN
# 118                 Holiday Inn         HOLIDAY INN
# 764                 Holiday Inn         HOLIDAY INN
# 109                 Holiday Inn         HOLIDAY INN
# 682                 Holiday Inn         HOLIDAY INN
# 108                 Holiday Inn         HOLIDAY INN
# 119                 Holiday Inn         HOLIDAY INN
# 110                 Holiday Inn         HOLIDAY INN
# 124                 Holiday Inn         HOLIDAY INN
# 111                 Holiday Inn         HOLIDAY INN
# 126                 Holiday Inn         HOLIDAY INN
# 734                 Holiday Inn         HOLIDAY INN
# 742                 Holiday Inn         HOLIDAY INN
# 732                 Holiday Inn         HOLIDAY INN
# 741                 Holiday Inn         HOLIDAY INN
# 731                 Holiday Inn         HOLIDAY INN
# 730                 Holiday Inn         HOLIDAY INN
# 729                 Holiday Inn         HOLIDAY INN
# 740                 Holiday Inn         HOLIDAY INN
# 728                 Holiday Inn         HOLIDAY INN
# 754                 Holiday Inn         HOLIDAY INN
# 727                 Holiday Inn         HOLIDAY INN
# 733                 Holiday Inn         HOLIDAY INN
# 735                 Holiday Inn         HOLIDAY INN
# 3547                Holiday Inn         HOLIDAY INN
# 3546                Holiday Inn         HOLIDAY INN
# 870                       Hyatt        HYATT HOTELS
# 301                Hyatt Hotels        HYATT HOTELS
# 958                Hyatt Hotels        HYATT HOTELS
# 2334               Hyatt Hotels        HYATT HOTELS
# 838                Hyatt Hotels        HYATT HOTELS
# 3507               Hyatt Hotels        HYATT HOTELS
# 2550               Hyatt Hotels        HYATT HOTELS
# 1824               Hyatt Hotels        HYATT HOTELS
# 3451               Hyatt Hotels        HYATT HOTELS
# 2576               Hyatt Hotels        HYATT HOTELS
# 3034               Hyatt Hotels        HYATT HOTELS
# 3434               Hyatt Hotels        HYATT HOTELS
# 2237               Hyatt Hotels        HYATT HOTELS
# 933                Hyatt Hotels        HYATT HOTELS
# 2267               Hyatt Hotels        HYATT HOTELS
# 3433               Hyatt Hotels        HYATT HOTELS
# 3432               Hyatt Hotels        HYATT HOTELS
# 441                Hyatt Hotels        HYATT HOTELS
# 2687            United Airlines     UNITED AIRLINES
# 2688            United Airlines     UNITED AIRLINES
# 2671            United Airlines     UNITED AIRLINES
# 3503            United Airlines     UNITED AIRLINES
# 3504            United Airlines     UNITED AIRLINES
# 2689            United Airlines     UNITED AIRLINES
# 3261            United Airlines     UNITED AIRLINES
# 2678            United Airlines     UNITED AIRLINES
# 1934            United Airlines     UNITED AIRLINES
# 1247            United Airlines     UNITED AIRLINES
# 1905            United Airlines     UNITED AIRLINES
# 1238            United Airlines     UNITED AIRLINES
# 2635            United Airlines     UNITED AIRLINES
# 2645                WALMART.COM             WALMART
# 2448                WALMART.COM             WALMART
# 2454                WALMART.COM             WALMART
# 3293                WALMART.COM             WALMART
# 3304                WALMART.COM             WALMART
# 2456                WALMART.COM             WALMART
# 2629                WALMART.COM             WALMART
# 2628                WALMART.COM             WALMART
# 3635                    Walmart             WALMART
# 721          carolina ale house           ALE HOUSE
# 1632                  mcdonalds           MCDONALDS

# %%
# df = df.drop(['SUPPLIER_ERP_HASH_TRIM'], axis=1)
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11203 entries, 0 to 11202
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SUPPLIER_NORMALIZED  11203 non-null  object
#  1   TOTAL_SPEND          11203 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 175.2+ KB

# %% [markdown]
# ### Funcion para remover el asterisco y lo que le sigue

# %%
import re

def remove_hash_and_trim(word):
    # Eliminar todo después de '#'
    word = re.sub(r'#.*$', '', word)
    # Eliminar espacios finales
    word = word.rstrip()
    return word

# Supongamos que df es tu DataFrame y que 'SUPPLIER_CLEAN' es la columna relevante
# Aplicar la función a la columna 'SUPPLIER_CLEAN'
df['SUPPLIER_ERP_HASH_TRIM'] = df['SUPPLIER_CLEAN'].apply(remove_hash_and_trim)

unique_before = df['SUPPLIER_CLEAN'].nunique()
unique_after = df['SUPPLIER_ERP_HASH_TRIM'].nunique()

# Imprimir el conteo distinto de valores antes y despues de la operacionn
print(f"Distinct values before operation: {unique_before}")
print(f"Distinct values after operation: {unique_after}")

# Calcular el numero de filas afectadas por la operacion 
values_normalized = unique_before - unique_after
print(f"Number of values normalized through the function: {values_normalized}")

# Identificar las filas afectadas por la operacion 
changed_rows = df[df['SUPPLIER_CLEAN'] != df['SUPPLIER_ERP_HASH_TRIM']]

# Contar el numero de filas afectadas por la operacion
rows_affected = changed_rows.shape[0]
print(f"Number of rows affected by the hash and trim function: {rows_affected}")

# Mostrar filas afectadas para revision
changed_rows[['SUPPLIER_CLEAN', 'SUPPLIER_ERP_HASH_TRIM']]
# Out:
# Distinct values before operation: 1710
# Distinct values after operation: 1544
# Number of values normalized through the function: 166
# Number of rows affected by the hash and trim function: 324
#               SUPPLIER_CLEAN SUPPLIER_ERP_HASH_TRIM
# 14            WAL-MART #1466               WAL-MART
# 127      TIM HORTONS #915678            TIM HORTONS
# 131          PAPA JOHNS #744             PAPA JOHNS
# 154           ZAXBY'S #74345                ZAXBY'S
# 155   BP#1309600LOVE PETRQPS                     BP
# 159             BUC-EE'S #57               BUC-EE'S
# 161           CASEY S # 4434                CASEY S
# 183      PANDA EXPRESS #2079          PANDA EXPRESS
# 185   PANERA BREAD #204993 P           PANERA BREAD
# 186   EXXON KENJO MARKET #45     EXXON KENJO MARKET
# 188   BP#6593693METROPOLIQPS                     BP
# 198          WEIGELS #86 Q88                WEIGELS
# 199          WEIGELS #88 Q88                WEIGELS
# 201             BUC-EE'S #50               BUC-EE'S
# 202          WEIGELS #88 Q88                WEIGELS
# 204    TEXAS ROADHOUSE #2064        TEXAS ROADHOUSE
# 205   BP#9205352FIVESTAR QPS                     BP
# 207          SONNYS BBQ #220             SONNYS BBQ
# 235              KROGER #441                 KROGER
# 250       WHOLEFDS NVL#10685           WHOLEFDS NVL
# 262       CHICK-FIL-A #02081            CHICK-FIL-A
# 308         PAPA JOHNS #3615             PAPA JOHNS
# 323             CASEYS #2818                 CASEYS
# 325      LOVE'S #0671 INSIDE                 LOVE'S
# 330       WHOLEFDS NVL#10685           WHOLEFDS NVL
# 370     DOLLAR-GENERAL #2849         DOLLAR-GENERAL
# 371     DOLLAR-GENERAL #1772         DOLLAR-GENERAL
# 407              ARBYS #5425                  ARBYS
# 462         CIRCLE K # 41256               CIRCLE K
# 469         CIRCLE K # 06620               CIRCLE K
# 472         CHICK-FIL-A #739            CHICK-FIL-A
# 483            SAFEWAY #1990                SAFEWAY
# 512             MAVERIK #606                MAVERIK
# 516   DAVE & BUSTERS #106 TA         DAVE & BUSTERS
# 537        ROUSES MARKET #46          ROUSES MARKET
# 559       CHICK-FIL-A #04757            CHICK-FIL-A
# 567          MOSERS FOODS #7           MOSERS FOODS
# 568             BUC-EE'S #34               BUC-EE'S
# 582      PANDA EXPRESS #2854          PANDA EXPRESS
# 599       CHICK-FIL-A #04962            CHICK-FIL-A
# 607       CHICK-FIL-A #02729            CHICK-FIL-A
# 611           KWIK TRIP #639              KWIK TRIP
# 632           WAL-MART #2184               WAL-MART
# 636            DENNY'S #6354                DENNY'S
# 637            WENDY'S #2099                WENDY'S
# 675             PUBLIX #1680                 PUBLIX
# 676          ULTRAMAR #41963               ULTRAMAR
# 680   IGA EXTRA LALONDE #517      IGA EXTRA LALONDE
# 684        TIM HORTONS #0889            TIM HORTONS
# 685           POPEYES #10531                POPEYES
# 690        TIM HORTONS #1619            TIM HORTONS
# 695   IGA EXTRA LALONDE #517      IGA EXTRA LALONDE
# 705        TIM HORTONS #1379            TIM HORTONS
# 706            POPEYES #4221                POPEYES
# 708      LOVE'S #0835 INSIDE                 LOVE'S
# 714   CHILI'S GRILL & BAR#16    CHILI'S GRILL & BAR
# 723       CHICK-FIL-A #04546            CHICK-FIL-A
# 737       CHICK-FIL-A #02805            CHICK-FIL-A
# 747   BP#88730361622 I70 QPS                     BP
# 757          THORNTONS #0007              THORNTONS
# 759            DD/BR #306048                  DD/BR
# 772   AMOCO#2124800WEST WQPS                  AMOCO
# 778              KROGER #429                 KROGER
# 812   PANERA BREAD #204707 O           PANERA BREAD
# 813   PANERA BREAD #204707 O           PANERA BREAD
# 892       CHICK-FIL-A #01207            CHICK-FIL-A
# 896      CVS/PHARMACY #10559           CVS/PHARMACY
# 921   ADVANCE AUTO PARTS #50     ADVANCE AUTO PARTS
# 979                  S&G #91                    S&G
# 983          GFS STORE #0802              GFS STORE
# 1009   TEXAS ROADHOUSE #2413        TEXAS ROADHOUSE
# 1015            BUC-EE'S #48               BUC-EE'S
# 1016       CIRCLE K #2742195               CIRCLE K
# 1017       CIRCLE K #2742195               CIRCLE K
# 1022  PAPPASITO'S CANTINA #0    PAPPASITO'S CANTINA
# 1024     TACO BELL # '034344              TACO BELL
# 1033    PAPPASITO'S #641 Q80            PAPPASITO'S
# 1034            RUBIO'S #284                RUBIO'S
# 1061              WENDYS #42                 WENDYS
# 1082     PANDA EXPRESS #1000          PANDA EXPRESS
# 1086           HARDEE'S #781               HARDEE'S
# 1178       TIM HORTONS #7500            TIM HORTONS
# 1179               A&W #1480                    A&W
# 1185       MARY BROWNS #9020            MARY BROWNS
# 1213    WM SUPERCENTER #1381         WM SUPERCENTER
# 1216        CIRCLE K # 03404               CIRCLE K
# 1220            MAVERIK #621                MAVERIK
# 1224            MAVERIK #621                MAVERIK
# 1309      CHICK-FIL-A #01130            CHICK-FIL-A
# 1310      CHICK-FIL-A #01130            CHICK-FIL-A
# 1329             PUBLIX #654                 PUBLIX
# 1331       TIM HORTONS #7266            TIM HORTONS
# 1333       TIM HORTONS #0449            TIM HORTONS
# 1335       TIM HORTONS #7266            TIM HORTONS
# 1336       TIM HORTONS #0268            TIM HORTONS
# 1337       TIM HORTONS #1506            TIM HORTONS
# 1339      DOLLAR TREE #40273            DOLLAR TREE
# 1340       TIM HORTONS #7266            TIM HORTONS
# 1341          FRESHCO # 3859                FRESHCO
# 1347     PANDA EXPRESS #1504          PANDA EXPRESS
# 1366            CHILI'S #210                CHILI'S
# 1374  PANERA BREAD #601674 P           PANERA BREAD
# 1375  PANERA BREAD #600782 O           PANERA BREAD
# 1378      CHICK-FIL-A #01227            CHICK-FIL-A
# 1380          AUTOZONE #3471               AUTOZONE
# 1397            RUBIO'S #284                RUBIO'S
# 1398            RUBIO'S #284                RUBIO'S
# 1404            RUBIO'S #284                RUBIO'S
# 1412      CHICK-FIL-A #03116            CHICK-FIL-A
# 1413           POPEYES #2556                POPEYES
# 1422      CHICK-FIL-A #05428            CHICK-FIL-A
# 1447          WAL-MART #0998               WAL-MART
# 1450          WAL-MART #0998               WAL-MART
# 1452      CHICK-FIL-A #01721            CHICK-FIL-A
# 1487       TIM HORTONS #5917            TIM HORTONS
# 1507      COUCHE-TARD # 1217            COUCHE-TARD
# 1508       TIM HORTONS #2065            TIM HORTONS
# 1526     SCNB SMITHFIELD #12        SCNB SMITHFIELD
# 1527      CHICK-FIL-A #01360            CHICK-FIL-A
# 1552     PANDA EXPRESS #2902          PANDA EXPRESS
# 1560  ODP BUS SOL LLC # 1006        ODP BUS SOL LLC
# 1561               KIM'S #45                  KIM'S
# 1562      CHICK-FIL-A #04470            CHICK-FIL-A
# 1564  ODP BUS SOL LLC # 1006        ODP BUS SOL LLC
# 1573      CHICK-FIL-A #00654            CHICK-FIL-A
# 1580   LARRYS GIANT SUBS #82      LARRYS GIANT SUBS
# 1597      WHOLEFDS NVL#10685           WHOLEFDS NVL
# 1645     WHOLEFDS GRP #10790           WHOLEFDS GRP
# 1649         28TH ST AGO #28            28TH ST AGO
# 1671         28TH ST AGO #28            28TH ST AGO
# 1715      CHICK-FIL-A #05285            CHICK-FIL-A
# 1769      CHICK-FIL-A #03946            CHICK-FIL-A
# 1770          WAL-MART #2534               WAL-MART
# 1777            RUBIO'S #223                RUBIO'S
# 1789  HABIT SAND CITY #28Q91        HABIT SAND CITY
# 1811  ARCO#07119ARCO #071QPS                   ARCO
# 1835      CHICK-FIL-A #05066            CHICK-FIL-A
# 1841      WHOLEFDS NVL#10685           WHOLEFDS NVL
# 1856        EXXON A-PLUS #71           EXXON A-PLUS
# 1858      CHICK-FIL-A #02585            CHICK-FIL-A
# 1869              IHOP #4508                   IHOP
# 1871      CHICK-FIL-A #01883            CHICK-FIL-A
# 1881            BUC-EE'S #50               BUC-EE'S
# 1895     PANDA EXPRESS #3007          PANDA EXPRESS
# 1954    WM SUPERCENTER #1037         WM SUPERCENTER
# 1967   TEXAS ROADHOUSE #2200        TEXAS ROADHOUSE
# 1972      CHICK-FIL-A #01622            CHICK-FIL-A
# 1980           DD/BR #341077                  DD/BR
# 1994   CEFCO #0098 GILMER TX                  CEFCO
# 1995   DAIRY QUEEN #14435QPS            DAIRY QUEEN
# 1997   CEFCO #0098 GILMER TX                  CEFCO
# 1999   CEFCO #0098 GILMER TX                  CEFCO
# 2002   CEFCO #0098 GILMER TX                  CEFCO
# 2006   CEFCO #0098 GILMER TX                  CEFCO
# 2008   EXXON QUICK TRACK #12      EXXON QUICK TRACK
# 2009   DAIRY QUEEN #14435QPS            DAIRY QUEEN
# 2011   CEFCO #0098 GILMER TX                  CEFCO
# 2021      CHICK-FIL-A #01486            CHICK-FIL-A
# 2041          WENDY'S #11671                WENDY'S
# 2045              PUBLIX #97                 PUBLIX
# 2048             PUBLIX #836                 PUBLIX
# 2051    SONIC DRIVE IN #4815         SONIC DRIVE IN
# 2062  PORTILLOS HOT DOGS #13     PORTILLOS HOT DOGS
# 2063  PORTILLOS HOT DOGS #29     PORTILLOS HOT DOGS
# 2073      CHICK-FIL-A #02777            CHICK-FIL-A
# 2074     WM SUPERCENTER #915         WM SUPERCENTER
# 2078          WAL-MART #3102               WAL-MART
# 2099            MEIJER # 256                 MEIJER
# 2100      CHICK-FIL-A #05175            CHICK-FIL-A
# 2111      CHICK-FIL-A #00663            CHICK-FIL-A
# 2168      PF CHANGS #9205 CP              PF CHANGS
# 2199      CHICK-FIL-A #04757            CHICK-FIL-A
# 2208      CHICK-FIL-A #01333            CHICK-FIL-A
# 2216   TEXAS ROADHOUSE #2139        TEXAS ROADHOUSE
# 2233     LOVE'S #0355 INSIDE                 LOVE'S
# 2235     LOVE'S #0360 INSIDE                 LOVE'S
# 2242      CHICK-FIL-A #00374            CHICK-FIL-A
# 2246      WHOLEFDS NVL#10685           WHOLEFDS NVL
# 2276    LOVE'S #0773 OUTSIDE                 LOVE'S
# 2313      KING SOOPERS #0128           KING SOOPERS
# 2315        LOAF N JUG #0803             LOAF N JUG
# 2320      CHICK-FIL-A #04757            CHICK-FIL-A
# 2333             PUBLIX #162                 PUBLIX
# 2340             PUBLIX #162                 PUBLIX
# 2371      CHICK-FIL-A #03807            CHICK-FIL-A
# 2374         WEIGELS #43 Q88                WEIGELS
# 2375          FOOD CITY #619              FOOD CITY
# 2401              IHOP #4404                   IHOP
# 2421  PANERA BREAD #601379 O           PANERA BREAD
# 2430       O'CHARLEY'S #2105            O'CHARLEY'S
# 2497  CALI PIZZA KITC INC #2    CALI PIZZA KITC INC
# 2522     LOVE'S #0514 INSIDE                 LOVE'S
# 2524             STINKER #36                STINKER
# 2559      CHICK-FIL-A #01827            CHICK-FIL-A
# 2560      PF CHANGS #9915 CP              PF CHANGS
# 2587     LOVE'S #0327 INSIDE                 LOVE'S
# 2588          WAL-MART #2763               WAL-MART
# 2590     LOVE'S #0767 INSIDE                 LOVE'S
# 2591    WM SUPERCENTER #3567         WM SUPERCENTER
# 2592     LOVE'S #0885 INSIDE                 LOVE'S
# 2595     LOVE'S #0767 INSIDE                 LOVE'S
# 2611        CIRCLE K # 23965               CIRCLE K
# 2618     TIM HORTONS #915619            TIM HORTONS
# 2625          ZAXBY'S #37806                ZAXBY'S
# 2649      WHOLEFDS NVL#10685           WHOLEFDS NVL
# 2662  PORTILLOS HOT DOGS #21     PORTILLOS HOT DOGS
# 2664  PANERA BREAD #204722 K           PANERA BREAD
# 2697      CHICK-FIL-A #02271            CHICK-FIL-A
# 2698      CHICK-FIL-A #02271            CHICK-FIL-A
# 2756  PANERA BREAD #601360 P           PANERA BREAD
# 2757  PANERA BREAD #601360 P           PANERA BREAD
# 2758      CHICK-FIL-A #02603            CHICK-FIL-A
# 2759      CHICK-FIL-A #02603            CHICK-FIL-A
# 2769      CHICK-FIL-A #00551            CHICK-FIL-A
# 2770  PANERA BREAD #202950 P           PANERA BREAD
# 2771      CHICK-FIL-A #00551            CHICK-FIL-A
# 2774      CHICK-FIL-A #00551            CHICK-FIL-A
# 2783      CHICK-FIL-A #04488            CHICK-FIL-A
# 2784       STAR MARKET #3696            STAR MARKET
# 2785      CHICK-FIL-A #04488            CHICK-FIL-A
# 2811  DAVE & BUSTERS #106 TA         DAVE & BUSTERS
# 2817    BB DINER DRAPER #192        BB DINER DRAPER
# 2818            MAVERIK #538                MAVERIK
# 2827      CHICK-FIL-A #04827            CHICK-FIL-A
# 2837            CASEYS #3783                 CASEYS
# 2840            CASEYS #3783                 CASEYS
# 2841            CASEYS #3783                 CASEYS
# 2843            CASEYS #3403                 CASEYS
# 2846      CHICK-FIL-A #04721            CHICK-FIL-A
# 2847            CASEYS #2893                 CASEYS
# 2849            CASEYS #3571                 CASEYS
# 2856     LOVE'S #0704 INSIDE                 LOVE'S
# 2859            CASEYS #6170                 CASEYS
# 2862            CASEYS #3926                 CASEYS
# 2863            CASEYS #6170                 CASEYS
# 2907  PANERA BREAD #204737 O           PANERA BREAD
# 2909      CHICK-FIL-A #00374            CHICK-FIL-A
# 2919      CHICK-FIL-A #00374            CHICK-FIL-A
# 2943         KROGER #481 SL9                 KROGER
# 2950        CIRCLE K # 03662               CIRCLE K
# 2967    WM SUPERCENTER #4641         WM SUPERCENTER
# 2978        ARCO #42605 AMPM                   ARCO
# 3023  CRACKER BARREL #588 BR         CRACKER BARREL
# 3054            RUBIO'S #284                RUBIO'S
# 3055            RUBIO'S #284                RUBIO'S
# 3060            RUBIO'S #284                RUBIO'S
# 3087        SQ *TENN CAB #54           SQ *TENN CAB
# 3122       TIM HORTONS #1862            TIM HORTONS
# 3126       TIM HORTONS #2709            TIM HORTONS
# 3127  SHOPPERS DRUG MART #24     SHOPPERS DRUG MART
# 3142         WHITE SPOT #115             WHITE SPOT
# 3166     CHICK-FIL-A # 00864            CHICK-FIL-A
# 3168     CHICK-FIL-A # 00864            CHICK-FIL-A
# 3169              IHOP #3804                   IHOP
# 3189     TIM HORTONS #916362            TIM HORTONS
# 3198  PANERA BREAD #601975 K           PANERA BREAD
# 3200      CHICK-FIL-A #04603            CHICK-FIL-A
# 3203       TACO BELL #031977              TACO BELL
# 3223            CASEYS #3075                 CASEYS
# 3224             PUBLIX #212                 PUBLIX
# 3247      CHICK-FIL-A #03710            CHICK-FIL-A
# 3251    WM SUPERCENTER #2323         WM SUPERCENTER
# 3252    WM SUPERCENTER #2323         WM SUPERCENTER
# 3271   BP#8472839JJ'S #8 QPS                     BP
# 3273      WHOLEFDS NVL#10685           WHOLEFDS NVL
# 3274         WALGREENS #9778              WALGREENS
# 3322      WHOLEFDS NVL#10685           WHOLEFDS NVL
# 3347      CHICK-FIL-A #01664            CHICK-FIL-A
# 3378     WM SUPERCENTER #175         WM SUPERCENTER
# 3379      WM SUPERCENTER #62         WM SUPERCENTER
# 3386            PUBLIX #1266                 PUBLIX
# 3389            PUBLIX #1266                 PUBLIX
# 3390      PIGGLY WIGGLY #299          PIGGLY WIGGLY
# 3393              SPINX #364                  SPINX
# 3397            PUBLIX #1266                 PUBLIX
# 3404         KROGER #481 SL9                 KROGER
# 3406     WM SUPERCENTER #175         WM SUPERCENTER
# 3409          ZAXBY'S #51206                ZAXBY'S
# 3413          WAL-MART #0175               WAL-MART
# 3459      CHICK-FIL-A #00374            CHICK-FIL-A
# 3463       J ALEXANDER'S #30          J ALEXANDER'S
# 3486      CHICK-FIL-A #04018            CHICK-FIL-A
# 3497    WM SUPERCENTER #1959         WM SUPERCENTER
# 3519       J ALEXANDER'S #30          J ALEXANDER'S
# 3520      CHICK-FIL-A #04757            CHICK-FIL-A
# 3523          WAL-MART #0828               WAL-MART
# 3524          WAL-MART #0973               WAL-MART
# 3563        CIRCLE K # 23468               CIRCLE K
# 3567        CIRCLE K # 23401               CIRCLE K
# 3578      EXXON BLUESKY #493          EXXON BLUESKY
# 3581        CIRCLE K # 23421               CIRCLE K
# 3617            BUC-EE'S #58               BUC-EE'S
# 3622      CHICK-FIL-A #05091            CHICK-FIL-A
# 3660      CHICK-FIL-A #01387            CHICK-FIL-A
# 3670      CHICK-FIL-A #04694            CHICK-FIL-A
# 3692       TIM HORTONS #1594            TIM HORTONS
# 3693       TIM HORTONS #1594            TIM HORTONS
# 3694          HARVEY'S #2768               HARVEY'S
# 3695        PIZZA PIZZA # 34            PIZZA PIZZA
# 3697       TIM HORTONS #1571            TIM HORTONS
# 3712   JASON'S DELI BHR #076       JASON'S DELI BHR
# 3733            PUBLIX #1266                 PUBLIX
# 3734      CHICK-FIL-A #01570            CHICK-FIL-A
# 3735      CHICK-FIL-A #01570            CHICK-FIL-A
# 3771      CHICK-FIL-A #02997            CHICK-FIL-A
# 3774        TUDORS NITRO #71           TUDORS NITRO
# 3781            CASEYS #6438                 CASEYS
# 3789             PUBLIX #212                 PUBLIX
# 3796   PORTILLOS HOT DOGS #2     PORTILLOS HOT DOGS
# 3801      HARRIS TEETER #366          HARRIS TEETER
# 3802      CHICK-FIL-A #04388            CHICK-FIL-A
# 3811         JACK'S #228 Q08                 JACK'S
# 3864             PUBLIX #212                 PUBLIX
# 3865  BP#6155980GIANT #22QPS                     BP
# 3878             KROGER #387                 KROGER
# 3879          WAL-MART #0175               WAL-MART
# 3886     HARRIS TEETER #0033          HARRIS TEETER
# 3892      WHOLEFDS NVL#10685           WHOLEFDS NVL
# 3921  CRACKER BARREL #464 TR         CRACKER BARREL
# 3926            MEIJER # 193                 MEIJER
# 3943        PAPA JOHN'S #742            PAPA JOHN'S
# 3990      PRICE CHOPPER #135          PRICE CHOPPER
# 3992      CHICK-FIL-A #04028            CHICK-FIL-A
# 3997            MAVERIK #394                MAVERIK

# %% [markdown]
# ### Funcion para remover metodos de pago

# %%
def remove_payment_methods(word):
    payment_methods = ['TCB*', 'NIC*  ', 'CF* ', 'IN *', 'GLF*', 'WPY*', 'ZSK*', 'TLF*', 'TN*', 'PY *', 'PLACPAY*',
                       'L2G*', 'IC* ', 'B2P*', 'CCI*', 'CEP*', 'CKE*', 'EIG*', 'FSP*', 'HAD*', 'PAR*', 'PAYPAL *', 
                       'PMT*', 'PP*', 'SLICE*', 'SQ *', 'TST*', '4TE*', 'UEP*', 'ORACL*']
    
    for method in payment_methods:
        if word.startswith(method.strip()):
            word = word[len(method.strip()):].strip('*').strip()
    return word

# Aplicar la función remove_payment_methods a la columna 'SUPPLIER_ERP_HASH_TRIM'
df['SUPPLIER_ERP_REM_PAYME'] = df['SUPPLIER_ERP_HASH_TRIM'].apply(remove_payment_methods)

# Contar valores únicos antes y después de la operación
unique_before = df['SUPPLIER_ERP_HASH_TRIM'].nunique()
unique_after = df['SUPPLIER_ERP_REM_PAYME'].nunique()

# Imprimir el conteo distinto de valores antes y después de la operación
print(f"Distinct values before operation: {unique_before}")
print(f"Distinct values after operation: {unique_after}")

# Calcular el número de valores afectados por la operación
values_normalized = unique_before - unique_after
print(f"Number of values normalized through the function: {values_normalized}")

# Identificar las filas afectadas por la operación
changed_rows = df[df['SUPPLIER_ERP_HASH_TRIM'] != df['SUPPLIER_ERP_REM_PAYME']]

# Contar el número de filas afectadas por la operación
rows_affected = changed_rows.shape[0]
print(f"Number of rows affected by the remove payment methods function: {rows_affected}")

# Opcionalmente, mostrar las filas afectadas para revisión
changed_rows[['SUPPLIER_ERP_HASH_TRIM', 'SUPPLIER_ERP_REM_PAYME']]
# Out:
# Distinct values before operation: 1544
# Distinct values after operation: 1543
# Number of values normalized through the function: 1
# Number of rows affected by the remove payment methods function: 218
#       SUPPLIER_ERP_HASH_TRIM SUPPLIER_ERP_REM_PAYME
# 42         TST* TRILL BURGER           TRILL BURGER
# 46               TST* SOYA 2                 SOYA 2
# 151          TST* MI AMAICHE             MI AMAICHE
# 153   TST* MIDWOOD SMOKE HOU      MIDWOOD SMOKE HOU
# 193   TST* MCGHIN'S SOUTHERN      MCGHIN'S SOUTHERN
# 263   SQ *QUICK TRIGGER BREW     QUICK TRIGGER BREW
# 264     SQ *WILL-O-WISP CAFE       WILL-O-WISP CAFE
# 287    TST* MERCATO KITCHEN-       MERCATO KITCHEN-
# 288    TST* MERCATO KITCHEN-       MERCATO KITCHEN-
# 304    TST* SALT AND SMOKE -       SALT AND SMOKE -
# 310         TST* KINGSTON 10            KINGSTON 10
# 327   EIG*CONSTANTCONTACT.CO     CONSTANTCONTACT.CO
# 328    TST* SALT AND SMOKE -       SALT AND SMOKE -
# 343    TST* HATTIE B'S- WEST       HATTIE B'S- WEST
# 366   TST* NOTHING BUNDT CAK      NOTHING BUNDT CAK
# 367    TST* PAGES OKRA GRILL       PAGES OKRA GRILL
# 368   TST* NOTHING BUNDT CAK      NOTHING BUNDT CAK
# 393   TST* DRAKES - JEFFERSO      DRAKES - JEFFERSO
# 398   TST* THE FORGE PIZZA -      THE FORGE PIZZA -
# 400   TST* WILDFIRE PUBLIC H      WILDFIRE PUBLIC H
# 453   TST* THE PATRIOTIC PIG      THE PATRIOTIC PIG
# 503   TST* JAMBA JUICE - 061      JAMBA JUICE - 061
# 518   TST* WALK-ONS - POYDRA      WALK-ONS - POYDRA
# 525   TST* WYOMING RIB AND C      WYOMING RIB AND C
# 527   TST* THE ALBANY - CHEY      THE ALBANY - CHEY
# 533   TST* ANTHONY'S - CO-19      ANTHONY'S - CO-19
# 534   TST* ANTHONY'S - CO-19      ANTHONY'S - CO-19
# 560         PY *MCA FRESHENS           MCA FRESHENS
# 575          TST* JAPANEIROS             JAPANEIROS
# 585    SQ *CICALA'S PIZZERIA      CICALA'S PIZZERIA
# 593   TST* EBISU JAPANESE RE      EBISU JAPANESE RE
# 600   SQ *OSCAR'S VERY MEXIC     OSCAR'S VERY MEXIC
# 622   SQ *KURA REVOLVING SUS     KURA REVOLVING SUS
# 651    TST* TARTINE BAKERY -       TARTINE BAKERY -
# 654   TST* BOTTOM OF THE FIF      BOTTOM OF THE FIF
# 655             SQ *NEIGHBOR               NEIGHBOR
# 656      TCB*MTA METER MTA I        MTA METER MTA I
# 657      TCB*MTA METER MTA I        MTA METER MTA I
# 658      TCB*MTA METER MTA P        MTA METER MTA P
# 660   TST* HIGH FLYING FOODS      HIGH FLYING FOODS
# 666   TST* THE BREAKFAST CLU      THE BREAKFAST CLU
# 699        SQ *HOUSE OF SUBS          HOUSE OF SUBS
# 739    FSP*FLIGHT PARK VALET      FLIGHT PARK VALET
# 750    FSP*FLIGHT PARK VALET      FLIGHT PARK VALET
# 783   TST* CLUCKERS - SHEPHE      CLUCKERS - SHEPHE
# 810   TST* BARRYS BAGELS - M      BARRYS BAGELS - M
# 827    TST* BEES KNEES NORTH       BEES KNEES NORTH
# 831   SQ *MIAMI INTERNATIONA     MIAMI INTERNATIONA
# 862          TST* PREZZO PGA             PREZZO PGA
# 878       SQ *THE KEBAB SHOP         THE KEBAB SHOP
# 906   TST* SEMINOLE REEF GRI      SEMINOLE REEF GRI
# 924   TST* MURPHY'S LAW IRIS      MURPHY'S LAW IRIS
# 967       TST* CARL'S TAVERN          CARL'S TAVERN
# 974   TST* BAR LOUIE - PERRY      BAR LOUIE - PERRY
# 1010     TST* GIORGIOS PIZZA         GIORGIOS PIZZA
# 1019   TST* MAMASS DAUGHTERS       MAMASS DAUGHTERS
# 1031        SQ *ISLICE PIZZA           ISLICE PIZZA
# 1097  TST* NEWSLINK OF NASHV      NEWSLINK OF NASHV
# 1099  SQ *OLD SCHOOL CATERIN     OLD SCHOOL CATERIN
# 1102  TST* SPORTSBOOK- NEXTO      SPORTSBOOK- NEXTO
# 1105   TST* PAGES OKRA GRILL       PAGES OKRA GRILL
# 1131  SQ *THE CODFATHER PROP     THE CODFATHER PROP
# 1161            SQ *TAXI CAB               TAXI CAB
# 1171  SQ *BEST CITY GYRO 3 I     BEST CITY GYRO 3 I
# 1200   TST* FLEET STREET PUB       FLEET STREET PUB
# 1208  TST* NASHVILLE - BARIS      NASHVILLE - BARIS
# 1225  TST* SADIES OF NEW MEX      SADIES OF NEW MEX
# 1232  TST* SLIM & HUSKYS - 5      SLIM & HUSKYS - 5
# 1233  TST* SLIM & HUSKYS - 5      SLIM & HUSKYS - 5
# 1241   TST* WHICH WICH - IHA       WHICH WICH - IHA
# 1292      SQ *BUCKHEAD BOOKS         BUCKHEAD BOOKS
# 1298           TST* BRENNANS               BRENNANS
# 1299      PY *MCA BOARS HEAD         MCA BOARS HEAD
# 1315  SQ *U.S. DONUTS CORDOV     U.S. DONUTS CORDOV
# 1401      SQ *THE KEBAB SHOP         THE KEBAB SHOP
# 1405  TST* DOUBLE ROADS TAVE      DOUBLE ROADS TAVE
# 1540      ORACL*WAFFLE HOUSE           WAFFLE HOUSE
# 1565  TLF*IN BLOOM FLOWERS G     IN BLOOM FLOWERS G
# 1566   TST* LONE STAR EATERY       LONE STAR EATERY
# 1572  SQ *LA PRINCESA PIZZER     LA PRINCESA PIZZER
# 1578            TST* MALONES                MALONES
# 1579  TST* BAMBINELLIS - ROS      BAMBINELLIS - ROS
# 1606   TST* LAX - TERMINAL 3       LAX - TERMINAL 3
# 1653  TST* JAMBA JUICE - 061      JAMBA JUICE - 061
# 1660      TST* RED MANGO CLT          RED MANGO CLT
# 1690      TST* RED MANGO CLT          RED MANGO CLT
# 1710  TST* ROOSE & RYE - ATL      ROOSE & RYE - ATL
# 1737     SQ *BUCKHEAD MARKET        BUCKHEAD MARKET
# 1755  TST* THE FINCH - NASHV      THE FINCH - NASHV
# 1757  TST* EMMY SQUARED - GU      EMMY SQUARED - GU
# 1790  TST* THE LITTLE PEAR -      THE LITTLE PEAR -
# 1795  PAR*MR. PICKLES SANDWI     MR. PICKLES SANDWI
# 1803  TST* SUPER DUPER - CAS      SUPER DUPER - CAS
# 1808  SQ *L&L HAWAIIAN BARBE     L&L HAWAIIAN BARBE
# 1809  TST* TASTES ON THE FLY      TASTES ON THE FLY
# 1821  TST* 400 DEGREE HOT CH      400 DEGREE HOT CH
# 1884    TST* AVOCADO CANTINA        AVOCADO CANTINA
# 1886     SQ *FOOD ADVENTURES        FOOD ADVENTURES
# 1919       TST* ONE13 SOCIAL           ONE13 SOCIAL
# 1949   TST* GREENLEAF - JOHN       GREENLEAF - JOHN
# 1964      ORACL*WAFFLE HOUSE           WAFFLE HOUSE
# 1968  SQ *PJ'S COFFEE OF NEW     PJ'S COFFEE OF NEW
# 1977   TST* LE PETIT PARIS -       LE PETIT PARIS -
# 1978   TST* LE PETIT PARIS -       LE PETIT PARIS -
# 1981  SQ *VIC'S SANDWICH SHO     VIC'S SANDWICH SHO
# 1982  SQ *VIC'S SANDWICH SHO     VIC'S SANDWICH SHO
# 1992      SQ *RAINBOW DONUTS         RAINBOW DONUTS
# 2027  TST* CALIFORNIA DREAMI      CALIFORNIA DREAMI
# 2028  TST* VICIOUS BISCUIT -      VICIOUS BISCUIT -
# 2043  TST* LOUIS PAPPAS MARK      LOUIS PAPPAS MARK
# 2097  TST* FIDDLERS HEARTH P      FIDDLERS HEARTH P
# 2120     SQ *AMTC CAB DRIVER        AMTC CAB DRIVER
# 2122  TST* THE CAPITOL HOTEL      THE CAPITOL HOTEL
# 2123  SQ *ACE NASHVILLE TRAN     ACE NASHVILLE TRAN
# 2184        SQ *METALY OUMAR           METALY OUMAR
# 2193  TST* WALK-ONS - POYDRA      WALK-ONS - POYDRA
# 2195        TST* COPPER VINE            COPPER VINE
# 2197  TST* WALK-ONS - POYDRA      WALK-ONS - POYDRA
# 2206  CKE*COPPER CREEK PUB &     COPPER CREEK PUB &
# 2248      IC* INSTACART*2246         INSTACART*2246
# 2249  TST* HATTIE B'S- MIDTO      HATTIE B'S- MIDTO
# 2254  TST* 400 DEGREE HOT CH      400 DEGREE HOT CH
# 2310  TST* COCINA AND CANTIN      COCINA AND CANTIN
# 2311  TST* LADY NOMADA - ARV      LADY NOMADA - ARV
# 2314  TST* MORNING STORY - A      MORNING STORY - A
# 2336  SQ *ABELLAS'S CUBAN RE     ABELLAS'S CUBAN RE
# 2350     SQ *YUMMY DONUT INC        YUMMY DONUT INC
# 2397      SQ *STAGE LEFT MEM         STAGE LEFT MEM
# 3265  TST* LASALLE HOSPITALI      LASALLE HOSPITALI
# 3292         PP*CHINA GARDEN           CHINA GARDEN
# 3298   TST* ALAINAS CAFE AND       ALAINAS CAFE AND
# 3302  TST* NEVS BARBECUE LLC      NEVS BARBECUE LLC
# 3308         TST* YOUNG JONI             YOUNG JONI
# 3402     SQ *BUCKHEAD MARKET        BUCKHEAD MARKET
# 3415  TST* GUS'S WORLD FAMOU      GUS'S WORLD FAMOU
# 3450         SQ *AA MSY CURB            AA MSY CURB
# 3462    TST* AVOCADO CANTINA        AVOCADO CANTINA
# 3467        TST* COPPER VINE            COPPER VINE
# 3473         TST* WILLA JEAN             WILLA JEAN
# 3483  TST* C.R. CHICKS - ABA      C.R. CHICKS - ABA
# 3505  TST* M.L. ROSE CRAFT B      M.L. ROSE CRAFT B
# 3531       TST* VOODOO BAYOU           VOODOO BAYOU
# 3548        WPY*HINOKA SUSHI           HINOKA SUSHI
# 3551  TST* HIGH FLYING FOODS      HIGH FLYING FOODS
# 3590  TST* WALK-ONS - POYDRA      WALK-ONS - POYDRA
# 3592  TST* ACME OYSTER HOUSE      ACME OYSTER HOUSE
# 3600  TST* DAISY MAES - POYD      DAISY MAES - POYD
# 3607  FSP*PARK'N GO - ORLAND     PARK'N GO - ORLAND
# 3612  TST* CARA MIAS DELICAT      CARA MIAS DELICAT
# 3613  TST* CARA MIAS DELICAT      CARA MIAS DELICAT
# 3614  TST* MIDDENDORFS - SLI      MIDDENDORFS - SLI
# 3616  TST* ACME OYSTER HOUSE      ACME OYSTER HOUSE
# 3620  TST* ACME OYSTER HOUSE      ACME OYSTER HOUSE
# 3644  TLF*WINDMILL FLORAL EX     WINDMILL FLORAL EX
# 3652  TST* LIMONCELLO RISTOR      LIMONCELLO RISTOR
# 3674    TST* SAINT X BREWERY        SAINT X BREWERY
# 3676  SQ *HURTS DONUT COMPAN     HURTS DONUT COMPAN
# 3679      SQ *BUCKHEAD BOOKS         BUCKHEAD BOOKS
# 3683  TST* GUACAMOLE TAQUERI      GUACAMOLE TAQUERI
# 3710  EIG*CONSTANTCONTACT.CO     CONSTANTCONTACT.CO
# 3736      TST* JUXT TAPHOUSE          JUXT TAPHOUSE
# 3742  SQ *TAQUERIA EL REY 2.     TAQUERIA EL REY 2.
# 3758  SQ *TAQUERIA EL REY 2.     TAQUERIA EL REY 2.
# 3768  TST* NEWSLINK OF NASHV      NEWSLINK OF NASHV
# 3797  SQ *GOLDEN DRAGON CHIN     GOLDEN DRAGON CHIN
# 3799  TST* EGG HARBOR CAFE -      EGG HARBOR CAFE -
# 3815      SQ *DAYLIGHT DONUT         DAYLIGHT DONUT
# 3819   TST* THE GUMBO BROS -       THE GUMBO BROS -
# 3833  TST* TOGO'S - WOODLAND      TOGO'S - WOODLAND
# 3853         TST* FRESHENS 2             FRESHENS 2
# 3937                PY *SAME                   SAME
# 3945  TST* IGUANA JOES - BEL      IGUANA JOES - BEL
# 3946   TST* IGUANA JOES MONT       IGUANA JOES MONT
# 3987  TST* PICKLE BARREL DEL      PICKLE BARREL DEL

# %% [markdown]
# ### Funcion para caracteres especiales

# %%
def finalize_name_cleaning(word):
    # Reemplazar caracteres específicos
    chars_to_remove = ['$', '%', '^', '#', '(', ')', '[', ']', ';', ':', '"', "'", ',', '’', '-', '/', '°']
    for char in chars_to_remove:
        word = word.replace(char, ' ')

    # Reemplazar espacios adicionales por un solo espacio
    word = ' '.join(word.split())

    # Chequear si el nombre contiene dominios importantes
    to_keep = ['.COM', '.com', '.ORG', '.org', '.NET', '.net', 'WWW.', 'www.']
    if any(keep in word for keep in to_keep):
        return word
    else:
        # Eliminar puntos y convertir a mayúsculas si no contiene dominios especiales
        word = word.replace('.', '').upper()

    return word

# Ejemplo de aplicación de la función
df['SUPPLIER_CLEANED_FINAL'] = df['SUPPLIER_ERP_REM_PAYME'].apply(finalize_name_cleaning)

# Contar valores únicos antes y después de la limpieza final
unique_before_final = df['SUPPLIER_ERP_REM_PAYME'].nunique()
unique_after_final = df['SUPPLIER_CLEANED_FINAL'].nunique()

print(f"Distinct values before final cleaning: {unique_before_final}")
print(f"Distinct values after final cleaning: {unique_after_final}")

# Calcular el número de valores unificados por la función de limpieza final
values_unified = unique_before_final - unique_after_final
print(f"Number of values unified through the final cleaning function: {values_unified}")

# Identificar las filas afectadas por la limpieza final
changed_rows_final = df[df['SUPPLIER_ERP_REM_PAYME'] != df['SUPPLIER_CLEANED_FINAL']]

# Contar el número de filas afectadas por la limpieza final
rows_affected_final = changed_rows_final.shape[0]
print(f"Number of rows affected by the final cleaning function: {rows_affected_final}")

# Mostrar las filas afectadas para revisión (opcional)
changed_rows_final[['SUPPLIER_ERP_REM_PAYME', 'SUPPLIER_CLEANED_FINAL']]
# Out:
# Distinct values before final cleaning: 1543
# Distinct values after final cleaning: 1516
# Number of values unified through the final cleaning function: 27
# Number of rows affected by the final cleaning function: 692
#                                  SUPPLIER_ERP_REM_PAYME  \
# 4                                               EATZI'S
# 7                                      BNA JIMMY JOHN'S
# 9                                             Pitt Stop
# 14                                             WAL-MART
# 33                                            Microsoft
# 38                                PLAYITA'S RESTAURANTE
# 39                               LOS COMPADRES MEXICAN-
# 40                                 DD *STORECHICK-FIL-A
# 43                                CITY CREEK BURGER CO.
# 44                                              Sunbizz
# 45                                  FRESH KITCHEN-DAVIE
# 47                                  FRESH KITCHEN-DAVIE
# 48                               Chipotle Mexican Grill
# 107                              MCKAY PRESS, AN RRD CO
# 129                                   WINGS, ETC. CAMBY
# 154                                             ZAXBY'S
# 159                                            BUC-EE'S
# 172                              2099-CLT CHARLOTTE'S G
# 178                               CITYOFSTLOUIS-LAMBERT
# 192                                       DOMINO'S 8055
# 193                                   MCGHIN'S SOUTHERN
# 201                                            BUC-EE'S
# 206                                         WENDY'S 802
# 211                                     BOJANGLES' 1330
# 213                               Glass City Steakhouse
# 241                                  KWIK PARKING, INC.
# 259                                EXXON 7-ELEVEN 41053
# 261                                             EZ Pass
# 262                                         CHICK-FIL-A
# 264                                    WILL-O-WISP CAFE
# 287                                    MERCATO KITCHEN-
# 288                                    MERCATO KITCHEN-
# 304                                    SALT AND SMOKE -
# 313                                 JETS PIZZA - MN-006
# 315                                       DOMINO'S 3945
# 325                                              LOVE'S
# 327                                  CONSTANTCONTACT.CO
# 328                                    SALT AND SMOKE -
# 334                                EXXON 7-ELEVEN 41069
# 343                                    HATTIE B'S- WEST
# 346                                           Marshalls
# 349                                        BAKERS - 121
# 356                              CAFE BEIGNET (DECATUR)
# 364                                                Etsy
# 365                                        ITT Training
# 370                                      DOLLAR-GENERAL
# 371                                      DOLLAR-GENERAL
# 373                              MCKAY PRESS, AN RRD CO
# 393                                   DRAKES - JEFFERSO
# 398                                   THE FORGE PIZZA -
# 409                                          Enterprise
# 419                                      7-ELEVEN 17647
# 421                              76 - THE ROSEVILLE STA
# 428                                          Enterprise
# 438                               TENNESSEE TRIBUNE 1 -
# 444                                          Enterprise
# 445                                          Enterprise
# 472                                         CHICK-FIL-A
# 487                              2075-CLT CNBC NEWS C 1
# 499                                 AUNTIE ANNE'S-NC136
# 503                                   JAMBA JUICE - 061
# 518                                   WALK-ONS - POYDRA
# 527                                   THE ALBANY - CHEY
# 533                                   ANTHONY'S - CO-19
# 534                                   ANTHONY'S - CO-19
# 559                                         CHICK-FIL-A
# 568                                            BUC-EE'S
# 570                                       DOMINO'S 6671
# 572                              SHIPLEY DO-NUTS - FC64
# 585                                   CICALA'S PIZZERIA
# 594   New York State Department of Finance and Taxation
# 595   New York State Department of Taxation and Finance
# 596   New York State Department of Taxation and Finance
# 599                                         CHICK-FIL-A
# 600                                  OSCAR'S VERY MEXIC
# 603                              KOLACHE FACTORY - CAST
# 605                               KOPP'S CUSTARD LAYTON
# 607                                         CHICK-FIL-A
# 618                                   FREMONT T/P-CITGO
# 623                                 National Car Rental
# 624                                 National Car Rental
# 628                                EXXON 7-ELEVEN 34718
# 629                                EXXON 7-ELEVEN 34718
# 632                                            WAL-MART
# 636                                             DENNY'S
# 637                                             WENDY'S
# 648                                LOS CUCOS - KINGWOOD
# 651                                    TARTINE BAKERY -
# 652                                      BI-RITE MARKET
# 689                                      POPEYE'S 13872
# 693                                 National Car Rental
# 708                                              LOVE'S
# 710                               CAFE SABOR ST. GEORGE
# 713                                      7-ELEVEN 38710
# 714                                 CHILI'S GRILL & BAR
# 723                                         CHICK-FIL-A
# 726                                76 - A & E FUELS INC
# 737                                         CHICK-FIL-A
# 755                              GIORDANO'S OF GREEKTOW
# 756                                    CLINTON/HARRISON
# 759                                               DD/BR
# 761                                    CLINTON/HARRISON
# 773                              JIMMY JOHNS - 580 - MI
# 779                                  JIMMY JOHNS - 2695
# 780                              WWW.DICKEYS.* SN: 2236
# 783                                   CLUCKERS - SHEPHE
# 798                                  CHILI'S C EAST MSY
# 808                                            Wingstop
# 809                              Mountain View Car Wash
# 810                                   BARRYS BAGELS - M
# 815                              DELI- LICIOUS CUCINA N
# 816                              JIMMY JOHNS 2543 - ECO
# 817                              JIMMY JOHNS 2543 - ECO
# 3047                          John Darrow Chain Control
# 3048                                 Chain installer 62
# 3050                                           Caltrans
# 3051                                           Caltrans
# 3054                                            RUBIO'S
# 3055                                            RUBIO'S
# 3060                                            RUBIO'S
# 3064                             REDLANDS BITE-CAFISHGR
# 3066                                           Circle K
# 3067                                             Amazon
# 3068                                             Amazon
# 3102                             HICKORY TAVERN - COLUM
# 3108                                Chili's Grill & Bar
# 3109                                Salute Market Place
# 3112                                            Birdies
# 3135                              2054-WIN THE EXCHANGE
# 3137                             3771-EDMT RELAY/RED CA
# 3143                             TST-TASTES ON THE FLY-
# 3146                              0835-VAN RELAY PIER C
# 3148                             SMILIE'S PLACE RESTAUR
# 3151                             3771-EDMT RELAY/RED CA
# 3152                             1859-TOR 6 & SUNDRY T3
# 3161                                   PIKEPASS ON-LINE
# 3165                                  FREDDY'S 112-0003
# 3166                                        CHICK-FIL-A
# 3168                                        CHICK-FIL-A
# 3174                             JIMMY JOHNS 2543 - ECO
# 3199                                  BAJA FISH TACOS -
# 3200                                        CHICK-FIL-A
# 3209                             HONEY DEW DONUTS - NEW
# 3217                                          Wings Ect
# 3219                                   CHILI'S ESPANOLA
# 3221                                  RUDY'S COUNTRY ST
# 3230                             IN-N-OUT SAN JUAN CAPO
# 3246                             PARK MGM/NOMAD-ADV DEP
# 3247                                        CHICK-FIL-A
# 3248                             DAVID'S BURGERS GATEWA
# 3249                             DAVID'S BURGERS GATEWA
# 3254                                             I-Pass
# 3255                                             United
# 3276                                             United
# 3283                                        Katie Giani
# 3294                             JIMMY JOHNS 2543 - ECO
# 3306                          In Aa- Tender Retail (par
# 3307                                            Parkind
# 3336                             CAFE BEIGNET (DECATUR)
# 3347                                        CHICK-FIL-A
# 3355                                FAMOUS DAVE'S- YUMA
# 3357                                 BLUE MOOSE - ALCOA
# 3358                                 Nothin But Chicken
# 3372                                          Red robin
# 3373                                      Slim chickens
# 3381                                           CHUBBY'S
# 3394                                MARCOS PIZZA - 8267
# 3395                                MARCOS PIZZA - 8267
# 3409                                            ZAXBY'S
# 3413                                           WAL-MART
# 3415                                  GUS'S WORLD FAMOU
# 3420                               CORKY'S COLLIERVILLE
# 3435                                        Shake Shack
# 3436                   Palm Beach International Airport
# 3437                                    Voodoo Doughnut
# 3439                                           Ali Taxi
# 3459                                        CHICK-FIL-A
# 3463                                      J ALEXANDER'S
# 3482                             AUNTIE ANNE'S - NC 156
# 3483                                  C.R. CHICKS - ABA
# 3486                                        CHICK-FIL-A
# 3505                                  M.L. ROSE CRAFT B
# 3506                                349 - AKA @ RESORTS
# 3510                                   ARIA - ADV SALES
# 3519                                      J ALEXANDER'S
# 3520                                        CHICK-FIL-A
# 3523                                           WAL-MART
# 3524                                           WAL-MART
# 3525                             JIMMY JOHNS 2543 - ECO
# 3540                                   LUCKY DOGS MSY-C
# 3545                                           Fastrack
# 3582                                        Whataburger
# 3587                                         ADOBE INC.
# 3590                                  WALK-ONS - POYDRA
# 3596                                     Wolf Bay Lodge
# 3600                                  DAISY MAES - POYD
# 3602                             1928 GREEN LEAFS / BAN
# 3607                                 PARK'N GO - ORLAND
# 3614                                  MIDDENDORFS - SLI
# 3617                                           BUC-EE'S
# 3622                                        CHICK-FIL-A
# 3633                             VENETIAN/PALAZZO FRT D
# 3636                               TRUETTS CHICK-FIL-A-
# 3639                                        Omni Hotels
# 3645                                     NYNY - ADV DEP
# 3646                            Teller Machine in Hotel
# 3650                               DOLPHIN/KEY/NAS LIMO
# 3651                               DOLPHIN/KEY/NAS LIMO
# 3653                                            EZ Pass
# 3654                                      WENDYS 193-19
# 3660                                        CHICK-FIL-A
# 3664                                      WENDYS 193-19
# 3670                                        CHICK-FIL-A
# 3671                             MANCINO'S PIZZA AND GR
# 3677                                 CHILI'S C EAST MSY
# 3681                             TOOJAY'S - BLUFFS SHOP
# 3682                             TOOJAY'S - BLUFFS SHOP
# 3684                             DELI- LICIOUS CUCINA N
# 3687                              TST-TAHINIS - 1913 HO
# 3688                              TST-TAHINIS - 1922 YO
# 3694                                           HARVEY'S
# 3707                               ELLIOTT'S STEAKHOUSE
# 3710                                 CONSTANTCONTACT.CO
# 3712                                   JASON'S DELI BHR
# 3713                                AMERICAN DELI 188-1
# 3716                                           Dominoes
# 3717                                     AFP Industries
# 3719                                         Home depot
# 3725                                Summerville Chamber
# 3726                                   Stickers banners
# 3732                                   Sherwin Williams
# 3734                                        CHICK-FIL-A
# 3735                                        CHICK-FIL-A
# 3742                                 TAQUERIA EL REY 2.
# 3758                                 TAQUERIA EL REY 2.
# 3769                               Martinez scrap corp.
# 3771                                        CHICK-FIL-A
# 3775                            Ace Hardware Homecenter
# 3776                                     The Home Depot
# 3777                                     The Home Depot
# 3778                             LOMELI'S INT'L SUPERMA
# 3784                             CNP NICK'S TOMATO C PB
# 3795                             CHILI'S MILLER PARK WA
# 3799                                  EGG HARBOR CAFE -
# 3802                                        CHICK-FIL-A
# 3811                                             JACK'S
# 3816                                          Monoprice
# 3819                                   THE GUMBO BROS -
# 3832                                            FasTrak
# 3833                                  TOGO'S - WOODLAND
# 3856                                      Choice Hotels
# 3862                                     ATL VARASANO'S
# 3872                                   LinkedIn Recruit
# 3873                                   LinkedIn Recruit
# 3879                                           WAL-MART
# 3893                              TENNESSEE TRIBUNE 1 -
# 3902                                      NEWSLINK C.08
# 3904                              HY-VEE PAPILLION 1514
# 3929                             JIMMY JOHNS - 471 - EC
# 3942                               DD *STORECHICK-FIL-A
# 3943                                        PAPA JOHN'S
# 3944                             SHIPLEY DO-NUTS - FC62
# 3945                                  IGUANA JOES - BEL
# 3949                             The Cheesecake Factory
# 3973                                   FREDDY'S 02-0030
# 3980                                  MAX'S GOURMET INC
# 3981                                     7-ELEVEN 41361
# 3982                                     7-ELEVEN 41361
# 3984                                     7-ELEVEN 41361
# 3986                                     7-ELEVEN 41361
# 3988                                        Byrne Dairy
# 3991                         Wyndham Hotels and Resorts
# 3992                                        CHICK-FIL-A
# 3993                                          Microsoft
#
#                                  SUPPLIER_CLEANED_FINAL
# 4                                               EATZI S
# 7                                      BNA JIMMY JOHN S
# 9                                             PITT STOP
# 14                                             WAL MART
# 33                                            MICROSOFT
# 38                                PLAYITA S RESTAURANTE
# 39                                LOS COMPADRES MEXICAN
# 40                                 DD *STORECHICK FIL A
# 43                                 CITY CREEK BURGER CO
# 44                                              SUNBIZZ
# 45                                  FRESH KITCHEN DAVIE
# 47                                  FRESH KITCHEN DAVIE
# 48                               CHIPOTLE MEXICAN GRILL
# 107                               MCKAY PRESS AN RRD CO
# 129                                     WINGS ETC CAMBY
# 154                                             ZAXBY S
# 159                                            BUC EE S
# 172                              2099 CLT CHARLOTTE S G
# 178                               CITYOFSTLOUIS LAMBERT
# 192                                       DOMINO S 8055
# 193                                   MCGHIN S SOUTHERN
# 201                                            BUC EE S
# 206                                         WENDY S 802
# 211                                      BOJANGLES 1330
# 213                               GLASS CITY STEAKHOUSE
# 241                                    KWIK PARKING INC
# 259                                EXXON 7 ELEVEN 41053
# 261                                             EZ PASS
# 262                                         CHICK FIL A
# 264                                    WILL O WISP CAFE
# 287                                     MERCATO KITCHEN
# 288                                     MERCATO KITCHEN
# 304                                      SALT AND SMOKE
# 313                                   JETS PIZZA MN 006
# 315                                       DOMINO S 3945
# 325                                              LOVE S
# 327                                   CONSTANTCONTACTCO
# 328                                      SALT AND SMOKE
# 334                                EXXON 7 ELEVEN 41069
# 343                                     HATTIE B S WEST
# 346                                           MARSHALLS
# 349                                          BAKERS 121
# 356                                CAFE BEIGNET DECATUR
# 364                                                ETSY
# 365                                        ITT TRAINING
# 370                                      DOLLAR GENERAL
# 371                                      DOLLAR GENERAL
# 373                               MCKAY PRESS AN RRD CO
# 393                                     DRAKES JEFFERSO
# 398                                     THE FORGE PIZZA
# 409                                          ENTERPRISE
# 419                                      7 ELEVEN 17647
# 421                                76 THE ROSEVILLE STA
# 428                                          ENTERPRISE
# 438                                 TENNESSEE TRIBUNE 1
# 444                                          ENTERPRISE
# 445                                          ENTERPRISE
# 472                                         CHICK FIL A
# 487                              2075 CLT CNBC NEWS C 1
# 499                                 AUNTIE ANNE S NC136
# 503                                     JAMBA JUICE 061
# 518                                     WALK ONS POYDRA
# 527                                     THE ALBANY CHEY
# 533                                     ANTHONY S CO 19
# 534                                     ANTHONY S CO 19
# 559                                         CHICK FIL A
# 568                                            BUC EE S
# 570                                       DOMINO S 6671
# 572                                SHIPLEY DO NUTS FC64
# 585                                   CICALA S PIZZERIA
# 594   NEW YORK STATE DEPARTMENT OF FINANCE AND TAXATION
# 595   NEW YORK STATE DEPARTMENT OF TAXATION AND FINANCE
# 596   NEW YORK STATE DEPARTMENT OF TAXATION AND FINANCE
# 599                                         CHICK FIL A
# 600                                  OSCAR S VERY MEXIC
# 603                                KOLACHE FACTORY CAST
# 605                               KOPP S CUSTARD LAYTON
# 607                                         CHICK FIL A
# 618                                   FREMONT T P CITGO
# 623                                 NATIONAL CAR RENTAL
# 624                                 NATIONAL CAR RENTAL
# 628                                EXXON 7 ELEVEN 34718
# 629                                EXXON 7 ELEVEN 34718
# 632                                            WAL MART
# 2769                                        CHICK FIL A
# 2771                                        CHICK FIL A
# 2774                                        CHICK FIL A
# 2775                              93577 ATLANTA AIRPORT
# 2780                                   JIMMY JOHNS 4455
# 2783                                        CHICK FIL A
# 2785                                        CHICK FIL A
# 2786                             O BRIEN S GENERAL STOR
# 2795                              93577 ATLANTA AIRPORT
# 2803                                       WENDY S 0062
# 2805                                 U DOT EXPRESS LANE
# 2807                                    HIRES BIG H SLC
# 2810                                            MOLLY S
# 2827                                        CHICK FIL A
# 2835                                   JIMMY JOHNS 2025
# 2836                                   JIMMY JOHNS 2025
# 2842                                   FREDDY S 01 0009
# 2846                                        CHICK FIL A
# 2853                               BJ S RESTAURANTS 526
# 2856                                             LOVE S
# 2860                                      WENDY S 10680
# 2872                                       WIFI ONBOARD
# 2873               INTERINDUSTRIAS OPERADORA DE HOTELES
# 2874                                 LOS TRES POTRILLOS
# 2875                          EL PILÓN DE LOS ARRIERGOS
# 2876                                   HOTEL EL TAPATIO
# 2877                                     SÚPER FARMACIA
# 2878                                         HOTEL EXPO
# 2879                             LOS MILAGROS DE DALILA
# 2880                                            LA LAJA
# 2881                       RADISSON TAPATIO GUADALAJARA
# 2882                       RADISSON TAPATIO GUADALAJARA
# 2883                       RADISSON TAPATIO GUADALAJARA
# 2884                       RADISSON TAPATIO GUADALAJARA
# 2885                       RADISSON TAPATIO GUADALAJARA
# 2886                       RADISSON TAPATIO GUADALAJARA
# 2887                                             VIASAT
# 2888                                   MARNAPA SA DE CV
# 2890                                             VIASAT
# 2901                               TWIN PEAKS WEST PALM
# 2909                                        CHICK FIL A
# 2919                                        CHICK FIL A
# 2921                              93580 ATLANTA AIRPORT
# 2928                                            WENDY S
# 2951                                            EZ PASS
# 2964                                      SMOKIN DAVE S
# 2966                                               TOLL
# 2969                                 FRESHDONUTSLLC DBA
# 2970                                     7 ELEVEN 35623
# 2973                                     KF 087 SHAWNEE
# 3006                                  BEAR S SMOKEHOUSE
# 3021                                    SPON DIVITS INC
# 3025                                        EXPRESSTOLL
# 3037                                           RITE AID
# 3038                                            SAFEWAY
# 3039                              CRUISE IN TIRE CHAINS
# 3040                          JOHN DARROW CHAIN CONTROL
# 3041                          JOHN DARROW CHAIN CONTROL
# 3042                                CHAIN INSTALLER 002
# 3043                          JOHN DARROW CHAIN CONTROL
# 3044                                CHAIN INSTALLER 250
# 3045                                CHAIN INSTALLER 250
# 3046                                CHAIN INSTALLER 360
# 3047                          JOHN DARROW CHAIN CONTROL
# 3048                                 CHAIN INSTALLER 62
# 3050                                           CALTRANS
# 3051                                           CALTRANS
# 3054                                            RUBIO S
# 3055                                            RUBIO S
# 3060                                            RUBIO S
# 3064                             REDLANDS BITE CAFISHGR
# 3066                                           CIRCLE K
# 3067                                             AMAZON
# 3068                                             AMAZON
# 3102                               HICKORY TAVERN COLUM
# 3108                                CHILI S GRILL & BAR
# 3109                                SALUTE MARKET PLACE
# 3112                                            BIRDIES
# 3135                              2054 WIN THE EXCHANGE
# 3137                             3771 EDMT RELAY RED CA
# 3143                              TST TASTES ON THE FLY
# 3146                              0835 VAN RELAY PIER C
# 3148                             SMILIE S PLACE RESTAUR
# 3151                             3771 EDMT RELAY RED CA
# 3152                             1859 TOR 6 & SUNDRY T3
# 3161                                   PIKEPASS ON LINE
# 3165                                  FREDDY S 112 0003
# 3166                                        CHICK FIL A
# 3168                                        CHICK FIL A
# 3174                               JIMMY JOHNS 2543 ECO
# 3199                                    BAJA FISH TACOS
# 3200                                        CHICK FIL A
# 3209                               HONEY DEW DONUTS NEW
# 3217                                          WINGS ECT
# 3219                                   CHILI S ESPANOLA
# 3221                                  RUDY S COUNTRY ST
# 3230                             IN N OUT SAN JUAN CAPO
# 3246                             PARK MGM NOMAD ADV DEP
# 3247                                        CHICK FIL A
# 3248                             DAVID S BURGERS GATEWA
# 3249                             DAVID S BURGERS GATEWA
# 3254                                             I PASS
# 3255                                             UNITED
# 3276                                             UNITED
# 3283                                        KATIE GIANI
# 3294                               JIMMY JOHNS 2543 ECO
# 3306                            IN AA TENDER RETAIL PAR
# 3307                                            PARKIND
# 3336                               CAFE BEIGNET DECATUR
# 3347                                        CHICK FIL A
# 3355                                 FAMOUS DAVE S YUMA
# 3357                                   BLUE MOOSE ALCOA
# 3358                                 NOTHIN BUT CHICKEN
# 3372                                          RED ROBIN
# 3373                                      SLIM CHICKENS
# 3381                                           CHUBBY S
# 3394                                  MARCOS PIZZA 8267
# 3395                                  MARCOS PIZZA 8267
# 3409                                            ZAXBY S
# 3413                                           WAL MART
# 3415                                  GUS S WORLD FAMOU
# 3420                               CORKY S COLLIERVILLE
# 3435                                        SHAKE SHACK
# 3436                   PALM BEACH INTERNATIONAL AIRPORT
# 3437                                    VOODOO DOUGHNUT
# 3439                                           ALI TAXI
# 3459                                        CHICK FIL A
# 3463                                      J ALEXANDER S
# 3482                               AUNTIE ANNE S NC 156
# 3483                                      CR CHICKS ABA
# 3486                                        CHICK FIL A
# 3505                                    ML ROSE CRAFT B
# 3506                                  349 AKA @ RESORTS
# 3510                                     ARIA ADV SALES
# 3519                                      J ALEXANDER S
# 3520                                        CHICK FIL A
# 3523                                           WAL MART
# 3524                                           WAL MART
# 3525                               JIMMY JOHNS 2543 ECO
# 3540                                   LUCKY DOGS MSY C
# 3545                                           FASTRACK
# 3582                                        WHATABURGER
# 3587                                          ADOBE INC
# 3590                                    WALK ONS POYDRA
# 3596                                     WOLF BAY LODGE
# 3600                                    DAISY MAES POYD
# 3602                               1928 GREEN LEAFS BAN
# 3607                                   PARK N GO ORLAND
# 3614                                    MIDDENDORFS SLI
# 3617                                           BUC EE S
# 3622                                        CHICK FIL A
# 3633                             VENETIAN PALAZZO FRT D
# 3636                                TRUETTS CHICK FIL A
# 3639                                        OMNI HOTELS
# 3645                                       NYNY ADV DEP
# 3646                            TELLER MACHINE IN HOTEL
# 3650                               DOLPHIN KEY NAS LIMO
# 3651                               DOLPHIN KEY NAS LIMO
# 3653                                            EZ PASS
# 3654                                      WENDYS 193 19
# 3660                                        CHICK FIL A
# 3664                                      WENDYS 193 19
# 3670                                        CHICK FIL A
# 3671                             MANCINO S PIZZA AND GR
# 3677                                 CHILI S C EAST MSY
# 3681                               TOOJAY S BLUFFS SHOP
# 3682                               TOOJAY S BLUFFS SHOP
# 3684                              DELI LICIOUS CUCINA N
# 3687                                TST TAHINIS 1913 HO
# 3688                                TST TAHINIS 1922 YO
# 3694                                           HARVEY S
# 3707                               ELLIOTT S STEAKHOUSE
# 3710                                  CONSTANTCONTACTCO
# 3712                                   JASON S DELI BHR
# 3713                                AMERICAN DELI 188 1
# 3716                                           DOMINOES
# 3717                                     AFP INDUSTRIES
# 3719                                         HOME DEPOT
# 3725                                SUMMERVILLE CHAMBER
# 3726                                   STICKERS BANNERS
# 3732                                   SHERWIN WILLIAMS
# 3734                                        CHICK FIL A
# 3735                                        CHICK FIL A
# 3742                                  TAQUERIA EL REY 2
# 3758                                  TAQUERIA EL REY 2
# 3769                                MARTINEZ SCRAP CORP
# 3771                                        CHICK FIL A
# 3775                            ACE HARDWARE HOMECENTER
# 3776                                     THE HOME DEPOT
# 3777                                     THE HOME DEPOT
# 3778                             LOMELI S INT L SUPERMA
# 3784                             CNP NICK S TOMATO C PB
# 3795                             CHILI S MILLER PARK WA
# 3799                                    EGG HARBOR CAFE
# 3802                                        CHICK FIL A
# 3811                                             JACK S
# 3816                                          MONOPRICE
# 3819                                     THE GUMBO BROS
# 3832                                            FASTRAK
# 3833                                    TOGO S WOODLAND
# 3856                                      CHOICE HOTELS
# 3862                                     ATL VARASANO S
# 3872                                   LINKEDIN RECRUIT
# 3873                                   LINKEDIN RECRUIT
# 3879                                           WAL MART
# 3893                                TENNESSEE TRIBUNE 1
# 3902                                       NEWSLINK C08
# 3904                              HY VEE PAPILLION 1514
# 3929                                 JIMMY JOHNS 471 EC
# 3942                               DD *STORECHICK FIL A
# 3943                                        PAPA JOHN S
# 3944                               SHIPLEY DO NUTS FC62
# 3945                                    IGUANA JOES BEL
# 3949                             THE CHEESECAKE FACTORY
# 3973                                   FREDDY S 02 0030
# 3980                                  MAX S GOURMET INC
# 3981                                     7 ELEVEN 41361
# 3982                                     7 ELEVEN 41361
# 3984                                     7 ELEVEN 41361
# 3986                                     7 ELEVEN 41361
# 3988                                        BYRNE DAIRY
# 3991                         WYNDHAM HOTELS AND RESORTS
# 3992                                        CHICK FIL A
# 3993                                          MICROSOFT

# %% [markdown]
# ### Funcion para remover numeros a la derecha

# %%
def remove_trailing_numbers(text):
    # Utiliza una expresión regular para eliminar números al final de la cadena
    return re.sub(r'\d+$', '', text).strip()

# Supongamos que df es tu DataFrame y que ya tiene una columna 'SUPPLIER_CLEANED_FINAL'
# que deseamos limpiar más.
df['SUPPLIER_NO_TRAIL_NUM'] = df['SUPPLIER_CLEANED_FINAL'].apply(remove_trailing_numbers)

# Contar valores únicos antes y después de la eliminación de números al final
unique_before = df['SUPPLIER_CLEANED_FINAL'].nunique()
unique_after = df['SUPPLIER_NO_TRAIL_NUM'].nunique()

# Imprimir el conteo de valores únicos
print(f"Distinct values before removing trailing numbers: {unique_before}")
print(f"Distinct values after removing trailing numbers: {unique_after}")

# Calcular el número de valores unificados por la función
values_unified = unique_before - unique_after
print(f"Number of values unified by removing trailing numbers: {values_unified}")

# Identificar las filas afectadas por la función
changed_rows = df[df['SUPPLIER_CLEANED_FINAL'] != df['SUPPLIER_NO_TRAIL_NUM']]

# Contar el número de filas afectadas por la función
rows_affected = changed_rows.shape[0]
print(f"Number of rows affected by removing trailing numbers: {rows_affected}")

# Mostrar las filas afectadas para revisión (opcional)
changed_rows[['SUPPLIER_CLEANED_FINAL', 'SUPPLIER_NO_TRAIL_NUM']]
# Out:
# Distinct values before removing trailing numbers: 1516
# Distinct values after removing trailing numbers: 1304
# Number of values unified by removing trailing numbers: 212
# Number of rows affected by removing trailing numbers: 442
#         SUPPLIER_CLEANED_FINAL  SUPPLIER_NO_TRAIL_NUM
# 0      AMERICAN 00180953551262               AMERICAN
# 10          THE UPS STORE 7592          THE UPS STORE
# 11      JETBLUE 27970588201065                JETBLUE
# 15      AMERICAN 0014430352586               AMERICAN
# 18      AMERICAN 0014430554307               AMERICAN
# 20       WHERE TRAVELER ST2859      WHERE TRAVELER ST
# 21       CAPITOL FILE TEMP 553      CAPITOL FILE TEMP
# 37             FIVE BELOW 1152             FIVE BELOW
# 46                      SOYA 2                   SOYA
# 130        WHITE CASTLE 050039           WHITE CASTLE
# 137             CIRCLE K 02301               CIRCLE K
# 142                  PILOT 286                  PILOT
# 150              BOJANGLES 265              BOJANGLES
# 160      LOGANS ROADHOUSE 3369       LOGANS ROADHOUSE
# 169               OUTBACK 3430                OUTBACK
# 170             APPLEBEES 7883              APPLEBEES
# 176                    QT 1022                     QT
# 177                    QT 1022                     QT
# 182        LONG JOHN SILVERS 6      LONG JOHN SILVERS
# 187           RED LOBSTER 0253            RED LOBSTER
# 192              DOMINO S 8055               DOMINO S
# 196           WHATABURGER 1297            WHATABURGER
# 197            HARDEES 1501805                HARDEES
# 206                WENDY S 802                WENDY S
# 211             BOJANGLES 1330              BOJANGLES
# 217     CINCINNATI AIRPORT 986     CINCINNATI AIRPORT
# 246     CINCINNATI AIRPORT 986     CINCINNATI AIRPORT
# 258                  CNNST2705                  CNNST
# 259       EXXON 7 ELEVEN 41053         EXXON 7 ELEVEN
# 303       NORTON *AP1517379992             NORTON *AP
# 310                KINGSTON 10               KINGSTON
# 311                  MAGGIES 2                MAGGIES
# 312            HARDEES 1501056                HARDEES
# 313          JETS PIZZA MN 006          JETS PIZZA MN
# 315              DOMINO S 3945               DOMINO S
# 324          CASEYS STORE 4250           CASEYS STORE
# 329             APPLEBEES 8123              APPLEBEES
# 334       EXXON 7 ELEVEN 41069         EXXON 7 ELEVEN
# 348           STAPLES 00113522                STAPLES
# 349                 BAKERS 121                 BAKERS
# 351           STAPLES 00111096                STAPLES
# 390     HOU AIRP GASTROHUB F11   HOU AIRP GASTROHUB F
# 394       JACK IN THE BOX 4334        JACK IN THE BOX
# 404          TACO BELL 0003207              TACO BELL
# 410           TACO BELL 032520              TACO BELL
# 413            CHEVRON 0301732                CHEVRON
# 415           CARLS JR 1100817               CARLS JR
# 419             7 ELEVEN 17647               7 ELEVEN
# 422       JACK IN THE BOX 0488        JACK IN THE BOX
# 429               SUBWAY 44357                 SUBWAY
# 430            TACO BELL 30799              TACO BELL
# 432            CHEVRON 0301732                CHEVRON
# 438        TENNESSEE TRIBUNE 1      TENNESSEE TRIBUNE
# 443     PHX ZINC BRASSERIES4 1   PHX ZINC BRASSERIES4
# 450    AMERICAN 00180908035254               AMERICAN
# 451             CIRCLE K 06340               CIRCLE K
# 487     2075 CLT CNBC NEWS C 1   2075 CLT CNBC NEWS C
# 499        AUNTIE ANNE S NC136       AUNTIE ANNE S NC
# 503            JAMBA JUICE 061            JAMBA JUICE
# 510           PIZZA HUT 041438              PIZZA HUT
# 511       MAVERIK CNTRY STRE 2     MAVERIK CNTRY STRE
# 519      WHERE TRAVELER ST2859      WHERE TRAVELER ST
# 533            ANTHONY S CO 19           ANTHONY S CO
# 534            ANTHONY S CO 19           ANTHONY S CO
# 544                   HDV NO 1                 HDV NO
# 550     BLACKJACKS PIZZA CO023    BLACKJACKS PIZZA CO
# 551         RAISING CANES 0276          RAISING CANES
# 558      PREMIUM PARKING P2310      PREMIUM PARKING P
# 570              DOMINO S 6671               DOMINO S
# 572       SHIPLEY DO NUTS FC64     SHIPLEY DO NUTS FC
# 573          TACO CABANA 20284            TACO CABANA
# 576     EINSTEIN BROS BAGELS28   EINSTEIN BROS BAGELS
# 577        SUNPASS*ACC21969630            SUNPASS*ACC
# 580        SUNPASS*ACC21969630            SUNPASS*ACC
# 581         PANDA EXPRESS 1796          PANDA EXPRESS
# 583        SUNPASS*ACC21969630            SUNPASS*ACC
# 606         USPS PO 1797790077                USPS PO
# 612               FLYING J 470               FLYING J
# 628       EXXON 7 ELEVEN 34718         EXXON 7 ELEVEN
# 629       EXXON 7 ELEVEN 34718         EXXON 7 ELEVEN
# 633           STAPLES 00100578                STAPLES
# 638             CIRCLE K 07063               CIRCLE K
# 640            EWR LOT ECON P6         EWR LOT ECON P
# 642            EWR LOT ECON P6         EWR LOT ECON P
# 649          CLAIM JUMPER 0501           CLAIM JUMPER
# 689             POPEYE S 13872               POPEYE S
# 697    VIA RAIL C3187301273036             VIA RAIL C
# 709            CHEVRON 0381216                CHEVRON
# 713             7 ELEVEN 38710               7 ELEVEN
# 715         PANDA EXPRESS 2734          PANDA EXPRESS
# 719           STAPLES 00100719                STAPLES
# 720           STAPLES 00100719                STAPLES
# 724               DEL TACO 953               DEL TACO
# 725     DEN SMASH BURGER C 113     DEN SMASH BURGER C
# 736              CHIPOTLE 2877               CHIPOTLE
# 744             CIRCLE K 05622               CIRCLE K
# 753             EUROCAFE ST733            EUROCAFE ST
# 770               SUBWAY 40668                 SUBWAY
# 779           JIMMY JOHNS 2695            JIMMY JOHNS
# 780      WWW.DICKEYS.* SN 2236       WWW.DICKEYS.* SN
# 799     DTW ANDIAMO CONC A 112     DTW ANDIAMO CONC A
# 2035                WENDYS 591                 WENDYS
# 2039              POPEYES 4806                POPEYES
# 2042                 LJS 31439                    LJS
# 2046                WENDYS 591                 WENDYS
# 2047             POPEYES 13765                POPEYES
# 2061          TACO BELL 036185              TACO BELL
# 2066     UNITED 01642870862651                 UNITED
# 2075            7 ELEVEN 41628               7 ELEVEN
# 2084         TACO BELL 3002078              TACO BELL
# 2085    IND GROWN MKT B 618111        IND GROWN MKT B
# 2101              SUBWAY 52695                 SUBWAY
# 2105             DOMINO S 4380               DOMINO S
# 2106             DOMINO S 6016               DOMINO S
# 2107              FLYING J 712               FLYING J
# 2108              FLYING J 712               FLYING J
# 2109            BOJANGLES 1184              BOJANGLES
# 2113              FLYING J 712               FLYING J
# 2114              FLYING J 712               FLYING J
# 2118        MCALISTER S 104191            MCALISTER S
# 2183    ONT AIRPT PRKING LOT 4   ONT AIRPT PRKING LOT
# 2201      THE NEW STAND ST2858       THE NEW STAND ST
# 2211          ATLMARKET ST2681           ATLMARKET ST
# 2222          FREDDY S 19 0010            FREDDY S 19
# 2223              FLYING J 645               FLYING J
# 2224                PILOT 1174                  PILOT
# 2226        MCALISTER S 100974            MCALISTER S
# 2227            7 ELEVEN 26911               7 ELEVEN
# 2228              FLYING J 645               FLYING J
# 2236            CIRCLE K 02223               CIRCLE K
# 2239    VIR ATL 93280943794441                VIR ATL
# 2240   AMERICAN 00180943794474               AMERICAN
# 2241   AMERICAN 00106471451646               AMERICAN
# 2248            INSTACART*2246             INSTACART*
# 2259         PORT OF SUBS 0039           PORT OF SUBS
# 2266      DISTRICT NEWS ST2806       DISTRICT NEWS ST
# 2275           CHEVRON 0046369                CHEVRON
# 2281               WENDYS 7541                 WENDYS
# 2285     YARD HOUSE ZK 0108311          YARD HOUSE ZK
# 2286     YARD HOUSE ZK 0108311          YARD HOUSE ZK
# 2309                    QT 953                     QT
# 2312           TARGET 00020529                 TARGET
# 2316           TARGET 00020529                 TARGET
# 2318           TARGET 00020529                 TARGET
# 2331         POPEYES 11722 414          POPEYES 11722
# 2332         POPEYES 11722 414          POPEYES 11722
# 2338                 WAWA 5200                   WAWA
# 2346        THE UPS STORE 5973          THE UPS STORE
# 2356             DOMINO S 5884               DOMINO S
# 2361           FASTSIGNS 51101              FASTSIGNS
# 2364           FASTSIGNS 51101              FASTSIGNS
# 2369          PIZZA HUT 037001              PIZZA HUT
# 2386                ARBYS 9073                  ARBYS
# 2395             DOMINO S 8712               DOMINO S
# 2404          WHATABURGER 1310            WHATABURGER
# 2417             CHIPOTLE 1181               CHIPOTLE
# 2422           HARDEES 1501033                HARDEES
# 2423       HONEYBAKED HAM 0406         HONEYBAKED HAM
# 2426      MARATHON PETRO176792         MARATHON PETRO
# 2439      MARATHON PETRO231423         MARATHON PETRO
# 2486   AMERICAN 00180932383623               AMERICAN
# 2512           HARDEES 1501396                HARDEES
# 2513        USPS PO 0172300571                USPS PO
# 2515    ADVANCE AUTO PARTS 932     ADVANCE AUTO PARTS
# 2516        USPS PO 0172300571                USPS PO
# 2518    ADVANCE AUTO PARTS 932     ADVANCE AUTO PARTS
# 2525                ARBYS 1525                  ARBYS
# 2534         HUDSONNEWS ST1369          HUDSONNEWS ST
# 2536         PAPPADEAUX SFD 60         PAPPADEAUX SFD
# 2539       BJS RESTAURANTS 498        BJS RESTAURANTS
# 2542           CHEVRON 0203049                CHEVRON
# 2554             CARL S JR 301              CARL S JR
# 2563               SUBWAY 5277                 SUBWAY
# 2583        USPS PO 0522500440                USPS PO
# 2593        SEVEN ELEVEN 40601           SEVEN ELEVEN
# 2594                   SE40681                     SE
# 2607                ARBYS 1844                  ARBYS
# 2648           SLIM & HUSKYS 5          SLIM & HUSKYS
# 2657        THE UPS STORE 1504          THE UPS STORE
# 2669           CHEVRON 0047269                CHEVRON
# 2692    LINKEDIN SN 9391408776            LINKEDIN SN
# 2695    HABIT PALM BCH GARDQ91   HABIT PALM BCH GARDQ
# 2696    HABIT PALM BCH GARDQ91   HABIT PALM BCH GARDQ
# 2730    CAPITAL GRILLE 0138035         CAPITAL GRILLE
# 2734          TGI FRIDAYS 1935            TGI FRIDAYS
# 2780          JIMMY JOHNS 4455            JIMMY JOHNS
# 2803              WENDY S 0062                WENDY S
# 2804             GATE 0326 Q80            GATE 0326 Q
# 2820              SUBWAY 24306                 SUBWAY
# 2823         TACO CABANA 20286            TACO CABANA
# 2825             CHIPOTLE 2391               CHIPOTLE
# 2828             CHIPOTLE 3799               CHIPOTLE
# 2830             CHIPOTLE 0828               CHIPOTLE
# 2835          JIMMY JOHNS 2025            JIMMY JOHNS
# 2836          JIMMY JOHNS 2025            JIMMY JOHNS
# 2842          FREDDY S 01 0009            FREDDY S 01
# 2852                    QT 321                     QT
# 2853      BJ S RESTAURANTS 526       BJ S RESTAURANTS
# 2854                    QT 203                     QT
# 2860             WENDY S 10680                WENDY S
# 2917             CHIPOTLE 1871               CHIPOTLE
# 2925    HABIT PALM BCH GARDQ91   HABIT PALM BCH GARDQ
# 2944             HUDSON ST1675              HUDSON ST
# 2945             HUDSON ST1675              HUDSON ST
# 2949                CANTEEN 19                CANTEEN
# 2953          STAPLES 00103424                STAPLES
# 2954          STAPLES 00103424                STAPLES
# 2957          STAPLES 00103424                STAPLES
# 2970            7 ELEVEN 35623               7 ELEVEN
# 2980          ACE PARKING 0997            ACE PARKING
# 2985          ACE PARKING 0997            ACE PARKING
# 3007              SUBWAY 13261                 SUBWAY
# 3014              OUTBACK 3459                OUTBACK
# 3016   AMERICAN 00180938145990               AMERICAN
# 3017   AMERICAN 00180938145986               AMERICAN
# 3018   AMERICAN 00180938145942               AMERICAN
# 3019   AMERICAN 00180938146023               AMERICAN
# 3042       CHAIN INSTALLER 002        CHAIN INSTALLER
# 3044       CHAIN INSTALLER 250        CHAIN INSTALLER
# 3045       CHAIN INSTALLER 250        CHAIN INSTALLER
# 3046       CHAIN INSTALLER 360        CHAIN INSTALLER
# 3048        CHAIN INSTALLER 62        CHAIN INSTALLER
# 3061    HABIT SAN JOSE BROKQ91   HABIT SAN JOSE BROKQ
# 3691         SWISS CHALET 1931           SWISS CHALET
# 3696              SUBWAY 29715                 SUBWAY
# 3709                   BLUE 32                   BLUE
# 3711             POPEYES 10357                POPEYES
# 3713       AMERICAN DELI 188 1      AMERICAN DELI 188
# 3742         TAQUERIA EL REY 2        TAQUERIA EL REY
# 3745             CHIPOTLE 4373               CHIPOTLE
# 3749             CHIPOTLE 2411               CHIPOTLE
# 3750             CHIPOTLE 2333               CHIPOTLE
# 3754             CHIPOTLE 4408               CHIPOTLE
# 3755             CHIPOTLE 4408               CHIPOTLE
# 3758         TAQUERIA EL REY 2        TAQUERIA EL REY
# 3788          JIMMY JOHNS 2543            JIMMY JOHNS
# 3793    AMERICAN 0012127494327               AMERICAN
# 3794    AMERICAN 0012128340369               AMERICAN
# 3812           HARDEES 1501448                HARDEES
# 3830                 WAWA 8050                   WAWA
# 3838    SMF PEETS COFFEEB 6401      SMF PEETS COFFEEB
# 3853                FRESHENS 2               FRESHENS
# 3871        TXTAG 888 468 9824          TXTAG 888 468
# 3874    BESTBUYCOM806922060290             BESTBUYCOM
# 3875    BESTBUYCOM806922060290             BESTBUYCOM
# 3876         BEST BUY 00001651               BEST BUY
# 3877         BEST BUY 00001651               BEST BUY
# 3893       TENNESSEE TRIBUNE 1      TENNESSEE TRIBUNE
# 3894             HUDSON ST1895              HUDSON ST
# 3902              NEWSLINK C08             NEWSLINK C
# 3904     HY VEE PAPILLION 1514       HY VEE PAPILLION
# 3912        HUNGRY HOWIES 0066          HUNGRY HOWIES
# 3932            TIMENEWSST2639             TIMENEWSST
# 3944      SHIPLEY DO NUTS FC62     SHIPLEY DO NUTS FC
# 3953     JETBLUE 2794441531065                JETBLUE
# 3954     JETBLUE 2794441532555                JETBLUE
# 3967          WEIS MARKETS 225           WEIS MARKETS
# 3972        USPS PO 3820380224                USPS PO
# 3973          FREDDY S 02 0030            FREDDY S 02
# 3981            7 ELEVEN 41361               7 ELEVEN
# 3982            7 ELEVEN 41361               7 ELEVEN
# 3983              SUBWAY 14878                 SUBWAY
# 3984            7 ELEVEN 41361               7 ELEVEN
# 3986            7 ELEVEN 41361               7 ELEVEN
# 4000         TACO CABANA 20148            TACO CABANA

# %%
# Crearemos un diccionario para almacenar los conteos de valores únicos de cada columna
conteos_unicos = {}

# Iteramos sobre cada columna en el DataFrame
for columna in df.columns:
    # Contamos los valores únicos en cada columna y los almacenamos en el diccionario
    conteos_unicos[columna] = df[columna].nunique()

# Mostramos el resultado
print(conteos_unicos)
# Out:
# {'ASSETID': 4002, 'SUPPLIER_ERP': 2169, 'TOTAL_SPEND': 2910, 'SUPPLIER_ERP_WONULL': 2169, 'SUPPLIER_CLEAN': 1710, 'SUPPLIER_ERP_HASH_TRIM': 1544, 'SUPPLIER_ERP_REM_PAYME': 1543, 'SUPPLIER_CLEANED_FINAL': 1516, 'SUPPLIER_NO_TRAIL_NUM': 1304}

# %%
df.rename(columns={'SUPPLIER_NO_TRAIL_NUM': 'SUPPLIER_NORMALIZED'}, inplace=True)
#df.rename(columns={'  Sum(Total Spend USD) FY_2023  ': 'TOTAL_SPEND'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4002 entries, 0 to 4001
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ASSETID                 4002 non-null   object
#  1   SUPPLIER_ERP            4002 non-null   object
#  2   TOTAL_SPEND             4002 non-null   float64
#  3   SUPPLIER_ERP_WONULL     4002 non-null   object
#  4   SUPPLIER_CLEAN          4002 non-null   object
#  5   SUPPLIER_ERP_HASH_TRIM  4002 non-null   object
#  6   SUPPLIER_ERP_REM_PAYME  4002 non-null   object
#  7   SUPPLIER_CLEANED_FINAL  4002 non-null   object
#  8   SUPPLIER_NO_TRAIL_NUM   4002 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 281.5+ KB

# %%
selected_columns =['ASSETID','SUPPLIER_ERP', 'SUPPLIER_NORMALIZED', 'TOTAL_SPEND']
df_selected =df[selected_columns]

shape_before = df_selected.shape
print("Row count before grouping and with blanks:", shape_before)

df_selected = df_selected.groupby(['ASSETID','SUPPLIER_ERP', 'SUPPLIER_NORMALIZED'])['TOTAL_SPEND'].sum().reset_index()

#Use .loc to strip whitespaces in 'SUPPLIER_ERP' and 'SUPPLIER_NORMALIZED'
df_selected.loc[:, 'SUPPLIER_ERP'] = df_selected['SUPPLIER_ERP'].str.strip()
df_selected.loc[:, 'SUPPLIER_NORMALIZED'] = df_selected['SUPPLIER_NORMALIZED'].str.strip()

# concur_data = df_summarized.dropna(subset=['SUPPLIER_ERP', 'SUPPLIER_NORMALIZED'], how='any', inplace=False)
# Encontrar índices donde la columna 'SUPPLIER_NORMALIZED' es 'UNKNOWN'
indices_to_drop = df_selected[df_selected['SUPPLIER_NORMALIZED'] == 'UNKNOWN'].index
# Eliminar estas filas del DataFrame
concur_data = df_selected.drop(indices_to_drop)

shape_after= concur_data.shape
print("Row count after grouping and without blanks:", shape_after)
# Out:
# Row count before grouping and with blanks: (4002, 4)
# Row count after grouping and without blanks: (3875, 4)

# %%
# Crearemos un diccionario para almacenar los conteos de valores únicos de cada columna
conteos_unicos = {}

# Iteramos sobre cada columna en el DataFrame
for columna in concur_data.columns:
    # Contamos los valores únicos en cada columna y los almacenamos en el diccionario
    conteos_unicos[columna] = concur_data[columna].nunique()

# Mostramos el resultado
print(conteos_unicos)
# Out:
# {'ASSETID': 3875, 'SUPPLIER_ERP': 2168, 'SUPPLIER_NORMALIZED': 1407, 'TOTAL_SPEND': 2870}

# %%
selected_columns_2 =['FILE_NAME','ASSETID','SUPPLIER_ERP', 'SUPPLIER_NORMALIZED_2', 'TOTAL_SPEND']
df_selected_2 =df[selected_columns]

shape_before = df_selected_2.shape
print("Row count before grouping and with blanks:", shape_before)

df_selected_2 = df_selected_2.groupby(['FILE_NAME','ASSETID','SUPPLIER_ERP', 'SUPPLIER_NORMALIZED'])['TOTAL_SPEND'].sum().reset_index()

#Use .loc to strip whitespaces in 'SUPPLIER_ERP' and 'SUPPLIER_NORMALIZED'
df_selected_2.loc[:, 'SUPPLIER_ERP'] = df_selected_2['SUPPLIER_ERP'].str.strip()
df_selected_2.loc[:, 'SUPPLIER_NORMALIZED'] = df_selected_2['SUPPLIER_NORMALIZED'].str.strip()

# concur_data = df_summarized.dropna(subset=['SUPPLIER_ERP', 'SUPPLIER_NORMALIZED'], how='any', inplace=False)
# Encontrar índices donde la columna 'SUPPLIER_NORMALIZED' es 'UNKNOWN'
indices_to_drop = df_selected_2[df_selected_2['SUPPLIER_NORMALIZED'] == 'UNKNOWN'].index
# Eliminar estas filas del DataFrame
concur_data_2 = df_selected_2.drop(indices_to_drop)

shape_after= concur_data_2.shape
print("Row count after grouping and without blanks:", shape_after)
# Out:
# Row count before grouping and with blanks: (51234, 5)
# Row count after grouping and without blanks: (49417, 5)

# %%
concur_data.to_csv('concur supplier list mar v.6.csv', encoding='UTF-8-SIG', index=False)

# %%
# Clustering operation Concur data input

selected_columns =['FILE_NAME','ASSETID','SUPPLIER_ERP', 'SUPPLIER_NORMALIZED', 'TOTAL_SPEND', 'SUPPLIER_NORMALIZED_2']
df_selected =df[selected_columns]

shape_before = df_selected.shape
print("Row count before grouping and with blanks:", shape_before)

df_summarized = df_selected.groupby(['FILE_NAME','ASSETID','SUPPLIER_ERP', 'SUPPLIER_NORMALIZED', 'SUPPLIER_NORMALIZED_2'])['TOTAL_SPEND'].sum().reset_index()

#Use .loc to strip whitespaces in 'SUPPLIER_ERP' and 'SUPPLIER_NORMALIZED'
df_summarized.loc[:, 'SUPPLIER_ERP'] = df_summarized['SUPPLIER_ERP'].str.strip()
df_summarized.loc[:, 'SUPPLIER_NORMALIZED'] = df_summarized['SUPPLIER_NORMALIZED'].str.strip()
df_summarized.loc[:, 'SUPPLIER_NORMALIZED_2'] = df_summarized['SUPPLIER_NORMALIZED_2'].str.strip()


concur_data = df_summarized.dropna(subset=['SUPPLIER_ERP', 'SUPPLIER_NORMALIZED'], how='any', inplace=False)

shape_after= concur_data.shape
print("Row count after grouping and without blanks:", shape_after)

concur_data.to_csv('concur supplier list mar v.2.csv', encoding='UTF-8-SIG', index=False)
# Out:
# Row count before grouping and with blanks: (51234, 6)
# Row count after grouping and without blanks: (51228, 11)

# %% [markdown]
# | Column                   | Distinct Values | Relative Variation | Percentage Variation   | Procedure Description                                        |
# |--------------------------|-----------------|--------------------|------------------------|--------------------------------------------------------------|
# | SUPPLIER_NORMALIZED      | 11203           | -                  | -                      | Data normalized from oracle                                  |
# | SUPPLIER_CLEAN           | 11138           | -65                | -0.58%                 | Apply dictionary and null values handled as unknown          |
# | SUPPLIER_ERP_HASH_TRIM   | 11035           | -103               | -0.92%                 | Removed everything to the right of a hash (#) symbol.        |
# | SUPPLIER_ERP_REM_PAYME   | 11028           | -7                 | -0.063%                | 'Payment' related terms removed from names.                  |
# | SUPPLIER_CLEANED_FINAL   | 10957           | -71                | -0.64%                 | Cleaned special characters while preserving internet domains.|
# | SUPPLIER_NO_TRAIL_NUM    | 10039           | -918               | -8.37%                 | Trailing numbers removed from supplier names.                |

# %% [markdown]
# | Casos para considerar en las funciones | Obs |
# |-|-|
# | LAX - TERMINAL 3 |
